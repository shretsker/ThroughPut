# %% [markdown]
# # Extracted Data Exploration and Cleaning

# %% [markdown]
# ## Introduction
#
# This notebook focuses on exploring and cleaning the extracted dataset of embedded systems products. The dataset contains various attributes of these products, including operating systems, wireless capabilities, certifications, and other technical specifications. Our goal is to standardize and clean this data to make it more suitable for analysis and insights generation.

# %% [markdown]
# ## Objectives
#
# 1. Explore the extracted data to understand its structure and content
# 2. Understand the initial extraction data, in each column
# 3. Clean and standardize the columns
# 4. Provide summary statistics for each cleaned column
# 5. Generate example values of the cleaned data, and save the cleaned data to a new csv file

# %% [markdown]
# ## 1. Setup and Data Loading <a id="1"></a>
#
# We start by importing necessary libraries and loading the result data files.

# %%
import os
import re
import ast
import logging
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 1000)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.float_format', '{:.2f}'.format)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.max_rows', 1000)

# Set up display options and styles
sns.set(style="whitegrid", font_scale=1.2)
plt.rcParams['figure.figsize'] = (12, 8)
# %matplotlib inline

# Configure logging
logging.basicConfig(level=logging.ERROR, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Load the data
data_dir = "../data/processed_feature_extraction_results.csv"
df = pd.read_csv(data_dir)
df.head()
# Out:
#             product_id                           name                  manufacturer        form_factor       evaluation_or_commercialization processor_architecture processor_core_count processor_manufacturer processor_tdp                  memory                             onboard_storage              input_voltage                                                                          io_count                                                                                                               wireless                                                                                 operating_system_bsp                                            operating_temperature_max operating_temperature_min                    certifications                                                                                    short_summary                                                                                                                                                                                                               full_summary                                                                                                                                                                                                                                                                                                                                                                                           full_product_description                                                                                                                                                                                                                                                                                                                 target_applications                                                                                                                                                                     duplicate_ids
# 0  iW-G27S-SCQM-4L004G-E016G-BIC  IMX QUAD MAX QUAD PLUS PICO ITX SBC  IWAVE SYSTEMS                PICO ITX               False                       ARM                          6               NXP               NaN                            Up to 8GB LPDDR4                          Up to 64GB eMMC         12V                                             ['USB 3.0', 'USB 2.0', 'HDMI', 'Ethernet', 'PCIe', 'CAN', 'UART', 'SPI', 'I2C', 'MIPI CSI', 'MIPI DSI', 'LVDS']                                                              ['Wi-Fi', 'Bluetooth']                                                                            ['Linux', 'Android Pie', 'QNX']            85°C                      -40°C                                            ['RoHS', 'REACH']  The iMX Quad Max Quad Plus Pico ITX SBC is a high-performance, compact single board computer designed for industrial and embedded applications.  The iMX Quad Max Quad Plus Pico ITX SBC integrates dual Cortex-A72 and Cortex-A53 cores, dual GPUs, and a VPU for enhanced multimedia capabilities. It supports up to 8GB LPDDR4 memory and 64GB eMMC storage, with extensive I/O options including USB, HDMI, Ethernet, and wireless connectivity.                                                                                                          The iMX Quad Max Quad Plus Pico ITX SBC is engineered for high-performance applications in industrial, automotive, and medical domains. It features a robust set of interfaces including dual Ethernet, multiple USB ports, PCIe, and advanced display outputs like HDMI and MIPI DSI. The board supports Linux, Android Pie, and QNX operating systems, making it versatile for various development needs.  ['Remote Energy Management', 'Intelligent Edge', 'Augmented and Virtual Reality', '4K Media Streaming', 'Industrial Automation', 'Automotive eCockpit']                                                                                                                                               ['iW-G27S-SCQM-4L004G-E016G-BIC', 'iW-G27S-SCQM-4L008G-E032G-BIC']
# 1          conga-TC170slash3955U                              CONGATC       CONGATEC     COM EXPRESS COMPACT                True                       X86                          2             INTEL               15W            Up to 32 GByte dual channel DDR4  Optional eMMC 5.1 on board mass storage      21 VDC    ['x PCI Express GEN 3 lanes', 'x Serial ATA Gen 3', 'x USB 3.0', 'x USB 2.0', 'LPC bus', 'I2C bus', 'x UART', 'Digital High Definition Audio Interface']                                                                           Available  ['Microsoft Windows', 'Microsoft Windows IoT Enterprise', 'Linux', 'Microsoft Windows Embedded Standard']            60°C                        0°C                                         FCC Class A, UL 94V0                                                  Compact module with Intel Core processors, dual channel DDR4 memory, and extensive I/O options.                                                                              The congaTC is a COM Express Compact module featuring Intel Core i7/i5/i3 and Celeron processors, supporting dual channel DDR4 memory, and offering a wide range of I/O interfaces including PCIe, SATA, USB, and more.                                                                            The congaTC module is designed for high-performance applications, equipped with Intel's 6th generation Core processors and Celeron options. It supports up to 32 GByte of dual channel DDR4 memory, and provides a variety of interfaces such as PCIe, SATA, USB, and audio. The module is suitable for industrial and embedded applications, offering features like Intel Turbo Boost, Hyper-Threading, and virtualization technologies.                                                            ['Industrial automation', 'Embedded systems', 'Digital signage', 'Medical devices', 'Gaming']                                                                                                                                                                                        ['conga-TC170slash3955U']
# 2                34012-0416-N1-2                            COMEMEL E        KONTRON        COM EXPRESS MINI                True                       X86             Up to 14 cores             INTEL               31W                         UP TO 8 GBYTE LPDDR                      UP TO 64 GBYTE EMMC          5V                                                                                     ['Up to 2x USB 3.0, 8x USB 2.0, up to 4x serial interfaces or CAN bus']  Supports wireless technologies with miniature RF connectors for WLAN and Bluetooth                                                                            ['Windows', 'Linux', 'VxWorks']            85°C                      -40°C                           EN50155:2021 for Edge AI Platforms                                                                COM Express mini Type 10 module with Intel Atom, Pentium, and Celeron processors.                                                                                                                    The COMemEL E is a COM Express mini Type 10 module featuring Intel Atom, Pentium, and Celeron processors, designed for low power and high performance in industrial applications.                                                                                                                                              The COMemEL E module is a compact, low-power solution optimized for industrial applications. It supports up to 8 GByte LPDDR memory with In-Band ECC, multiple USB ports, SATA, eMMC Flash, and optional GbE with TSN support. It is designed to operate in industrial temperature ranges and supports various operating systems including Windows, Linux, and VxWorks.                                                                                                                       ['Industrial', 'Embedded Systems']                                                                                                                  ['34012-0416-N1-2', '34012-0432-J2-4', '34013-0416-R1-2', '34013-0432-R1-4', '34013-0832-R2-4']
# 3       conga-TCA7slashi-x6212RE                             CONGATCA       CONGATEC     COM EXPRESS COMPACT               False                       X86                          4             INTEL                6W          DDR4 SODIMM, 3200 MT/s, up to 32GB                               eMMC, 64GB         NaN                                                                                                                        ['PCIe, USB, SATA, UART, CAN, GPIO']                                                                                 NaN                             ['Microsoft Windows IoT Enterprise', 'Linux Yocto', 'RTS RealTime Hypervisor']            85°C                      -40°C                                                          NaN                           COM Express Compact module with Intel Atom, Pentium, and Celeron processors, supporting industrial temperature ranges.                                                                   The congaTCA is a COM Express Compact module featuring Intel Atom xE, Pentium, and Celeron processors, designed for industrial applications with support for DDR4 SODIMM memory, eMMC storage, and a wide range of I/O interfaces.  The congaTCA module by congatec is built on the COM Express Compact form factor, integrating Intel Atom xE, Pentium, and Celeron processors. It supports dual-channel DDR4 SODIMM memory up to 32GB, onboard eMMC storage, and various I/O interfaces including PCIe, USB, SATA, UART, CAN, and GPIO. The module is suitable for industrial applications with an operating temperature range from -40°C to 85°C. It supports multiple operating systems including Microsoft Windows IoT Enterprise and Linux Yocto.                                                                                                                ['Industrial', 'Embedded Systems', 'IoT']  ['conga-TCA7slashi-x6212RE', 'conga-TCA7slashi-x6414RE', 'conga-TCA7slashi-x6425RE', 'conga-TCA7slashJ6413', 'conga-TCA7slashJ6426', 'conga-TCA7slashx6211E', 'conga-TCA7slashx6413E', 'conga-TCA7slashx6425E']
# 4                 MIC-7700H-00A1                                  MIC      ADVANTECH  Compact Fanless System               False                       x86                        24C             INTEL               35W      Dual-channel DDR3 1600 MHz, up to 16GB                        HDD, CFast, mSATA     9-36VDC                                                                                                                  ['4x USB 3.0, 4x USB 2.0, 6x COM, 2x LAN']                            WiFi Module 802.11 a/b/g/n/ac 2T2R w/BT5.1, Intel AC9260                                                                                                Embedded OS            60°C                      -20°C           ['CE', 'FCC Class A', 'CCC', 'BSMI', 'UL', 'RoHS']                                                    Compact fanless system with Intel Core CPU, multiple I/O ports, and wide input voltage range.                                                                                                       The MIC series is a compact fanless system featuring Intel's 4th and 5th Gen Core CPUs, supporting a wide range of I/O interfaces and expansion modules, suitable for industrial applications.                                                                                                  The MIC series by Advantech is designed for industrial applications, offering a compact fanless design with Intel Core processors. It supports a variety of I/O interfaces including USB, COM, and LAN ports, and offers flexible storage options with HDD, CFast, and mSATA. The system is certified with CE, FCC, CCC, BSMI, UL, and RoHS standards, ensuring compliance and reliability in various environments.                                                                                            ['Industrial Automation', 'Embedded Systems', 'IoT Gateways']                                                                                                                                                                             ['MIC-7700H-00A1', 'MIC-7700Q-00A1']

# %%
df.columns
# Out:
# Index(['product_id', 'name', 'manufacturer', 'form_factor', 'evaluation_or_commercialization', 'processor_architecture', 'processor_core_count', 'processor_manufacturer', 'processor_tdp', 'memory', 'onboard_storage', 'input_voltage', 'io_count', 'wireless', 'operating_system_bsp', 'operating_temperature_max', 'operating_temperature_min', 'certifications', 'short_summary', 'full_summary', 'full_product_description', 'target_applications', 'duplicate_ids'], dtype='object')

# %%
columns = [
    "name",
    "manufacturer",
    "form_factor",
    "evaluation_or_commercialization",
    "processor_architecture",
    "processor_core_count",
    "processor_manufacturer",
    "processor_tdp",
    "memory",
    "onboard_storage",
    "input_voltage",
    "io_count",
    "wireless",
    "operating_system_bsp",
    "operating_temperature_max",
    "operating_temperature_min",
    "certifications",
]


# Display top 10 unique values for each column, sorted by frequency
for column in columns:
    unique_count = df[column].nunique()
    value_counts = df[column].value_counts().head(50)

    print(f"\n{'-' * 100}")
    print(f"{column.upper()} (Total unique values: {unique_count})")
    print(f"{'-' * 100}")

    if not value_counts.empty:
        max_value_length = max(len(str(value)) for value in value_counts.index)
        max_count_length = max(len(str(count)) for count in value_counts.values)

        for value, count in value_counts.items():
            percentage = (count / len(df)) * 100
            print(f"{str(value):<{max_value_length}} | {count:>{max_count_length}} | {percentage:.2f}%")
    else:
        print("No data available for this column")

    print(f"{'-' * 100}\n")
# Out:
# ----------------------------------------------------------------------------------------------------
# NAME (Total unique values: 677)
# ----------------------------------------------------------------------------------------------------
# AIMB                                                    | 47 | 4.80%
# SOM                                                     | 19 | 1.94%
# ASMB                                                    | 12 | 1.23%
# PCM                                                     | 11 | 1.12%
# ARK                                                     | 10 | 1.02%
# MIO                                                     | 10 | 1.02%
# RSB                                                     |  9 | 0.92%
# RASPBERRY PI MODEL B                                    |  7 | 0.72%
# AIMB-275                                                |  7 | 0.72%
# VENICE GW                                               |  7 | 0.72%
# COM EXPRESS COMPACT MODULE                              |  6 | 0.61%
# COM EXPRESS BASIC MODULE                                |  6 | 0.61%
# TREK                                                    |  6 | 0.61%
# EDHMIC                                                  |  6 | 0.61%
# EMETXEI                                                 |  5 | 0.51%
# PCA                                                     |  5 | 0.51%
# CONGATC                                                 |  5 | 0.51%
# COMPUTER ON MODULES                                     |  5 | 0.51%
# MIC                                                     |  5 | 0.51%
# AIMB-580                                                |  5 | 0.51%
# PCEGA                                                   |  5 | 0.51%
# UNOG                                                    |  5 | 0.51%
# VENICE GW SINGLE BOARD COMPUTER                         |  4 | 0.41%
# SOM COM EXPRESS COMPACT MODULE                          |  4 | 0.41%
# EMETXEIM                                                |  4 | 0.41%
# ARKL                                                    |  4 | 0.41%
# CONGATS                                                 |  4 | 0.41%
# PCEGAE                                                  |  4 | 0.41%
# COM EXPRESS MINI MODULE                                 |  4 | 0.41%
# AGS GPU SERVER                                          |  3 | 0.31%
# CONGASA                                                 |  3 | 0.31%
# IBASE IBAF                                              |  3 | 0.31%
# AIMB-225                                                |  3 | 0.31%
# COMPUTE MODULE                                          |  3 | 0.31%
# MIO EXTENSION SBC                                       |  3 | 0.31%
# RASPBERRY PI                                            |  3 | 0.31%
# CONGATCA                                                |  3 | 0.31%
# ROCK PI S                                               |  3 | 0.31%
# ROM QSEVEN MODULE                                       |  3 | 0.31%
# SOM INTEL ATOMCELERON PROCESSOR COM EXPRESS MINI MODULE |  3 | 0.31%
# MIOJUAE                                                 |  3 | 0.31%
# ROCK PI N                                               |  3 | 0.31%
# ODYSSEY XJ                                              |  3 | 0.31%
# UBIQUITOUS TOUCH COMPUTER                               |  3 | 0.31%
# ARKDS                                                   |  3 | 0.31%
# RASPBERRY PI COMPUTE MODULE                             |  3 | 0.31%
# ARKFSAE                                                 |  2 | 0.20%
# QBiA                                                    |  2 | 0.20%
# TX COMPUTER ON MODULE                                   |  2 | 0.20%
# BL BPC EW                                               |  2 | 0.20%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# MANUFACTURER (Total unique values: 112)
# ----------------------------------------------------------------------------------------------------
# ADVANTECH                          | 404 | 41.27%
# IEI                                |  60 | 6.13%
# CONGATEC                           |  39 | 3.98%
# KONTRON                            |  37 | 3.78%
# ARBOR TECHNOLOGY                   |  25 | 2.55%
# VERSALOGIC CORPORATION             |  22 | 2.25%
# IBASE                              |  21 | 2.15%
# ADLINK TECHNOLOGY INC              |  18 | 1.84%
# MYIR ELECTRONICS LIMITED           |  15 | 1.53%
# AXIOMTEK                           |  14 | 1.43%
# KARO ELECTRONICS GMBH              |  14 | 1.43%
# VERSALOGIC                         |  13 | 1.33%
# IWAVE SYSTEMS TECHNOLOGIES         |  11 | 1.12%
# EUROTECH                           |  11 | 1.12%
# PHOENIX CONTACT                    |  11 | 1.12%
# SOLIDRUN                           |  10 | 1.02%
# ADLINK TECHNOLOGY                  |  10 | 1.02%
# EDA TECHNOLOGY CO LTD              |   9 | 0.92%
# CONGATEC GMBH                      |   9 | 0.92%
# IWAVE SYSTEMS                      |   9 | 0.92%
# NEXCOBOT                           |   9 | 0.92%
# SOLIDRUN LTD                       |   9 | 0.92%
# GATEWORKS CORPORATION              |   8 | 0.82%
# RASPBERRY PI TRADING LTD           |   7 | 0.72%
# SECO                               |   7 | 0.72%
# RADXA                              |   6 | 0.61%
# NVIDIA                             |   6 | 0.61%
# RASPBERRY PI                       |   6 | 0.61%
# ASUS                               |   6 | 0.61%
# GIGAIPC                            |   6 | 0.61%
# FORLINX EMBEDDED TECHNOLOGY CO LTD |   6 | 0.61%
# IBASE TECHNOLOGY                   |   6 | 0.61%
# RASPBERRY PI LTD                   |   6 | 0.61%
# DIGI INTERNATIONAL                 |   6 | 0.61%
# AAEON                              |   5 | 0.51%
# SEEED STUDIO                       |   5 | 0.51%
# OLIMEX                             |   4 | 0.41%
# NXP                                |   4 | 0.41%
# GATEWORKS                          |   4 | 0.41%
# BOUNDARY DEVICES                   |   3 | 0.31%
# ESPRESSIF SYSTEMS                  |   3 | 0.31%
# GOOGLE                             |   3 | 0.31%
# KARO ELECTRONICS                   |   3 | 0.31%
# MIXTILE                            |   3 | 0.31%
# D SYSTEMS                          |   3 | 0.31%
# ACURA EMBEDDED SYSTEMS INC         |   3 | 0.31%
# GUMSTIX                            |   3 | 0.31%
# INTEL                              |   3 | 0.31%
# CONGATEC AG                        |   2 | 0.20%
# STARTECHCOM                        |   2 | 0.20%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# FORM_FACTOR (Total unique values: 227)
# ----------------------------------------------------------------------------------------------------
# MINI-ITX                 | 56 | 5.72%
# SBC                      | 55 | 5.62%
# ATX                      | 51 | 5.21%
# SMARC                    | 38 | 3.88%
# COM EXPRESS COMPACT      | 38 | 3.88%
# QSEVEN                   | 35 | 3.58%
# SINGLE BOARD COMPUTER    | 32 | 3.27%
# Single Board Computer    | 30 | 3.06%
# COM EXPRESS              | 29 | 2.96%
# COM EXPRESS BASIC        | 25 | 2.55%
# MICROATX                 | 22 | 2.25%
# RASPBERRY PI             | 20 | 2.04%
# COM EXPRESS MINI         | 18 | 1.84%
# SODIMM                   | 17 | 1.74%
# PICO-ITX                 | 16 | 1.63%
# COM EXPRESS BASIC MODULE | 13 | 1.33%
# Mini-ITX                 | 13 | 1.33%
# PICOITX                  | 13 | 1.33%
# PCPLUS                   | 12 | 1.23%
# EBX                      | 12 | 1.23%
# EPIC                     | 11 | 1.12%
# SYSTEM ON MODULE         | 11 | 1.12%
# Fanless Box PC           | 10 | 1.02%
# MICRO ATX                | 10 | 1.02%
# QFN                      | 10 | 1.02%
# ETX                      |  9 | 0.92%
# SOM                      |  9 | 0.92%
# Box PC                   |  9 | 0.92%
# COM                      |  7 | 0.72%
# PICMG                    |  7 | 0.72%
# ALL-IN-ONE               |  7 | 0.72%
# DIN RAIL                 |  7 | 0.72%
# Fanless Embedded Box PC  |  7 | 0.72%
# Proprietary              |  6 | 0.61%
# THIN MINI-ITX            |  6 | 0.61%
# SYSTEM MODULE            |  6 | 0.61%
# MIO                      |  6 | 0.61%
# COM Express Basic        |  5 | 0.51%
# SINGLEBOARD COMPUTER     |  5 | 0.51%
# MINI ITX                 |  5 | 0.51%
# SINGLE-BOARD COMPUTER    |  5 | 0.51%
# Embedded                 |  5 | 0.51%
# PALMSIZE                 |  4 | 0.41%
# DINRAIL                  |  4 | 0.41%
# REGULAR SIZE             |  4 | 0.41%
# Panel PC                 |  4 | 0.41%
# PC                       |  4 | 0.41%
# PICO ITX                 |  4 | 0.41%
# Embedded SBC             |  4 | 0.41%
# Compact                  |  4 | 0.41%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# EVALUATION_OR_COMMERCIALIZATION (Total unique values: 3)
# ----------------------------------------------------------------------------------------------------
# False             | 826 | 84.37%
# True              | 151 | 15.42%
# Commercialization |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# PROCESSOR_ARCHITECTURE (Total unique values: 60)
# ----------------------------------------------------------------------------------------------------
# x86                                                      | 372 | 38.00%
# X86                                                      | 251 | 25.64%
# ARM                                                      | 250 | 25.54%
# ARM Cortex-A53                                           |   9 | 0.92%
# x86-64                                                   |   8 | 0.82%
# ARM Cortex-A                                             |   5 | 0.51%
# SILVERMONT                                               |   4 | 0.41%
# ARM Cortex-A72                                           |   3 | 0.31%
# INTEL                                                    |   3 | 0.31%
# ARM Cortex-A8                                            |   3 | 0.31%
# ARM Cortex-A9                                            |   2 | 0.20%
# ARM v8                                                   |   2 | 0.20%
# Intel 64                                                 |   2 | 0.20%
# Skylake-U                                                |   2 | 0.20%
# Apollo Lake                                              |   2 | 0.20%
# ARM big.LITTLE                                           |   2 | 0.20%
# ARM CORTEX-A                                             |   2 | 0.20%
# Intel performance hybrid architecture                    |   2 | 0.20%
# ZEN                                                      |   2 | 0.20%
# Intel Xeon E and 8th/9th Generation Core i3/i5/i7 series |   1 | 0.10%
# ARMv8                                                    |   1 | 0.10%
# 8-bit                                                    |   1 | 0.10%
# ARM Cortex-M3                                            |   1 | 0.10%
# Cortex-A53 64-bit                                        |   1 | 0.10%
# RISCV                                                    |   1 | 0.10%
# CORTEX-A                                                 |   1 | 0.10%
# Xtensa                                                   |   1 | 0.10%
# Performance hybrid architecture                          |   1 | 0.10%
# RISC-V                                                   |   1 | 0.10%
# ARM CORTEXA                                              |   1 | 0.10%
# Zen                                                      |   1 | 0.10%
# Arm Cortex-A53                                           |   1 | 0.10%
# ARM Cortex A53                                           |   1 | 0.10%
# Silvermont                                               |   1 | 0.10%
# ARM CORTEX A                                             |   1 | 0.10%
# 32-bit ARM architecture                                  |   1 | 0.10%
# Alder Lake-S                                             |   1 | 0.10%
# x86_64                                                   |   1 | 0.10%
# Arm Cortex                                               |   1 | 0.10%
# ARM CORTEX-M3                                            |   1 | 0.10%
# Alder Lake N                                             |   1 | 0.10%
# Mobile Athlon architecture                               |   1 | 0.10%
# Raptor Lake-S                                            |   1 | 0.10%
# Haswell                                                  |   1 | 0.10%
# Alder Lake                                               |   1 | 0.10%
# x86 hybrid architecture                                  |   1 | 0.10%
# Intel® Core™ Ultra Meteor Lake-H/U                       |   1 | 0.10%
# x86 and Arm                                              |   1 | 0.10%
# ARM Cortex-A72/A53                                       |   1 | 0.10%
# Intel Atom C3000                                         |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# PROCESSOR_CORE_COUNT (Total unique values: 141)
# ----------------------------------------------------------------------------------------------------
# 4                                         | 270 | 27.58%
# 2                                         |  95 | 9.70%
# Quad-core                                 |  56 | 5.72%
# Quad Core                                 |  51 | 5.21%
# 6                                         |  36 | 3.68%
# 8                                         |  27 | 2.76%
# Quad                                      |  20 | 2.04%
# 1                                         |  20 | 2.04%
# Dual-core                                 |  18 | 1.84%
# Quad core                                 |  16 | 1.63%
# Quad-Core                                 |  15 | 1.53%
# Dual                                      |  12 | 1.23%
# Dual Core                                 |  11 | 1.12%
# Up to 14 cores                            |  10 | 1.02%
# 24                                        |  10 | 1.02%
# Quad/Dual                                 |   9 | 0.92%
# Up to 16 cores                            |   8 | 0.82%
# 16 cores                                  |   7 | 0.72%
# 16                                        |   7 | 0.72%
# Dual/Quad                                 |   7 | 0.72%
# Dual core                                 |   7 | 0.72%
# 8 cores                                   |   6 | 0.61%
# 4 cores                                   |   6 | 0.61%
# QuadCore                                  |   6 | 0.61%
# 6 to 10 cores                             |   6 | 0.61%
# 12                                        |   5 | 0.51%
# Single, Dual, Quad                        |   5 | 0.51%
# Up to 24 cores                            |   5 | 0.51%
# Up to 4 cores                             |   4 | 0.41%
# Dual-Core                                 |   4 | 0.41%
# 2 / 4                                     |   4 | 0.41%
# 14 cores                                  |   4 | 0.41%
# 10                                        |   4 | 0.41%
# Single Core, Dual Core                    |   4 | 0.41%
# 14                                        |   4 | 0.41%
# 24 cores                                  |   4 | 0.41%
# Hexa/Quad                                 |   3 | 0.31%
# Quad, Dual, Single                        |   3 | 0.31%
# 6 P-Cores, 8 E-Cores, 2 Low Power E-Cores |   3 | 0.31%
# DUAL CORE                                 |   3 | 0.31%
# Single-core                               |   3 | 0.31%
# 4C/8T                                     |   3 | 0.31%
# Up to 28 cores                            |   2 | 0.20%
# Quad- or dual-core                        |   2 | 0.20%
# Single                                    |   2 | 0.20%
# 1, 2, or 4                                |   2 | 0.20%
# Single/Dual/Quad                          |   2 | 0.20%
# dual core                                 |   2 | 0.20%
# Single, dual, quad-core                   |   2 | 0.20%
# Up to 24                                  |   2 | 0.20%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# PROCESSOR_MANUFACTURER (Total unique values: 49)
# ----------------------------------------------------------------------------------------------------
# INTEL                     | 543 | 55.46%
# NXP                       | 120 | 12.26%
# Intel                     |  84 | 8.58%
# AMD                       |  61 | 6.23%
# BROADCOM                  |  23 | 2.35%
# ROCKCHIP                  |  22 | 2.25%
# FREESCALE                 |  11 | 1.12%
# Broadcom                  |  11 | 1.12%
# ARM                       |  10 | 1.02%
# TEXAS INSTRUMENTS         |  10 | 1.02%
# NVIDIA                    |   8 | 0.82%
# ALLWINNER                 |   7 | 0.72%
# XILINX                    |   5 | 0.51%
# TI                        |   5 | 0.51%
# RENESAS                   |   5 | 0.51%
# DMP                       |   5 | 0.51%
# QUALCOMM                  |   4 | 0.41%
# ESPRESSIF SYSTEMS         |   3 | 0.31%
# MEDIATEK                  |   3 | 0.31%
# MARVELL                   |   3 | 0.31%
# STMICROELECTRONICS        |   3 | 0.31%
# Freescale                 |   2 | 0.20%
# DMP ELECTRONICS INC       |   2 | 0.20%
# RASPBERRY PI LTD          |   2 | 0.20%
# KNERON                    |   1 | 0.10%
# STERICSSON                |   1 | 0.10%
# Rabbit                    |   1 | 0.10%
# Marvell                   |   1 | 0.10%
# ST Microelectronics       |   1 | 0.10%
# RABBIT                    |   1 | 0.10%
# Raspberry Pi              |   1 | 0.10%
# STM                       |   1 | 0.10%
# Rockchip                  |   1 | 0.10%
# Western Design Center     |   1 | 0.10%
# Espressif Systems         |   1 | 0.10%
# ADVANTECH                 |   1 | 0.10%
# ALLWINNER TECH            |   1 | 0.10%
# ARM LIMITED               |   1 | 0.10%
# Allwinner                 |   1 | 0.10%
# Renesas                   |   1 | 0.10%
# ATMEL                     |   1 | 0.10%
# QUALCOMM TECHNOLOGIES INC |   1 | 0.10%
# Allwinner Technology      |   1 | 0.10%
# Arm                       |   1 | 0.10%
# VIA                       |   1 | 0.10%
# MICROCHIP                 |   1 | 0.10%
# ST                        |   1 | 0.10%
# RABBIT SEMICONDUCTOR INC  |   1 | 0.10%
# RABBIT SEMICONDUCTOR      |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# PROCESSOR_TDP (Total unique values: 143)
# ----------------------------------------------------------------------------------------------------
# 15W                                                      | 90 | 9.19%
# 6W                                                       | 86 | 8.78%
# 35W                                                      | 43 | 4.39%
# 45W                                                      | 35 | 3.58%
# 95W                                                      | 25 | 2.55%
# 65W                                                      | 25 | 2.55%
# 10W                                                      | 23 | 2.35%
# 125W                                                     | 15 | 1.53%
# 12W                                                      | 12 | 1.23%
# 6W/6W/12W/9W/6W up to 45W                                | 10 | 1.02%
# 28W (passive cooled)                                     | 10 | 1.02%
# 65W / 35W                                                |  8 | 0.82%
# 25 W                                                     |  8 | 0.82%
# 125 W                                                    |  7 | 0.72%
# 10 watts                                                 |  7 | 0.72%
# 28W                                                      |  7 | 0.72%
# 6W to 12W                                                |  6 | 0.61%
# 35W to 65W                                               |  6 | 0.61%
# 6W, 9W, 12W                                              |  5 | 0.51%
# 205W                                                     |  5 | 0.51%
# 12-25W                                                   |  4 | 0.41%
# 45 W                                                     |  4 | 0.41%
# 6W to 45W                                                |  4 | 0.41%
# 35 watts                                                 |  4 | 0.41%
# 9W                                                       |  4 | 0.41%
# 5W                                                       |  4 | 0.41%
# 6.7W                                                     |  4 | 0.41%
# 6W/10W/10W                                               |  3 | 0.31%
# 10 W                                                     |  3 | 0.31%
# 70W                                                      |  3 | 0.31%
# 17 watts                                                 |  3 | 0.31%
# 25 to 45 watts                                           |  3 | 0.31%
# 19 Watt                                                  |  3 | 0.31%
# 15 to 45W                                                |  3 | 0.31%
# 6W to 10W                                                |  3 | 0.31%
# Ultra low power                                          |  3 | 0.31%
# 5W to 10W                                                |  3 | 0.31%
# 65 W                                                     |  3 | 0.31%
# 45 Watt                                                  |  2 | 0.20%
# 31W                                                      |  2 | 0.20%
# 77 watts                                                 |  2 | 0.20%
# 28W (passive cooled), 15-25W (passive cooled), 54W (fan) |  2 | 0.20%
# 8 watts                                                  |  2 | 0.20%
# 12-28W                                                   |  2 | 0.20%
# 15W to 45W                                               |  2 | 0.20%
# Up to 125W                                               |  2 | 0.20%
# 2W                                                       |  2 | 0.20%
# 80W                                                      |  2 | 0.20%
# Low power consumption                                    |  2 | 0.20%
# 12-54W                                                   |  2 | 0.20%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# MEMORY (Total unique values: 638)
# ----------------------------------------------------------------------------------------------------
# 4 GB LPDDR4                                  | 24 | 2.45%
# 8GB DDR3L                                    | 17 | 1.74%
# 1 GB DDR3                                    | 13 | 1.33%
# 2 GB LPDDR4                                  | 11 | 1.12%
# 8GB LPDDR4                                   | 10 | 1.02%
# 8 GB DDR3L                                   | 10 | 1.02%
# 4GB LPDDR4                                   |  9 | 0.92%
# 4 GB DDR3L                                   |  9 | 0.92%
# Up to 8GB DDR3L                              |  8 | 0.82%
# Up to 32GB DDR4                              |  8 | 0.82%
# 512 MB DDR3                                  |  7 | 0.72%
# 8GB DDR3L SDRAM                              |  7 | 0.72%
# 4 GB DDR3L SDRAM                             |  7 | 0.72%
# 8 GB DDR4                                    |  6 | 0.61%
# 4 GByte LPDDR4                               |  6 | 0.61%
# 4 GB LPDDR3                                  |  6 | 0.61%
# 512 MB DDR3 SDRAM                            |  6 | 0.61%
# 2GB LPDDR4                                   |  6 | 0.61%
# 8GB DDR4 SODIMM                              |  5 | 0.51%
# Up to 32GB DDR4 SODIMM                       |  5 | 0.51%
# 8 GB LPDDR4                                  |  5 | 0.51%
# Up to 4 GB DDR2 SDRAM                        |  5 | 0.51%
# Up to 64GB DDR4 SODIMM                       |  5 | 0.51%
# 1 GB LPDDR4                                  |  5 | 0.51%
# Up to 8GB DDR3L SODIMM                       |  5 | 0.51%
# 4GB DDR3L                                    |  5 | 0.51%
# Up to 32 GByte DDR4 SODIMM                   |  5 | 0.51%
# DDR3 2GB                                     |  4 | 0.41%
# Up to 8GB LPDDR4                             |  4 | 0.41%
# 16GB DDR3L 1600MHz                           |  4 | 0.41%
# DDR4, up to 64GB                             |  4 | 0.41%
# LPDDR4 8GB                                   |  4 | 0.41%
# Dual Channel Non-ECC DDR4, Max Capacity 64GB |  4 | 0.41%
# DDR 333 MHz, Max Capacity 1 GB               |  4 | 0.41%
# 2 GB DDR3                                    |  4 | 0.41%
# Up to 64 GByte DDR4 SODIMM                   |  4 | 0.41%
# 2GB DDR3                                     |  4 | 0.41%
# 1GB DDR3                                     |  3 | 0.31%
# Up to 4GB LPDDR4                             |  3 | 0.31%
# 2 GB DDR2 SDRAM                              |  3 | 0.31%
# Up to 4 GB LPDDR4                            |  3 | 0.31%
# 32GB DDR4 2133MHz SDRAM                      |  3 | 0.31%
# Supports up to 32 GB DDR3                    |  3 | 0.31%
# 16GB DDR4 ECC                                |  3 | 0.31%
# 4 GB DDR3 1600 MHz                           |  3 | 0.31%
# 512K SRAM                                    |  3 | 0.31%
# 64GB DDR4 SODIMM                             |  3 | 0.31%
# 1 GB RAM                                     |  3 | 0.31%
# Up to 8 GB LPDDR4X RAM                       |  3 | 0.31%
# 64GB DDR4                                    |  3 | 0.31%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# ONBOARD_STORAGE (Total unique values: 508)
# ----------------------------------------------------------------------------------------------------
# mSATA                                                      | 43 | 4.39%
# 16 GB eMMC                                                 | 35 | 3.58%
# 64GB eMMC                                                  | 30 | 3.06%
# Up to 64GB eMMC                                            | 20 | 2.04%
# 16GB eMMC                                                  | 17 | 1.74%
# 8 GB eMMC                                                  | 16 | 1.63%
# eMMC                                                       | 15 | 1.53%
# 64 GB eMMC                                                 | 13 | 1.33%
# Optional NVMe SSD                                          | 12 | 1.23%
# 32 GB eMMC                                                 | 10 | 1.02%
# 8GB eMMC                                                   |  9 | 0.92%
# 8 GB eMMC NAND Flash                                       |  8 | 0.82%
# CompactFlash Type III                                      |  8 | 0.82%
# CompactFlash socket                                        |  7 | 0.72%
# 32Gb/s M.2                                                 |  7 | 0.72%
# Up to 64 GByte eMMC                                        |  7 | 0.72%
# mSATA support                                              |  6 | 0.61%
# 128 GB eMMC flash                                          |  6 | 0.61%
# 32GB eMMC                                                  |  6 | 0.61%
# Micro SD card slot                                         |  5 | 0.51%
# Up to 64 GB eMMC                                           |  5 | 0.51%
# eMMC 64GB                                                  |  5 | 0.51%
# eMMC up to 64GB                                            |  5 | 0.51%
# 64 GB eMMC, 128 GB M.2 SSD                                 |  5 | 0.51%
# NVMe SSD                                                   |  5 | 0.51%
# Optional eMMC                                              |  5 | 0.51%
# non-volatile User Data Storage                             |  5 | 0.51%
# eMMC 8GB                                                   |  4 | 0.41%
# Up to 1 TByte NVMe SSD                                     |  4 | 0.41%
# 4 GB eMMC NAND Flash                                       |  4 | 0.41%
# Supports mSATA                                             |  4 | 0.41%
# mSATA supported                                            |  4 | 0.41%
# eMMC, Optional SSD                                         |  4 | 0.41%
# eMMC 5.0 high-speed drive 32GB soldered on board           |  4 | 0.41%
# 32 GBytes eMMC                                             |  3 | 0.31%
# 64 GBytes eMMC                                             |  3 | 0.31%
# Eight SATA 3 and one M.2 connectors (SATA/PCIe compatible) |  3 | 0.31%
# 16 GBytes eMMC                                             |  3 | 0.31%
# 8GB, 16GB, 32GB, 64GB or 128GB eMMC flash                  |  3 | 0.31%
# Optional eMMC 5.1 on board mass storage                    |  3 | 0.31%
# Non-volatile User Data Storage                             |  3 | 0.31%
# NVMe, up to 256GB (Optional)                               |  3 | 0.31%
# MicroSD card slot                                          |  3 | 0.31%
# CFast, mSATA                                               |  3 | 0.31%
# Onboard flash (Optional, MLC up to 64GB, SLC up to 32GB)   |  3 | 0.31%
# eMMC 32GB                                                  |  3 | 0.31%
# 8GB, 16GB, 32GB eMMC                                       |  3 | 0.31%
# 64GB SSD                                                   |  3 | 0.31%
# Supports mSATA and SATA HDD                                |  3 | 0.31%
# 128 GB mSATA SSD                                           |  2 | 0.20%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# INPUT_VOLTAGE (Total unique values: 137)
# ----------------------------------------------------------------------------------------------------
# 12V                                         | 308 | 31.46%
# 5V                                          | 144 | 14.71%
# 12V DC                                      | 103 | 10.52%
# 12 VDC                                      |  34 | 3.47%
# 5V DC                                       |  28 | 2.86%
# 24 V DC                                     |  15 | 1.53%
# 12 V                                        |  14 | 1.43%
# 9-36 VDC                                    |  12 | 1.23%
# 5 VDC                                       |  12 | 1.23%
# 3.3V                                        |  12 | 1.23%
# 8-60 VDC                                    |  12 | 1.23%
# 5 V                                         |  11 | 1.12%
# 12 V DC                                     |  11 | 1.12%
# 12VDC                                       |  10 | 1.02%
# 5 V DC                                      |   8 | 0.82%
# 100-240V AC                                 |   8 | 0.82%
# 9-36V DC                                    |   8 | 0.82%
# 3.3 V                                       |   7 | 0.72%
# 12V DC-in                                   |   7 | 0.72%
# +12V/+5V/+3.3V/+5Vsb/-12V/12V_8P            |   6 | 0.61%
# ATX                                         |   6 | 0.61%
# 12-24 V DC                                  |   5 | 0.51%
# 19V                                         |   5 | 0.51%
# 100-240 VAC                                 |   4 | 0.41%
# ATX power supply                            |   4 | 0.41%
# 5V, 5VSB                                    |   4 | 0.41%
# 12-24 VDC                                   |   4 | 0.41%
# 8-30 V DC                                   |   4 | 0.41%
# 12-24V DC                                   |   3 | 0.31%
# 5V, 12V option                              |   3 | 0.31%
# 24 VDC                                      |   3 | 0.31%
# 5V, 12V, 3.3V, 5VSB                         |   3 | 0.31%
# 9-36 V DC                                   |   3 | 0.31%
# DC 9-36V                                    |   3 | 0.31%
# +5V                                         |   3 | 0.31%
# 5V, 12V                                     |   3 | 0.31%
# 5V/12V                                      |   2 | 0.20%
# 5V-20V                                      |   2 | 0.20%
# 3.3V, 5V                                    |   2 | 0.20%
# +12 V/+5 V/+3.3 V/+5 VSB/V12_8P/-12 V       |   2 | 0.20%
# 3.3 V, 5 V, 12 V, 5 Vsb                     |   2 | 0.20%
# ATX/AT power supply                         |   2 | 0.20%
# AC                                          |   2 | 0.20%
# 12V to 24V                                  |   2 | 0.20%
# 100-240VAC                                  |   2 | 0.20%
# 3.3V/5V/5Vsb/12V/12V_8P                     |   2 | 0.20%
# ATX 12V                                     |   2 | 0.20%
# +12V/+5V/+3.3V/+5Vsb/-12V/12V_8P_0/12V_8P_1 |   2 | 0.20%
# 12V, 5V, 3.3V, 5VSB                         |   2 | 0.20%
# 12V - 24V DC                                |   2 | 0.20%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# IO_COUNT (Total unique values: 885)
# ----------------------------------------------------------------------------------------------------
# ['Not Available']                                                                                                              | 68 | 6.95%
# ['PCIe, USB, SATA, Ethernet']                                                                                                  |  5 | 0.51%
# ['Multiple I/Os including PCIe4, USB3.2, and 10GBase-KR']                                                                      |  4 | 0.41%
# ['2 x DP, 4 x USB, 2 x COM ports, 2 x Ethernet']                                                                               |  4 | 0.41%
# ['Multiple USB, PCIe, SATA, Ethernet']                                                                                         |  4 | 0.41%
# ['PCIe, SATA, USB, Ethernet']                                                                                                  |  3 | 0.31%
# ['4x USB', '2x LAN', '2x DisplayPort', '1x Audio In/Out', '1x PCIe x4', '1x PCIe x1']                                          |  2 | 0.20%
# ['8 x USB 2.0, 8-bit GPIO']                                                                                                    |  2 | 0.20%
# ['USB 3.2 Gen 2 x 4', 'USB 2.0 x 2', 'HDMI x 1', 'DP x 1', 'eDP x 1', 'Ethernet x 2']                                          |  2 | 0.20%
# ['103 GPIOs']                                                                                                                  |  2 | 0.20%
# ['Multiple interfaces including Ethernet, USB, UART, SDIO']                                                                    |  2 | 0.20%
# ['12 USB ports, 2 UART ports']                                                                                                 |  2 | 0.20%
# ['48x GPIO']                                                                                                                   |  2 | 0.20%
# ['22']                                                                                                                         |  2 | 0.20%
# ['PCIe x16, USB 3.2 Gen 2, SATA III, Gigabit Ethernet']                                                                        |  2 | 0.20%
# ['VGA', 'HDMI', 'USB 3.1 Gen 1', 'Ethernet', 'Serial Port RS232', 'Audio jack', 'PS/2 Keyboard Port', 'PS/2 Mouse Port']       |  2 | 0.20%
# ['Quad GbE, PCIe, SATA, USB']                                                                                                  |  2 | 0.20%
# ['VGA, USB']                                                                                                                   |  2 | 0.20%
# ['Ethernet, USB, UART, SPI, I2C, PWM, SAI, CAN']                                                                               |  1 | 0.10%
# ['2x USB, 2x COM ports, Audio, HDMI, VGA, Ethernet']                                                                           |  1 | 0.10%
# ['Two USB ports, four USB host ports, two SATA ports, two Gigabit Ethernet ports']                                             |  1 | 0.10%
# ['HDMI', 'USB', 'CSI', 'DSI', 'Ethernet', 'Micro SD Card']                                                                     |  1 | 0.10%
# ['19 Digital I/O Pins']                                                                                                        |  1 | 0.10%
# ['8 GPIO, 2 COM Ports, 4 USB3.0, 8 USB2.0']                                                                                    |  1 | 0.10%
# ['4 x USB', '2 x RS-232', '2 x RS-485', '2 x HDMI', '1 x VGA', '2 x GbE LAN']                                                  |  1 | 0.10%
# ['CRT, DVI-D, USB, Audio, Mic-in, Line-out, Serial RS-232, FDD, PS/2 keyboard, PS/2 mouse']                                    |  1 | 0.10%
# ['Rich interfaces']                                                                                                            |  1 | 0.10%
# ['Multiple I/O ports including USB, HDMI, RS485, RS232']                                                                       |  1 | 0.10%
# ['HDMI, USB, Ethernet, Micro SD, GPIO']                                                                                        |  1 | 0.10%
# ['2 x USB', '1 x Ethernet', '2 x Camera Interfaces', '1 x PCIe', '1 x SATA', '1 x LVDS']                                       |  1 | 0.10%
# ['4 USB 3.1 Gen 1', '2 HDMI', '2 GbE LAN', '4 RS232', 'Audio: Mic-in, Line-out']                                               |  1 | 0.10%
# ['HDMI 2.0b', 'DP 1.2', 'USB 3.2 Gen 1 Type A', 'USB 3.2 Gen 1 Type C', 'GPIO 40-pin', 'SATA III', 'GbE LAN']                  |  1 | 0.10%
# ['HDMI', 'Dual Channel 24-bit LVDS', 'CAN', 'UART', 'I2C', 'GPIO', 'USB', 'SDIO', 'SATA II', 'PCIe x1 Gen2']                   |  1 | 0.10%
# ['USB 3.2 Gen 1', 'USB 2.0', 'SATA III', 'PCIe x16', 'PCIe x8', 'PCIe x4', 'RJ45 LAN', 'HDMI', 'VGA', 'DVI-D']                 |  1 | 0.10%
# ['COM ports, USB ports, Ethernet, VGA, DP, LVDS']                                                                              |  1 | 0.10%
# ['PCIe, GbE, CAN Bus, SPI, GPIOs, UART, I2C, USB']                                                                             |  1 | 0.10%
# ['USB: 6, SATA II: 2, COM: 6, Mini PCIE: 2']                                                                                   |  1 | 0.10%
# ['SPI, I2C, UART, HDMI, USB, LVDS, SPDIF, Audio Jack, CSI, DSI']                                                               |  1 | 0.10%
# ['85']                                                                                                                         |  1 | 0.10%
# ['2 SATA, 4 USB, 4 COM, 2 LAN']                                                                                                |  1 | 0.10%
# ['4 USB ports', '2 COM ports', '2 SATA ports', '1 VGA', '1 LVDS']                                                              |  1 | 0.10%
# ['2x HDMI', '1x LVDS', '1x iDP', '2x PCIe GbE', '4x USB 3.1 Gen 1', '2x SATA 6Gb/s', '2x RS-232', '1x RS-422/485', '1x Audio'] |  1 | 0.10%
# ['USB', 'PCIe', 'SATA', 'Ethernet', 'CANFD', 'UART', 'HDMI', 'LVDS', 'MIPI DSI', 'RGB', 'eDP']                                 |  1 | 0.10%
# ['4x USB 3.2 Gen 2', '8x USB 2.0', '2x SATA III', '1x PCIe Gen 3 x4', '1x PCIe Gen 3 x8', '1x PCIe Gen 3 x16']                 |  1 | 0.10%
# ['2 x DP', '4 x USB', '2 x COM ports', '1 x Ethernet']                                                                         |  1 | 0.10%
# ['Multiple USB, VGA, COM Ports']                                                                                               |  1 | 0.10%
# ['Multiple interfaces including USB, Ethernet, SPI, UART']                                                                     |  1 | 0.10%
# ['Multiple I/O including USB, PCIe, UART, SPI, I2C, CAN']                                                                      |  1 | 0.10%
# ['214 PS I/O']                                                                                                                 |  1 | 0.10%
# ['10 USB ports', '2 Serial ports', 'Dual GbE LAN', 'PCIe x16 slot']                                                            |  1 | 0.10%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# WIRELESS (Total unique values: 421)
# ----------------------------------------------------------------------------------------------------
# Wi-Fi, Bluetooth                                                                | 35 | 3.58%
# ['Wi-Fi', 'Bluetooth']                                                          | 30 | 3.06%
# Wi-Fi                                                                           | 15 | 1.53%
# WiFi, Bluetooth                                                                 | 13 | 1.33%
# WiFi                                                                            | 12 | 1.23%
# 802.11 a/b/g/n/ac+BT5.0                                                         |  9 | 0.92%
# 5G connectivity                                                                 |  7 | 0.72%
# Wi-Fi, Bluetooth, Cellular                                                      |  6 | 0.61%
# M.2 E key for wireless                                                          |  6 | 0.61%
# Wi-Fi, Bluetooth, GSM                                                           |  6 | 0.61%
# Supports WiFi modems                                                            |  6 | 0.61%
# Wi-Fi/Bluetooth, 3g and GPS                                                     |  5 | 0.51%
# Dual GbE & wireless connectivity                                                |  5 | 0.51%
# ['WiFi', 'Bluetooth', 'Cellular']                                               |  5 | 0.51%
# ['Wi-Fi a/b/g/n/ac', 'Bluetooth']                                               |  5 | 0.51%
# SMARC 2.0 modules support wireless technologies including WLAN and Bluetooth    |  4 | 0.41%
# Intel AC9260 dual band 802.11AC 2*2 WiFi/BT5.0                                  |  4 | 0.41%
# Wi-Fi and Bluetooth module support                                              |  4 | 0.41%
# Wi-Fi, Bluetooth, Cellular Socket                                               |  4 | 0.41%
# ['WiFi', 'Bluetooth']                                                           |  4 | 0.41%
# Wireless I/O & Sensors                                                          |  4 | 0.41%
# Wi-Fi 6E                                                                        |  3 | 0.31%
# Support for wireless technologies including WLAN and Bluetooth                  |  3 | 0.31%
# ['Wi-Fi', 'Bluetooth', 'LTE']                                                   |  3 | 0.31%
# Dual-band 2.4GHz and 5GHz IEEE 802.11.b/g/n/ac wireless LAN, Bluetooth 5.0, BLE |  3 | 0.31%
# 802.11 a/b/g/n/ac + BT 4.2                                                      |  3 | 0.31%
# WiFi 6E                                                                         |  3 | 0.31%
# Optional Wi-Fi module                                                           |  3 | 0.31%
# 802.11 b/g/n                                                                    |  3 | 0.31%
# Optional wireless connectivity                                                  |  3 | 0.31%
# Wi-Fi/Bluetooth                                                                 |  3 | 0.31%
# Supports NGFF WiFi/BT                                                           |  3 | 0.31%
# Bluetooth, WiFi                                                                 |  3 | 0.31%
# M.2 E-Key for wireless module                                                   |  3 | 0.31%
# Wireless Medical Automation                                                     |  2 | 0.20%
# Supports Wi-Fi modems via Mini PCIe socket                                      |  2 | 0.20%
# Dual-band 2.4GHz and 5GHz IEEE 802.11b/g/n/ac wireless LAN, Bluetooth 5.0, BLE  |  2 | 0.20%
# Wi-Fi 6E with Bluetooth                                                         |  2 | 0.20%
# 1 x M.2 E key for wireless                                                      |  2 | 0.20%
# WiFi/BT Module                                                                  |  2 | 0.20%
# Wi-Fi and Bluetooth modules via PCIe interfaces                                 |  2 | 0.20%
# ['WiFi 6 (802.11ax)', 'Dual-Mode Bluetooth', '5G', 'LoRa', 'Zigbee']            |  2 | 0.20%
# Wi-Fi b/g/n, Bluetooth                                                          |  2 | 0.20%
# Wireless Modules                                                                |  2 | 0.20%
# Yes                                                                             |  2 | 0.20%
# ['Wi-Fi', 'Bluetooth', 'Optional GPS']                                          |  2 | 0.20%
# 802.11 a/b/g/n/ac, Bluetooth 4.1                                                |  2 | 0.20%
# WiFi Module 802.11 a/b/g/n/ac 2T2R w/BT5.1, Intel AC9260                        |  2 | 0.20%
# WiFi 6 (802.11ax)                                                               |  2 | 0.20%
# Wi-Fi IEEE 802.11 a/b/g/n/ac, Bluetooth                                         |  2 | 0.20%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# OPERATING_SYSTEM_BSP (Total unique values: 478)
# ----------------------------------------------------------------------------------------------------
# Linux                                                                                                                | 32 | 3.27%
# ['Linux', 'Android']                                                                                                 | 30 | 3.06%
# ['Windows', 'Linux']                                                                                                 | 29 | 2.96%
# ['Linux']                                                                                                            | 16 | 1.63%
# Windows                                                                                                              | 15 | 1.53%
# ['Windows', 'Linux', 'VxWorks']                                                                                      | 14 | 1.43%
# ['Windows', 'Windows Embedded', 'Linux', 'VxWorks', 'QNX']                                                           | 12 | 1.23%
# ['Windows 10', 'Linux']                                                                                              | 12 | 1.23%
# Windows, Linux                                                                                                       | 10 | 1.02%
# Raspberry Pi OS                                                                                                      | 10 | 1.02%
# ['Windows XP Embedded', 'Windows Embedded Standard']                                                                 |  9 | 0.92%
# Win10/Ubuntu                                                                                                         |  8 | 0.82%
# Yocto Linux                                                                                                          |  8 | 0.82%
# ['Windows 10', 'Ubuntu']                                                                                             |  8 | 0.82%
# Windows 10 64-bit                                                                                                    |  7 | 0.72%
# Windows IoT Enterprise LTSC                                                                                          |  7 | 0.72%
# ['Raspberry Pi OS Desktop 32-bit', 'Raspberry Pi OS Lite 32-bit']                                                    |  6 | 0.61%
# Windows 10                                                                                                           |  6 | 0.61%
# ['Windows Embedded Standard', 'Linux']                                                                               |  6 | 0.61%
# Embedded OS                                                                                                          |  6 | 0.61%
# ['Windows', 'Windows Embedded', 'Linux', 'VxWorks']                                                                  |  6 | 0.61%
# ['Microsoft Windows 10', 'Microsoft Windows IoT Enterprise', 'Linux']                                                |  5 | 0.51%
# ['Windows 10 IoT Enterprise']                                                                                        |  5 | 0.51%
# ['Microsoft Windows', 'Linux']                                                                                       |  5 | 0.51%
# ['Windows 10 IoT Enterprise', 'Linux']                                                                               |  5 | 0.51%
# ['Debian', 'Android']                                                                                                |  5 | 0.51%
# ['Windows 10', 'Ubuntu 20.04', 'Yocto']                                                                              |  5 | 0.51%
# ['Android', 'Linux']                                                                                                 |  5 | 0.51%
# ['Windows 10 IoT', 'Linux']                                                                                          |  4 | 0.41%
# ['Windows 10', 'Linux Ubuntu']                                                                                       |  4 | 0.41%
# Without operating system                                                                                             |  4 | 0.41%
# ['Windows 10', 'Windows 7']                                                                                          |  4 | 0.41%
# ESP-IDF                                                                                                              |  4 | 0.41%
# Windows 10 and Linux                                                                                                 |  4 | 0.41%
# WES7                                                                                                                 |  4 | 0.41%
# ['Windows Embedded Standard', 'VxWorks', 'Linux Ubuntu']                                                             |  4 | 0.41%
# Ubuntu Linux                                                                                                         |  4 | 0.41%
# DYNAMIC C                                                                                                            |  4 | 0.41%
# ['Windows', 'QNX', 'VxWorks', 'Linux']                                                                               |  4 | 0.41%
# ['Linux', 'Windows IoT']                                                                                             |  4 | 0.41%
# Win10 IoT Ent_LTSB 64 bit                                                                                            |  3 | 0.31%
# Windows 10 64-bit, Linux: Ubuntu                                                                                     |  3 | 0.31%
# ['WES7', 'WE8S']                                                                                                     |  3 | 0.31%
# ['Windows Embedded', 'Linux', 'VxWorks']                                                                             |  3 | 0.31%
# ['Microsoft Windows', 'Linux', 'Android', 'Yocto']                                                                   |  3 | 0.31%
# ['Windows Starter', 'Home Basic', 'Home Premium', 'MeeGO', 'Linux', 'Google Chrome']                                 |  3 | 0.31%
# Microsoft Windows, Linux                                                                                             |  3 | 0.31%
# ThinManager                                                                                                          |  3 | 0.31%
# ['Microsoft Windows', 'Microsoft Windows IoT Enterprise', 'Microsoft Windows IoT Core', 'Linux', 'Android', 'Yocto'] |  3 | 0.31%
# Linux, Windows 10                                                                                                    |  3 | 0.31%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# OPERATING_TEMPERATURE_MAX (Total unique values: 48)
# ----------------------------------------------------------------------------------------------------
# 60°C               | 451 | 46.07%
# 85°C               | 279 | 28.50%
# 70°C               |  38 | 3.88%
# 60 C               |  35 | 3.58%
# 85 C               |  27 | 2.76%
# 85C                |  14 | 1.43%
# 40°C               |  13 | 1.33%
# 50°C               |  13 | 1.33%
# +85°C              |   7 | 0.72%
# 60° C              |   7 | 0.72%
# 70 C               |   7 | 0.72%
# 75°C               |   6 | 0.61%
# 60C                |   6 | 0.61%
# 85 °C              |   5 | 0.51%
# 50 C               |   4 | 0.41%
# 70C                |   4 | 0.41%
# 35°C               |   3 | 0.31%
# 60 °C              |   3 | 0.31%
# +85C               |   3 | 0.31%
# 55 C               |   3 | 0.31%
# 125°C              |   2 | 0.20%
# 85℃                |   2 | 0.20%
# 100°C              |   2 | 0.20%
# +60°C              |   2 | 0.20%
# 125 °C             |   2 | 0.20%
# +85° C             |   2 | 0.20%
# 105°C              |   2 | 0.20%
# 40 °C              |   2 | 0.20%
# 85°C (185°F)       |   1 | 0.10%
# 50 degrees Celsius |   1 | 0.10%
# 85 oC              |   1 | 0.10%
# +85 C              |   1 | 0.10%
# 70° C              |   1 | 0.10%
# 95°C               |   1 | 0.10%
# 158°F (70°C)       |   1 | 0.10%
# 70 °C              |   1 | 0.10%
# 85 degrees Celsius |   1 | 0.10%
# +70 °C             |   1 | 0.10%
# 55°C               |   1 | 0.10%
# +70°C              |   1 | 0.10%
# +80°C              |   1 | 0.10%
# 90°C               |   1 | 0.10%
# +65°C              |   1 | 0.10%
# 45°C               |   1 | 0.10%
# +80℃               |   1 | 0.10%
# 105C               |   1 | 0.10%
# 83°C               |   1 | 0.10%
# 70℃                |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# OPERATING_TEMPERATURE_MIN (Total unique values: 27)
# ----------------------------------------------------------------------------------------------------
# 0°C               | 327 | 33.40%
# -40°C             | 326 | 33.30%
# -20°C             | 139 | 14.20%
# -40 C             |  31 | 3.17%
# 0 C               |  21 | 2.15%
# -20 C             |  21 | 2.15%
# -40C              |  16 | 1.63%
# -25°C             |  15 | 1.53%
# 0C                |   9 | 0.92%
# -30°C             |   8 | 0.82%
# -40 °C            |   8 | 0.82%
# 0° C              |   8 | 0.82%
# 0 °C              |   5 | 0.51%
# -10°C             |   5 | 0.51%
# -40℃              |   3 | 0.31%
# -10 C             |   2 | 0.20%
# 0 degrees Celsius |   2 | 0.20%
# 5°C               |   2 | 0.20%
# -40° C            |   2 | 0.20%
# -25C              |   2 | 0.20%
# -30 C             |   2 | 0.20%
# -10 °C            |   1 | 0.10%
# -40°C (-40°F)     |   1 | 0.10%
# -40 oC            |   1 | 0.10%
# -20C              |   1 | 0.10%
# 32°F (0°C)        |   1 | 0.10%
# -20℃              |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# CERTIFICATIONS (Total unique values: 353)
# ----------------------------------------------------------------------------------------------------
# CE, FCC                                              | 40 | 4.09%
# RoHS                                                 | 34 | 3.47%
# ['CE', 'FCC']                                        | 27 | 2.76%
# CE/FCC                                               | 22 | 2.25%
# ['CE', 'FCC Class B']                                | 20 | 2.04%
# ['CE', 'FCC', 'RoHS']                                | 13 | 1.33%
# RoHS COMPLIANT                                       | 12 | 1.23%
# ['CE', 'FCC', 'UL', 'CCC', 'BSMI']                   | 10 | 1.02%
# FCC Class B                                          | 10 | 1.02%
# ['RoHS', 'CE', 'FCC Class B']                        | 10 | 1.02%
# RoHS COMPLIANT 2002/95/EC                            | 10 | 1.02%
# CE/FCC Class B                                       | 10 | 1.02%
# CE                                                   |  9 | 0.92%
# ['IEC 60068-2-27', 'IEC 60068-2-64', 'MIL-STD-810F'] |  9 | 0.92%
# CE, FCC Class B                                      |  9 | 0.92%
# ['CE', 'FCC Class B', 'RoHS COMPLIANT']              |  8 | 0.82%
# FCC Part 15                                          |  8 | 0.82%
# FCC Class A                                          |  8 | 0.82%
# Modular compliance certification                     |  8 | 0.82%
# ['RoHS']                                             |  8 | 0.82%
# ['CE', 'FCC Class A']                                |  8 | 0.82%
# CE/FCC Class A                                       |  7 | 0.72%
# MIL-STD-810G                                         |  7 | 0.72%
# RoHS compliant                                       |  7 | 0.72%
# ['CE', 'FCC Class A', 'CCC', 'BSMI', 'UL']           |  5 | 0.51%
# ['CE', 'FCC', 'EAC', 'RoHS', 'UL', 'cUL']            |  5 | 0.51%
# IPC-A-610G Class 3                                   |  5 | 0.51%
# RoHS Compliant                                       |  5 | 0.51%
# ['CE Class B', 'FCC Class B']                        |  5 | 0.51%
# FCC, CE                                              |  5 | 0.51%
# FCC                                                  |  5 | 0.51%
# MIL-STD-810G compliance                              |  5 | 0.51%
# EN50155, EN45545, E-mark                             |  5 | 0.51%
# CE, FCC Class A                                      |  4 | 0.41%
# DIN EN ISO 9001                                      |  4 | 0.41%
# Class I, Division 2 (CID2) & ATEX Solutions          |  4 | 0.41%
# ['RoHS', 'REACH']                                    |  4 | 0.41%
# EMC CE, FCC                                          |  3 | 0.31%
# ['FCC', 'CE']                                        |  3 | 0.31%
# ['CE', 'FCC Class A', 'CCC', 'BSMI', 'CB', 'UL']     |  3 | 0.31%
# ['CE', 'FCC Class B', 'RoHS Compliant']              |  3 | 0.31%
# RoHS Compliance                                      |  3 | 0.31%
# RoHS, CE, FCC Class B                                |  3 | 0.31%
# FCC, China RoHS                                      |  3 | 0.31%
# ['CE', 'FCC', 'UL', 'CB', 'CCC', 'BSMI']             |  3 | 0.31%
# ['RoHS', 'REACH', 'PICMG COM Express R2.1']          |  3 | 0.31%
# AEC-Q100                                             |  3 | 0.31%
# ['RoHS', 'MIL-STD-810H']                             |  3 | 0.31%
# IEC-60068-2, IPC-A-610                               |  3 | 0.31%
# ['RoHS', 'CE']                                       |  2 | 0.20%
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# ### 2.1 Name

# %% [markdown]
# This cleaning process will:
# - Convert all names to uppercase.
# - Remove extra spaces.
# - Remove common suffixes that don't add much distinguishing information.
# - Standardize common terms and abbreviations.
# - Remove parentheses and their contents.
# - Remove any remaining non-alphanumeric characters except hyphens and spaces.
# - Remove any extra spaces that might have been introduced during the cleaning process.

# %%
def clean_product_name(name):
    # Convert to uppercase
    name = name.upper()

    # Remove extra spaces
    name = " ".join(name.split())

    # Remove common suffixes
    suffixes_to_remove = [
        " MODULE",
        " BOARD",
        " COMPUTER",
        " SERIES",
        " MOTHERBOARD",
        " CPU",
        " SINGLE",
        " DEVELOPMENT KIT",
        " DEVELOPMENT",
        " PLATFORM",
        " SYSTEM",
    ]
    for suffix in suffixes_to_remove:
        if name.endswith(suffix):
            name = name[: -len(suffix)]

    # Standardize common prefixes and mid-string occurrences
    replacements = {
        "COM EXPRESS": "COM-EXPRESS",
        "RASPBERRY PI": "RASPBERRY-PI",
        "COMPUTER ON": "COM",
        "TX COMPUTER ON": "TX COM",
        "ICES COM EXPRESS": "ICES COM-EXPRESS",
        "SYSTEM ON": "SOM",
        "COMPUTER-ON-MODULE": "COM",
        "MINI ITX": "MINI-ITX",
        "PICO ITX": "PICO-ITX",
        "MICRO ITX": "MICRO-ITX",
        "NANO ITX": "NANO-ITX",
        "QSEVEN": "Q7",
        "IMXM": "IMX-M",
        "IMX M": "IMX-M",
        "IMXUL": "IMX-UL",
        "IMX UL": "IMX-UL",
    }
    for old, new in replacements.items():
        name = name.replace(old, new)

    # Remove parentheses and their contents
    name = re.sub(r"\([^)]*\)", "", name)

    # Remove any remaining non-alphanumeric characters except hyphen and space
    name = re.sub(r"[^A-Z0-9\- ]", "", name)

    # Remove extra spaces again (in case any were introduced)
    name = " ".join(name.split())

    return name


# Apply the cleaning function
original_unique = df["name"].nunique()
df["name"] = df["name"].apply(clean_product_name)
cleaned_unique = df["name"].nunique()

# Compare the number of unique values before and after cleaning
print(f"\nOriginal unique names: {original_unique}")
print(f"Cleaned unique names: {cleaned_unique}")
print(f"Reduction: {original_unique - cleaned_unique} ({((original_unique - cleaned_unique) / original_unique) * 100:.2f}%)")

df["name"].value_counts().head(20)
# Out:
# Original unique names: 677
# Cleaned unique names: 671
# Reduction: 6 (0.89%)
# name
# AIMB                    47
# SOM                     20
# ASMB                    12
# PCM                     12
# ARK                     11
# MIO                     10
# RSB                      9
# RASPBERRY-PI MODEL B     7
# VENICE GW                7
# AIMB-275                 7
# EDHMIC                   6
# COM-EXPRESS COMPACT      6
# COM-EXPRESS BASIC        6
# TREK                     6
# MIC                      6
# EMETXEI                  5
# PCA                      5
# UNOG                     5
# AIMB-580                 5
# CONGATC                  5
# Name: count, dtype: int64

# %% [markdown]
# ### 2.2 Manufacturer

# %% [markdown]
# This cleaning process will:
# - Convert all manufacturer names to uppercase.
# - Remove extra spaces.
# - Standardize common variations of the same manufacturer (e.g., combining "ADLINK TECHNOLOGY INC" and "ADLINK" into "ADLINK TECHNOLOGY").

# %%
def clean_manufacturer(value):
    if isinstance(value, str):
        # Convert to uppercase
        value = value.upper()

        # Remove extra spaces
        value = " ".join(value.split())

        # Standardize common names
        replacements = {
            "ADLINK TECHNOLOGY INC": "ADLINK TECHNOLOGY",
            "ADLINK": "ADLINK TECHNOLOGY",
            "IWAVE SYSTEMS TECHNOLOGIES": "IWAVE SYSTEMS",
            "IWAVE SYSTEMS TECHNOLOGIES PVT LTD": "IWAVE SYSTEMS",
            "IWAVE SYSTEMS TECH": "IWAVE SYSTEMS",
            "SOLIDRUN LTD": "SOLIDRUN",
            "IBASE TECHNOLOGY": "IBASE",
            "RASPBERRY PI TRADING LTD": "RASPBERRY PI",
            "RASPBERRY PI LTD": "RASPBERRY PI",
            "RASPBERRY PI FOUNDATION": "RASPBERRY PI",
            "CONGATEC GMBH": "CONGATEC",
            "CONGATEC AG": "CONGATEC",
            "VERSALOGIC CORPORATION": "VERSALOGIC",
            "DIGI INTERNATIONAL INC": "DIGI INTERNATIONAL",
            "KARO ELECTRONICS GMBH": "KARO ELECTRONICS",
            "FORLINX EMBEDDED TECHNOLOGY CO LTD": "FORLINX EMBEDDED TECHNOLOGY",
            "SHANGHAI EDA TECHNOLOGY CO LTD": "EDA TECHNOLOGY",
            "ESPRESSIF SYSTEMS": "ESPRESSIF",
            "SEEED STUDIO": "SEEEDSTUDIO",
            "ADVANTECH CO LTD": "ADVANTECH",
            "ADVANTECH INNOCORE": "ADVANTECH",
            "INTRINSYC TECHNOLOGIES CORPORATION": "INTRINSYC TECHNOLOGIES",
            "INTRINSYC TECHNOLOGIES CORP": "INTRINSYC TECHNOLOGIES",
            "SECO SPA": "SECO",
            "KUNBUS GMBH": "KUNBUS",
            "GATEWORKS CORPORATION": "GATEWORKS",
            "MYIR ELECTRONICS LIMITED": "MYIR ELECTRONICS",
            "ACURA EMBEDDED SYSTEMS INC": "ACURA EMBEDDED SYSTEMS",
            "WINSYSTEMS INC": "WINSYSTEMS",
            "AUVIDEA GMBH": "AUVIDEA",
            "MOXA INC": "MOXA",
        }

        for old, new in replacements.items():
            if value == old:
                return new

        return value
    return value


original_unique = df["manufacturer"].nunique()
df["manufacturer"] = df["manufacturer"].apply(clean_manufacturer)
cleaned_unique = df["manufacturer"].nunique()

print(f"\nOriginal unique manufacturers: {original_unique}")
print(f"Cleaned unique manufacturers: {cleaned_unique}")
print(f"Reduction: {original_unique - cleaned_unique} ({((original_unique - cleaned_unique) / original_unique) * 100:.2f}%)")

df["manufacturer"].value_counts()
# Out:
# Original unique manufacturers: 112
# Cleaned unique manufacturers: 88
# Reduction: 24 (21.43%)
# manufacturer
# ADVANTECH                        406
# IEI                               60
# CONGATEC                          50
# KONTRON                           37
# VERSALOGIC                        35
# ADLINK TECHNOLOGY                 29
# IBASE                             27
# ARBOR TECHNOLOGY                  25
# IWAVE SYSTEMS                     22
# RASPBERRY PI                      21
# SOLIDRUN                          19
# KARO ELECTRONICS                  17
# MYIR ELECTRONICS                  15
# AXIOMTEK                          14
# GATEWORKS                         12
# EUROTECH                          11
# PHOENIX CONTACT                   11
# EDA TECHNOLOGY CO LTD              9
# SECO                               9
# NEXCOBOT                           9
# DIGI INTERNATIONAL                 8
# GIGAIPC                            6
# FORLINX EMBEDDED TECHNOLOGY        6
# SEEEDSTUDIO                        6
# RADXA                              6
# ASUS                               6
# NVIDIA                             6
# AAEON                              5
# OLIMEX                             4
# ESPRESSIF                          4
# NXP                                4
# GOOGLE                             3
# KUNBUS                             3
# MIXTILE                            3
# D SYSTEMS                          3
# GUMSTIX                            3
# BOUNDARY DEVICES                   3
# ACURA EMBEDDED SYSTEMS             3
# INTEL                              3
# STARTECHCOM                        2
# BEACON EMBEDDEDWORKS               2
# MOXA                               2
# TOYBRICK                           2
# EDA TECHNOLOGY                     2
# NEXCOM                             2
# INTRINSYC TECHNOLOGIES             2
# NORDIC SEMICONDUCTOR               1
# AIM                                1
# MICROSOFT                          1
# SCIOSENSE                          1
# TRENZ ELECTRONIC                   1
# WWWRLC AI SOLUTION                 1
# UP BOARDS                          1
# CYPRESS SEMICONDUCTOR              1
# UDOO                               1
# SFERA LABS                         1
# HARTING                            1
# DIAMOND SYSTEMS                    1
# KNERON                             1
# AIC                                1
# MICROSYS INC                       1
# WINSYSTEMS                         1
# MASELETTRONICA                     1
# WANDBOARD ORG                      1
# STERICSSON                         1
# RABBIT SEMICONDUCTOR               1
# THE WESTERN DESIGN CENTER INC      1
# RABBIT                             1
# BLACK OAK ENGINEERING              1
# AUVIDEA                            1
# LANTRONIX                          1
# TECHNEXION                         1
# MICROSYS                           1
# FREEWAVE TECHNOLOGIES              1
# ZWORLD INC                         1
# SCHNEIDER ELECTRIC                 1
# JADAK                              1
# UNIGEN CORPORATION                 1
# NEX                                1
# PHYTEC                             1
# LAIRD CONNECTIVITY                 1
# FREESCALE                          1
# BLUETECHNIX                        1
# GHI ELECTRONICS                    1
# LOGIC                              1
# TEXAS INSTRUMENTS                  1
# CUBIETEAM                          1
# OKDO TECHNOLOGY                    1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.3 Form Factor

# %% [markdown]
# This cleaning process will:
# - Convert all form factors to uppercase.
# - Remove extra spaces.
# - Standardize common terms and variations.
# - Group similar form factors together.
# - Remove any remaining non-alphanumeric characters except hyphens and spaces.

# %%
def clean_form_factor(value):
    if not isinstance(value, str):
        return value

    # Convert to uppercase
    value = value.upper()

    # Remove extra spaces
    value = " ".join(value.split())

    # Standardize common terms
    replacements = {
        "MINI-ITX": "MINI-ITX",
        "MINI ITX": "MINI-ITX",
        "MINIITX": "MINI-ITX",
        "THIN MINI-ITX": "THIN MINI-ITX",
        "THIN MINIITX": "THIN MINI-ITX",
        "MICRO-ATX": "MICRO-ATX",
        "MICRO ATX": "MICRO-ATX",
        "MICROATX": "MICRO-ATX",
        "MATX": "MICRO-ATX",
        "PICO-ITX": "PICO-ITX",
        "PICO ITX": "PICO-ITX",
        "PICOITX": "PICO-ITX",
        "NANO-ITX": "NANO-ITX",
        "NANO ITX": "NANO-ITX",
        "NANOITX": "NANO-ITX",
        "COM EXPRESS": "COM EXPRESS",
        "COMEXPRESS": "COM EXPRESS",
        "COM-EXPRESS": "COM EXPRESS",
        "QSEVEN": "QSEVEN",
        "Q7": "QSEVEN",
        "SMARC": "SMARC",
        "SINGLE BOARD COMPUTER": "SBC",
        "SINGLEBOARD COMPUTER": "SBC",
        "SINGLE-BOARD COMPUTER": "SBC",
        "SINGLEBOARD": "SBC",
        "EMBEDDED SBC": "SBC",
        "SYSTEM ON MODULE": "SOM",
        "SYSTEM-ON-MODULE": "SOM",
        "SYSTEM MODULE": "SOM",
        "COMPUTER ON MODULE": "COM",
        "RASPBERRY PI": "RASPBERRY PI",
        "RASPBERRY PI COMPATIBLE": "RASPBERRY PI",
        "FANLESS BOX PC": "BOX PC",
        "FANLESS EMBEDDED BOX PC": "BOX PC",
        "EMBEDDED BOX PC": "BOX PC",
        "EMBEDDED BOX COMPUTER": "BOX PC",
        "BOX COMPUTER": "BOX PC",
        "FANLESS PC": "BOX PC",
        "FANLESS COMPACT SYSTEM": "BOX PC",
        "COMPACT EXPANDABLE FANLESS SYSTEM": "BOX PC",
        "DINRAIL": "DIN RAIL",
        "DIN RAIL MOUNTABLE": "DIN RAIL",
        "PICMG": "PICMG",
        "FULLSIZE PICMG": "PICMG FULLSIZE",
        "PICMG FULLSIZE CPU CARD": "PICMG FULLSIZE",
        "HALF-SIZE PICMG": "PICMG HALF-SIZE",
        "HALFSIZE PICMG": "PICMG HALF-SIZE",
        "COMPACTPCI": "COMPACT PCI",
        "MINI PCIE": "MINI PCIE",
        "HALF-SIZE": "HALF-SIZE",
        "HALFSIZE": "HALF-SIZE",
        "HALF SIZE": "HALF-SIZE",
        "ALL-IN-ONE": "ALL-IN-ONE",
        "RACKMOUNT": "RACKMOUNT",
        "U RACKMOUNT": "RACKMOUNT",
        "U RACKMOUNT CHASSIS": "RACKMOUNT",
        "EMBEDDED": "EMBEDDED",
        "EMBEDDED SYSTEM": "EMBEDDED",
        "EMBEDDED IPC": "EMBEDDED",
        "EMBEDDED MODULE": "EMBEDDED",
    }

    for old, new in replacements.items():
        if value == old or value.startswith(old + " "):
            return new

    # Remove any remaining non-alphanumeric characters except hyphen and space
    value = re.sub(r"[^A-Z0-9\- ]", "", value)

    return value


original_unique = df["form_factor"].nunique()
df["form_factor"] = df["form_factor"].apply(clean_form_factor)
cleaned_unique = df["form_factor"].nunique()

print(f"\nOriginal unique form factors: {original_unique}")
print(f"Cleaned unique form factors: {cleaned_unique}")
print(f"Reduction: {original_unique - cleaned_unique} ({((original_unique - cleaned_unique) / original_unique) * 100:.2f}%)")

df["form_factor"].value_counts()
# Out:
# Original unique form factors: 227
# Cleaned unique form factors: 140
# Reduction: 87 (38.33%)
# form_factor
# COM EXPRESS                         147
# SBC                                 133
# MINI-ITX                             76
# ATX                                  51
# SMARC                                40
# BOX PC                               38
# QSEVEN                               37
# MICRO-ATX                            35
# PICO-ITX                             35
# SOM                                  31
# RASPBERRY PI                         25
# SODIMM                               17
# DIN RAIL                             13
# EBX                                  12
# PCPLUS                               12
# EPIC                                 11
# EMBEDDED                             11
# HALF-SIZE                            11
# QFN                                  10
# ETX                                   9
# PICMG                                 9
# COM                                   8
# RACKMOUNT                             8
# ALL-IN-ONE                            8
# THIN MINI-ITX                         7
# COMPACT                               6
# MIO                                   6
# PROPRIETARY                           6
# COMPACT PCI                           5
# REGULAR SIZE                          4
# PC104                                 4
# PC                                    4
# PALMSIZE                              4
# SLOT SBC                              4
# PANEL PC                              4
# PCI                                   3
# DEVELOPMENT BOARD                     3
# SMALL SIZE                            3
# MINI PCIE                             3
# COMPACT IN-VEHICLE COMPUTING BOX      3
# MICROSOM                              3
# DIGI SMTPLUS                          2
# SMALL ENCLOSURE                       2
# COMHPC                                2
# COMPACT VISION SYSTEM                 2
# MODULAR IPC                           2
# MXM                                   2
# COMHPC SIZE A                         2
# PCI-ISA                               2
# EPIC SBC                              2
# IN-VEHICLE SMART DISPLAY              2
# DESKTOP                               2
# RTX                                   2
# COMPACT KEYBOARD                      2
# OSM LGA                               2
# FULLSIZE                              2
# ISA HALF-SIZE SBC                     2
# PICMG FULLSIZE                        2
# ULTRASLIM                             2
# OPS                                   2
# EATX                                  2
# NANO-ITX                              2
# IN-VEHICLE COMPUTING BOX              1
# TABLET                                1
# MOBILE DATA TERMINAL                  1
# MICROPROCESSOR CORE MODULE            1
# COMPACT SBC                           1
# ARM BASED BOX COMPUTER                1
# PC HALF SIZE                          1
# MODULE                                1
# HIROSE DF CONNECTORS                  1
# SMALL FORM FACTOR                     1
# COM-ULTRA                             1
# RISC COMPACT BOX COMPUTER             1
# BGA                                   1
# U AI MODULAR BOX PC                   1
# FREESCALE TOWER                       1
# SUMIT                                 1
# PCIE                                  1
# DISK SIZE SBC                         1
# VESA                                  1
# COM HPC SIZE C                        1
# PALM-SIZE BOX                         1
# POCKET-SIZE                           1
# FANLESS BOX COMPUTER                  1
# ARDUINO ZERO COMPATIBLE               1
# DEVELOPER BOARD                       1
# DIP                                   1
# 1U RACKMOUNT                          1
# COMHPC SIZE D                         1
# FANLESS CUBE                          1
# POCKET SIZE                           1
# PC PLUS                               1
# ARDUINO COMPATIBLE                    1
# SMALL SIZE ENCLOSURE                  1
# INTELLIGENT DISPLAY MODULE            1
# OSM                                   1
# PC FORMAT                             1
# OPEN Q SYSTEM MODULE                  1
# COM-HPC                               1
# PICO                                  1
# BOARD LEVEL UNIT                      1
# MODULAR                               1
# MODULAR BOX                           1
# COMPACT SYSTEM                        1
# PICMG HALF-SIZE                       1
# RUGGEDIZED DESIGN                     1
# DIGITAL SIGNAGE PLATFORM              1
# PCI MODULE                            1
# SMART DISPLAY MODULE                  1
# COM HPC                               1
# FCBGA                                 1
# PCPLUS SBC                            1
# REGULAR SIZE ENCLOSURE                1
# COMHPC SIZE C MODULE                  1
# MINISTX                               1
# COMPACT FANLESS SYSTEM                1
# SERVER GRADE IPC                      1
# ULTRASMALL                            1
# PALM-SIZED                            1
# RISC SIGNAGE BOX                      1
# EXPOSED BOARD                         1
# OSM V                                 1
# AMC                                   1
# CREDIT CARD-SIZED BOARD               1
# STAMP HOLE                            1
# MINI PC                               1
# FANLESS COMPACT EMBEDDED              1
# VEHICLE COMPUTER                      1
# UTX                                   1
# JUKE BOARD                            1
# EDM COMPACT                           1
# DEVELOPER KIT                         1
# DEVELOPMENT KIT                       1
# ARDUINO                               1
# COMPACT EXPANDABLE                    1
# STACKABLEUSB                          1
# LFBGA                                 1
# 3U VPX                                1
# PCI HALFSIZED                         1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.4 Evaluation or Commercialization

# %%
def clean_evaluation_or_commercialization(value):
    if isinstance(value, str):
        value = value.lower()
        if value in ["true", "false"]:
            return value == "true"
    return None

df["evaluation_or_commercialization"] = df["evaluation_or_commercialization"].apply(clean_evaluation_or_commercialization)

df["evaluation_or_commercialization"].value_counts()
# Out:
# evaluation_or_commercialization
# False    826
# True     151
# Name: count, dtype: int64

# %% [markdown]
# ### 2.5 Processor Architecture

# %% [markdown]
# This cleaning process will:
# - Convert all processor architectures to uppercase.
# - Remove extra spaces.
# - Standardize common terms and variations.
# - Group similar architectures together.
# - Handle specific cases like Intel and ARM variations.

# %%
def clean_processor_architecture(value):
    if not isinstance(value, str):
        return value

    # Convert to uppercase
    value = value.upper()

    # Remove extra spaces
    value = " ".join(value.split())

    # Standardize common terms
    replacements = {
        "X86": "X86",
        "X86-64": "X86-64",
        "X86_64": "X86-64",
        "INTEL 64": "X86-64",
        "IA-32": "X86",
        "ARM": "ARM",
        "ARM CORTEX-A53": "ARM CORTEX-A53",
        "ARM CORTEX A53": "ARM CORTEX-A53",
        "CORTEX-A53 64-BIT": "ARM CORTEX-A53",
        "ARM CORTEX-A": "ARM CORTEX-A",
        "ARM CORTEX A": "ARM CORTEX-A",
        "CORTEX-A": "ARM CORTEX-A",
        "ARM CORTEXA": "ARM CORTEX-A",
        "ARM CORTEX-A72": "ARM CORTEX-A72",
        "ARM CORTEX-A8": "ARM CORTEX-A8",
        "ARM CORTEX-A9": "ARM CORTEX-A9",
        "ARM CORTEX-A7": "ARM CORTEX-A7",
        "CORTEX-A7": "ARM CORTEX-A7",
        "ARM CORTEX-M3": "ARM CORTEX-M3",
        "ARM CORTEX-M4": "ARM CORTEX-M4",
        "ARM CORTEX-M33": "ARM CORTEX-M33",
        "ARMV8": "ARMV8",
        "ARM BIG.LITTLE": "ARM BIG.LITTLE",
        "ARM CORTEX-A72/A53": "ARM BIG.LITTLE",
        "SILVERMONT": "INTEL ATOM",
        "APOLLO LAKE": "INTEL ATOM",
        "BAY TRAIL": "INTEL ATOM",
        "INTEL ATOM C3000": "INTEL ATOM",
        "ZEN": "AMD ZEN",
        "SKYLAKE-U": "INTEL CORE",
        "HASWELL": "INTEL CORE",
        "ALDER LAKE": "INTEL CORE",
        "ALDER LAKE-S": "INTEL CORE",
        "ALDER LAKE N": "INTEL CORE",
        "RAPTOR LAKE-S": "INTEL CORE",
        "INTEL PERFORMANCE HYBRID ARCHITECTURE": "INTEL HYBRID",
        "PERFORMANCE HYBRID ARCHITECTURE": "INTEL HYBRID",
        "X86 HYBRID ARCHITECTURE": "INTEL HYBRID",
        "INTEL® CORE™ ULTRA METEOR LAKE-H/U": "INTEL HYBRID",
        "RISCV": "RISC-V",
        "XTENSA": "XTENSA",
        "XTENSA LX6": "XTENSA",
        "MOBILE ATHLON ARCHITECTURE": "AMD",
        "8-BIT": "8-BIT",
        "16-BIT": "16-BIT",
        "32-BIT ARM ARCHITECTURE": "ARM",
    }

    for old, new in replacements.items():
        if value == old or value.startswith(old + " "):
            return new

    # If no match found, return the original value
    return value


# Apply the cleaning function
original_unique = df["processor_architecture"].nunique()
df["processor_architecture"] = df["processor_architecture"].apply(clean_processor_architecture)
cleaned_unique = df["processor_architecture"].nunique()

print(f"\nOriginal unique processor architectures: {original_unique}")
print(f"Cleaned unique processor architectures: {cleaned_unique}")
print(f"Reduction: {original_unique - cleaned_unique} ({((original_unique - cleaned_unique) / original_unique) * 100:.2f}%)")

df["processor_architecture"].value_counts()
# Out:
# Original unique processor architectures: 60
# Cleaned unique processor architectures: 19
# Reduction: 41 (68.33%)
# processor_architecture
# X86                                                         626
# ARM                                                         291
# X86-64                                                       11
# INTEL ATOM                                                    9
# INTEL CORE                                                    7
# INTEL HYBRID                                                  4
# AMD ZEN                                                       3
# INTEL                                                         3
# RISC-V                                                        2
# XTENSA                                                        2
# ARM CORTEX-A7                                                 1
# PICMZ                                                         1
# 8-BIT                                                         1
# ARM CORTEX-A53                                                1
# AMD                                                           1
# ARMV8                                                         1
# INTEL XEON E AND 8TH/9TH GENERATION CORE I3/I5/I7 SERIES      1
# ARM CORTEX-A                                                  1
# 16-BIT                                                        1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.6 Processor Core Count

# %%
def clean_processor_core_count(value):
    if isinstance(value, str):
        value = value.lower()
        value = re.sub(r"\s+", " ", value)  # Remove extra spaces

        # Handle specific mappings
        mapping = {
            "single": "1", "dual": "2", "quad": "4", "hexa": "6", "octa": "8",
            "four": "4", "eight": "8", "nine": "9"
        }
        for key, replacement in mapping.items():
            if key in value:
                return replacement

        # Handle ranges
        range_match = re.search(r"(\d+)\s*(?:to|-)\s*(\d+)", value)
        if range_match:
            return f"{range_match.group(1)}-{range_match.group(2)}"

        # Handle "up to X cores"
        up_to_match = re.search(r"up to (\d+)", value)
        if up_to_match:
            return f"1-{up_to_match.group(1)}"

        # Handle "X to Y cores"
        to_match = re.search(r"(\w+)\s+to\s+(\w+)\s+cores", value)
        if to_match:
            start = mapping.get(to_match.group(1), to_match.group(1))
            end = mapping.get(to_match.group(2), to_match.group(2))
            return f"{start}-{end}"

        # Handle "X processing cores"
        processing_cores_match = re.search(r"(\w+)\s+processing\s+cores", value)
        if processing_cores_match:
            return mapping.get(processing_cores_match.group(1), processing_cores_match.group(1))

        # Extract single number if present
        number_match = re.search(r"\d+", value)
        if number_match:
            return number_match.group()

    return value


original_unique = df["processor_core_count"].nunique()
df["processor_core_count"] = df["processor_core_count"].apply(clean_processor_core_count)
cleaned_unique = df["processor_core_count"].nunique()

print(f"\nOriginal unique processor core counts: {original_unique}")
print(f"Cleaned unique processor core counts: {cleaned_unique}")
print(f"Reduction: {original_unique - cleaned_unique} ({((original_unique - cleaned_unique) / original_unique) * 100:.2f}%)")

df["processor_core_count"].value_counts()
# Out:
# Original unique processor core counts: 141
# Cleaned unique processor core counts: 30
# Reduction: 111 (78.72%)
# processor_core_count
# 4       460
# 2       202
# 1        60
# 6        41
# 8        37
# 24       15
# 16       15
# 1-14     12
# 14       10
# 1-16     10
# 1-24      9
# 6-10      6
# 12        6
# 1-4       5
# 10        5
# 9         2
# 1-8       2
# 128       2
# 1-6       2
# 1-28      2
# 80        1
# 3         1
# 64        1
# 5         1
# 32        1
# 2-16      1
# 1-60      1
# 20        1
# 1-10      1
# 1-32      1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.7 Processor Manufacturer

# %% [markdown]
# This cleaning process will:
# - Convert all manufacturer names to uppercase.
# - Remove extra spaces.
# - Standardize common terms and variations.
# - Group similar manufacturers together.

# %%
def clean_processor_manufacturer(value):
    if not isinstance(value, str):
        return value

    # Convert to uppercase
    value = value.upper()

    # Remove extra spaces
    value = " ".join(value.split())

    # Standardize common terms
    replacements = {
        "INTEL": "INTEL",
        "NXP": "NXP",
        "AMD": "AMD",
        "BROADCOM": "BROADCOM",
        "ROCKCHIP": "ROCKCHIP",
        "FREESCALE": "FREESCALE",
        "ARM": "ARM",
        "ARM LIMITED": "ARM",
        "TEXAS INSTRUMENTS": "TEXAS INSTRUMENTS",
        "TI": "TEXAS INSTRUMENTS",
        "NVIDIA": "NVIDIA",
        "ALLWINNER": "ALLWINNER",
        "ALLWINNER TECH": "ALLWINNER",
        "ALLWINNER TECHNOLOGY": "ALLWINNER",
        "XILINX": "XILINX",
        "RENESAS": "RENESAS",
        "DMP": "DMP",
        "DMP ELECTRONICS INC": "DMP",
        "QUALCOMM": "QUALCOMM",
        "QUALCOMM TECHNOLOGIES INC": "QUALCOMM",
        "ESPRESSIF SYSTEMS": "ESPRESSIF",
        "ESPRESSIF": "ESPRESSIF",
        "MEDIATEK": "MEDIATEK",
        "MARVELL": "MARVELL",
        "STMICROELECTRONICS": "STMICROELECTRONICS",
        "ST MICROELECTRONICS": "STMICROELECTRONICS",
        "ST": "STMICROELECTRONICS",
        "STM": "STMICROELECTRONICS",
        "RASPBERRY PI LTD": "RASPBERRY PI",
        "RASPBERRY PI": "RASPBERRY PI",
        "KNERON": "KNERON",
        "STERICSSON": "STERICSSON",
        "RABBIT": "RABBIT",
        "RABBIT SEMICONDUCTOR": "RABBIT",
        "RABBIT SEMICONDUCTOR INC": "RABBIT",
        "WESTERN DESIGN CENTER": "WESTERN DESIGN CENTER",
        "ADVANTECH": "ADVANTECH",
        "ATMEL": "ATMEL",
        "VIA": "VIA",
        "MICROCHIP": "MICROCHIP",
    }

    for old, new in replacements.items():
        if value == old or value.startswith(old + " "):
            return new

    # If no match found, return the original value
    return value


# Apply the cleaning function
original_unique = df["processor_manufacturer"].nunique()
df["processor_manufacturer"] = df["processor_manufacturer"].apply(clean_processor_manufacturer)
cleaned_unique = df["processor_manufacturer"].nunique()

print(f"\nOriginal unique processor manufacturers: {original_unique}")
print(f"Cleaned unique processor manufacturers: {cleaned_unique}")
print(f"Reduction: {original_unique - cleaned_unique} ({((original_unique - cleaned_unique) / original_unique) * 100:.2f}%)")

df["processor_manufacturer"].value_counts()
# Out:
# Original unique processor manufacturers: 49
# Cleaned unique processor manufacturers: 27
# Reduction: 22 (44.90%)
# processor_manufacturer
# INTEL                    627
# NXP                      120
# AMD                       61
# BROADCOM                  34
# ROCKCHIP                  23
# TEXAS INSTRUMENTS         15
# FREESCALE                 13
# ARM                       12
# ALLWINNER                 10
# NVIDIA                     8
# DMP                        7
# STMICROELECTRONICS         6
# RENESAS                    6
# QUALCOMM                   5
# XILINX                     5
# RABBIT                     4
# ESPRESSIF                  4
# MARVELL                    4
# MEDIATEK                   3
# RASPBERRY PI               3
# VIA                        1
# MICROCHIP                  1
# ATMEL                      1
# ADVANTECH                  1
# WESTERN DESIGN CENTER      1
# KNERON                     1
# STERICSSON                 1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.8 Processor TDP

# %% [markdown]
# This cleaning process will:
# - Preserves range values (e.g., "6W-12W")
# - Standardizes all numeric values to one decimal place
# - Converts "up to X" format to a range starting from 0W
# - Handles special cases like "ultra low power" and "low power consumption"
# - Removes extra spaces and standardizes the "W" suffix

# %%
def clean_processor_tdp(value):
    if not isinstance(value, str):
        return value

    value = value.lower().strip()
    value = re.sub(r"\s+", " ", value)  # Remove extra spaces

    # Handle special cases
    if value in ["ultra low power", "low power consumption", "low power design", "low power"]:
        return "LOW POWER"

    # Convert ranges to standard format
    range_match = re.search(r"(\d+(?:\.\d+)?)\s*(?:w|watts)?\s*(?:to|-)\s*(\d+(?:\.\d+)?)\s*(?:w|watts)?", value)
    if range_match:
        return f"{float(range_match.group(1)):.1f}W-{float(range_match.group(2)):.1f}W"

    # Handle "up to X" format
    up_to_match = re.search(r"(?:up to|max) (\d+(?:\.\d+)?)\s*(?:w|watts)", value)
    if up_to_match:
        return f"0.0W-{float(up_to_match.group(1)):.1f}W"

    # Handle single values
    single_match = re.search(r"(\d+(?:\.\d+)?)\s*(?:w|watts)?", value)
    if single_match:
        return f"{float(single_match.group(1)):.1f}W"

    return value


# Apply the cleaning function
df["processor_tdp"] = df["processor_tdp"].apply(clean_processor_tdp)

# Display the updated value counts
print(df["processor_tdp"].value_counts().head(20))

# Count unique TDP configurations
unique_tdp_configs = df["processor_tdp"].nunique()
print(f"\nNumber of unique TDP configurations: {unique_tdp_configs}")

# Calculate statistics for single TDP values
tdp_values = df["processor_tdp"].dropna()
single_tdps = tdp_values[tdp_values.str.match(r"^\d+\.\d+W$")]
single_tdps_numeric = single_tdps.str.rstrip("W").astype(float)

if not single_tdps_numeric.empty:
    print(f"\nMost common TDP: {single_tdps.mode().values[0]}")
    print(f"Median TDP: {single_tdps_numeric.median():.1f}W")
    print(f"Mean TDP: {single_tdps_numeric.mean():.1f}W")
    print(f"Min TDP: {single_tdps_numeric.min():.1f}W")
    print(f"Max TDP: {single_tdps_numeric.max():.1f}W")

# Count products with TDP ranges
tdp_ranges = tdp_values[tdp_values.str.contains("-")]
print(f"\nNumber of products with TDP ranges: {len(tdp_ranges)}")
print(f"Percentage of products with TDP ranges: {len(tdp_ranges) / len(tdp_values) * 100:.2f}%")

# Count low power products
low_power_count = len(tdp_values[tdp_values == "LOW POWER"])
print(f"\nNumber of products with unspecified low power consumption: {low_power_count}")
# Out:
# processor_tdp
# 6.0W           102
# 15.0W           94
# 35.0W           49
# 45.0W           45
# 65.0W           38
# 10.0W           33
# 95.0W           26
# 125.0W          22
# 28.0W           20
# 12.0W           16
# 0.0W-45.0W      12
# 25.0W           10
# 6.0W-12.0W       9
# 35.0W-65.0W      8
# LOW POWER        7
# 5.0W             6
# 205.0W           5
# 12.0W-25.0W      5
# 15.0W-45.0W      5
# 15.0W-25.0W      4
# Name: count, dtype: int64
#
# Number of unique TDP configurations: 83
#
# Most common TDP: 6.0W
# Median TDP: 15.0W
# Mean TDP: 38.7W
# Min TDP: 1.0W
# Max TDP: 1900.0W
#
# Number of products with TDP ranges: 84
# Percentage of products with TDP ranges: 13.68%
#
# Number of products with unspecified low power consumption: 7

# %% [markdown]
# ### 2.9 Memory

# %% [markdown]
# This cleaning process will:
# - Preserves "Up to X" format
# - Keeps range values
# - Maintains information about memory types (DDR, LPDDR, SDRAM, etc.)
# - Standardizes memory sizes to GB or MB
# - Handles "Max Capacity X" format
# - Keeps original values for entries that don't match any specific format

# %%
def standardize_memory_size(value, unit):
    value = float(value)
    if unit.upper() == "KB":
        return f"{value / 1024:.2f}MB"
    elif unit.upper() == "MB":
        return f"{value:.0f}MB"
    elif unit.upper() == "GB":
        return f"{value:.0f}GB"
    elif unit.upper() == "TB":
        return f"{value * 1024:.0f}GB"
    return f"{value}{unit}"


def clean_memory(value):
    if not isinstance(value, str):
        return value

    value = value.upper().strip()
    value = re.sub(r"\s+", " ", value)  # Remove extra spaces

    # Handle "Up to X" format
    up_to_match = re.search(r"UP TO (\d+(?:\.\d+)?)\s*(GB|MB|TB|KB)", value, re.IGNORECASE)
    if up_to_match:
        size = standardize_memory_size(up_to_match.group(1), up_to_match.group(2))
        return f"UP TO {size}"

    # Handle range format
    range_match = re.search(
        r"(\d+(?:\.\d+)?)\s*(GB|MB|TB|KB)\s*-\s*(\d+(?:\.\d+)?)\s*(GB|MB|TB|KB)", value, re.IGNORECASE
    )
    if range_match:
        start = standardize_memory_size(range_match.group(1), range_match.group(2))
        end = standardize_memory_size(range_match.group(3), range_match.group(4))
        return f"{start}-{end}"

    # Handle single values with type
    single_match = re.search(r"(\d+(?:\.\d+)?)\s*(GB|MB|TB|KB)\s*(DDR\d?L?|LPDDR\d?X?|SDRAM)?", value, re.IGNORECASE)
    if single_match:
        size = standardize_memory_size(single_match.group(1), single_match.group(2))
        mem_type = single_match.group(3) or ""
        return f"{size} {mem_type}".strip()

    # Handle "Max Capacity X" format
    max_cap_match = re.search(r"MAX(?:IMUM)?\s+CAPACITY\s+(\d+(?:\.\d+)?)\s*(GB|MB|TB|KB)", value, re.IGNORECASE)
    if max_cap_match:
        size = standardize_memory_size(max_cap_match.group(1), max_cap_match.group(2))
        return f"MAX {size}"

    # If no specific format is matched, return the original value
    return value


# Apply the cleaning function
df["memory"] = df["memory"].apply(clean_memory)

# Display the updated value counts
print(df["memory"].value_counts().head(20))

# Count unique memory configurations
unique_memory_configs = df["memory"].nunique()
print(f"\nNumber of unique memory configurations: {unique_memory_configs}")

# Calculate statistics for single memory values
memory_values = df["memory"].dropna()
single_memories = memory_values[memory_values.str.match(r"^\d+(?:GB|MB)")]
single_memories_gb = single_memories.str.extract("(\d+)(\w+)").apply(
    lambda x: float(x[0]) if x[1] == "GB" else float(x[0]) / 1024, axis=1
)

if not single_memories_gb.empty:
    print(f"\nMost common memory size: {single_memories.mode().values[0] if not single_memories.empty else 'N/A'}")
    print(f"Median memory size: {single_memories_gb.median():.2f}GB")
    print(f"Mean memory size: {single_memories_gb.mean():.2f}GB")
    print(f"Min memory size: {single_memories_gb.min():.2f}GB")
    print(f"Max memory size: {single_memories_gb.max():.2f}GB")

# Count products with memory ranges or "Up to" specifications
memory_ranges = memory_values[memory_values.str.contains("-|UP TO|MAX")]
print(f"\nNumber of products with memory ranges or max specifications: {len(memory_ranges)}")
print(
    f"Percentage of products with memory ranges or max specifications: {len(memory_ranges) / len(memory_values) * 100:.2f}%"
)

# Count products with specific memory types
ddr_count = len(memory_values[memory_values.str.contains("DDR")])
lpddr_count = len(memory_values[memory_values.str.contains("LPDDR")])
sdram_count = len(memory_values[memory_values.str.contains("SDRAM")])
print(f"\nNumber of products with DDR memory: {ddr_count}")
print(f"Number of products with LPDDR memory: {lpddr_count}")
print(f"Number of products with SDRAM: {sdram_count}")
# Out:
# memory
# UP TO 32GB     85
# UP TO 8GB      78
# UP TO 64GB     66
# 8GB DDR3L      47
# 8GB            46
# 4GB LPDDR4     36
# UP TO 16GB     34
# 4GB            31
# UP TO 4GB      30
# 32GB           28
# 4GB DDR3L      28
# 1GB            26
# 64GB           22
# 1GB DDR3       21
# 2GB            20
# 8GB DDR4       20
# UP TO 128GB    18
# UP TO 2GB      18
# 2GB LPDDR4     17
# 512MB DDR3     15
# Name: count, dtype: int64
#
# Number of unique memory configurations: 131
#
# Most common memory size: 8GB DDR3L
# Median memory size: 4.00GB
# Mean memory size: 15.90GB
# Min memory size: 0.00GB
# Max memory size: 768.00GB
#
# Number of products with memory ranges or max specifications: 359
# Percentage of products with memory ranges or max specifications: 36.75%
#
# Number of products with DDR memory: 391
# Number of products with LPDDR memory: 102
# Number of products with SDRAM: 2

# %% [markdown]
# ### 2.10 Onboard Storage

# %% [markdown]
# This enhanced cleaning function will:
# - Standardize storage sizes (GB, MB, TB)
# - Standardize mentions of eMMC, SSD, and common interfaces (SATA, MSATA, NVME, PCIE, M.2)
# - Remove common phrases like "UP TO", "OPTIONAL", "ONBOARD", "SUPPORTS"
# - Simplify ranges and multiple options
# - Standardize flash types (NAND, NOR, SPI)
# - Remove parentheses and their contents
# - Remove any remaining non-alphanumeric characters except hyphen, period, and forward slash
# - Remove extra spaces

# %%
def clean_onboard_storage(value):
    if not isinstance(value, str):
        return value

    value = value.upper()
    value = re.sub(r"\s+", " ", value)  # Remove extra spaces

    # Standardize storage sizes
    value = re.sub(r"(\d+)\s*(GB|MB|TB)", r"\1\2", value)
    value = re.sub(r"(\d+)GBYTE", r"\1GB", value)
    value = re.sub(r"(\d+)MBYTE", r"\1MB", value)
    value = re.sub(r"(\d+)TBYTE", r"\1TB", value)

    # Standardize eMMC mentions
    value = re.sub(r"EMMC", "EMMC", value)

    # Standardize SSD mentions
    value = re.sub(r"(NVME|SATA|M\.2)\s+SSD", r"\1 SSD", value)

    # Standardize common interfaces
    value = re.sub(r"SATA(?: III?)?", "SATA", value)
    value = re.sub(r"MSATA", "MSATA", value)
    value = re.sub(r"NVME", "NVME", value)
    value = re.sub(r"PCIE", "PCIE", value)
    value = re.sub(r"M\.2", "M.2", value)

    # Remove common phrases
    value = re.sub(r"UP TO ", "", value)
    value = re.sub(r"OPTIONAL ", "", value)
    value = re.sub(r"ONBOARD ", "", value)
    value = re.sub(r"SUPPORTS? ", "", value)

    # Simplify ranges
    value = re.sub(r"(\d+)GB?-(\d+)GB", r"\1GB-\2GB", value)

    # Simplify multiple options
    value = re.sub(r"(\d+)GB,?\s+(\d+)GB,?\s+(\d+)GB", r"\1GB/\2GB/\3GB", value)

    # Standardize flash types
    value = re.sub(r"NAND FLASH", "NAND", value)
    value = re.sub(r"NOR FLASH", "NOR", value)
    value = re.sub(r"SPI FLASH", "SPI", value)

    # Remove parentheses and their contents
    value = re.sub(r"\([^)]*\)", "", value)

    # Remove any remaining non-alphanumeric characters except hyphen, period, and forward slash
    value = re.sub(r"[^A-Z0-9\-\./]", " ", value)

    # Remove extra spaces again (in case any were introduced)
    value = " ".join(value.split())

    return value


original_unique = df["onboard_storage"].nunique()
df["onboard_storage"] = df["onboard_storage"].apply(clean_onboard_storage)
cleaned_unique = df["onboard_storage"].nunique()

print(f"\nOriginal unique onboard storage: {original_unique}")
print(f"Cleaned unique onboard storage: {cleaned_unique}")
print(f"Reduction: {original_unique - cleaned_unique} ({((original_unique - cleaned_unique) / original_unique) * 100:.2f}%)")

df["onboard_storage"].value_counts()
# Out:
# Original unique onboard storage: 508
# Cleaned unique onboard storage: 422
# Reduction: 86 (16.93%)
# onboard_storage
# 64GB EMMC                                                                82
# 16GB EMMC                                                                54
# MSATA                                                                    49
# 8GB EMMC                                                                 26
# EMMC                                                                     20
# 32GB EMMC                                                                19
# NVME SSD                                                                 19
# EMMC 64GB                                                                15
# 8GB EMMC NAND                                                            11
# COMPACTFLASH TYPE III                                                    10
# NON-VOLATILE USER DATA STORAGE                                            9
# 1TB NVME SSD                                                              8
# COMPACTFLASH SOCKET                                                       7
# 32GB/S M.2                                                                7
# 128GB EMMC FLASH                                                          6
# MSATA SUPPORT                                                             6
# 4GB EMMC NAND                                                             6
# 4GB EMMC FLASH                                                            6
# EMMC 8GB                                                                  5
# 4GB NAND                                                                  5
# 64GB SSD                                                                  5
# 64GB EMMC 128GB M.2 SSD                                                   5
# 4GB EMMC                                                                  5
# MICRO SD CARD SLOT                                                        5
# EMMC SSD                                                                  4
# CF SOCKET                                                                 4
# FLASH                                                                     4
# 8GB/16GB/32GB EMMC                                                        4
# EMMC 5.0 HIGH-SPEED DRIVE 32GB SOLDERED ON BOARD                          4
# EIGHT SATA 3 AND ONE M.2 CONNECTORS                                       4
# MSATA SUPPORTED                                                           4
# 1 X MSATA                                                                 4
# MICROSD CARD SLOT                                                         4
# 256MB NAND                                                                3
# CFAST MSATA                                                               3
# NVME 256GB                                                                3
# 1GB                                                                       3
# 16GBS EMMC                                                                3
# SOLDERED EMMC 5.0 32GB                                                    3
# 64GBS EMMC                                                                3
# 8GB/16GB/32GB 64GB OR 128GB EMMC FLASH                                    3
# MLC 8GB SLC 4GB                                                           3
# MSATA SATA                                                                3
# 16GB EMMC NAND                                                            3
# CFAST TYPE III                                                            3
# MSATA AND SATA HDD                                                        3
# EMMC 32GB                                                                 3
# 32GBS EMMC                                                                3
# EMMC 5.1 ON BOARD MASS STORAGE                                            3
# MICROSD SLOT                                                              3
# 32GB EMMC FLASH                                                           2
# 1 X SATA HDD BAY 1 X MSATA                                                2
# 128GB SATA SSD                                                            2
# 64G EMMC                                                                  2
# 320GB HDD                                                                 2
# EMBEDDED MULTIMEDIACARD 128GB                                             2
# 128GB MSATA SSD                                                           2
# EMMC 64/128GB                                                             2
# 64GB UMLC SQFLASH SSD                                                     2
# 64GB MSATA                                                                2
# M.2 KEY M 2280 SLOT WITH PCIE X4 SIGNAL FOR NVME SSD                      2
# COMPACTFLASH SOCKET TYPE II                                               2
# MSATA M.2                                                                 2
# 64GB ON BOARD NAND                                                        2
# EMMC FLASH                                                                2
# TLC 64GB                                                                  2
# 64GB SLC EMMC                                                             2
# 2MB FLASH                                                                 2
# 4GBS EMMC FLASH                                                           2
# 128GB EMMC                                                                2
# 8GB/16GB SSD                                                              2
# NOR EMMC SD/MICROSD                                                       2
# 32GB EMMC 5.0 INTERFACE                                                   2
# 16GB/32GB/64GB                                                            2
# MSATA SLOT                                                                2
# 512MB NAND                                                                2
# 16G SQFLASH                                                               2
# MICROSD                                                                   2
# EMMC 4GB - 32GB SSD 8GB - 64GB                                            2
# CFAST                                                                     2
# 16GBS EMMC FLASH MEMORY                                                   2
# SSDS                                                                      2
# 1GB ONBOARD                                                               2
# 2X SATA3 6GB/S                                                            2
# 1MB FLASH                                                                 2
# EMMC FLASH 64GB OPTIONAL                                                  2
# EMMC 64GB SATA SSD                                                        2
# 512K FLASH                                                                2
# M.2 NVME SSD                                                              2
# 4GB FLASH                                                                 2
# INTEL C622 SATA3 CONTROLLER                                               2
# ONE SATA HDD                                                              2
# EMMC 16GB                                                                 2
# EMMC NAND BUILT-IN                                                        2
# SATA SSD                                                                  2
# 2 X MSATA VIA JUMPER SETTING FOR MINI-PCIE SLOTS                          2
# 32GB OF NAND                                                              2
# 4GB EMMC NAND 16MB SPI NOR                                                2
# MB NAND                                                                   2
# EMMC DRIVE SOLDERED ONBOARD                                               2
# 64G OF FLASH                                                              2
# 1 X SATA HDD BAY                                                          2
# ONE SATA HDD BAY ONE EXTERNAL CFAST SOCKET                                2
# 8GB EMMC FLASH                                                            2
# M.2 KEY B SATA                                                            2
# 128GB NVME SSD                                                            2
# 64GB EMMC 512MB QUAD SPI NOR                                              1
# ONE MSATA SLOT TWO DRIVE BAY SATA SSD/HDD                                 1
# 1X M.2 WITH SIM CARD HOLDER FOR LTE AND SATA MODULES                      1
# 2 X SATA 6GB/S 1 X MINI SATA SLOT                                         1
# MSATA VIA MINI PCIE SATA                                                  1
# 1 X MSATA 1 X SATA HDD                                                    1
# 2GB SLC NAND                                                              1
# M.2 STORAGE 2242 SATA                                                     1
# 16MB FLASH                                                                1
# 4 X SATA 6GB/S                                                            1
# NAND MICROSD                                                              1
# 1TB 2.5 SSD SATA 128GB 2TB M.2 SSD                                        1
# EMMC 128GB                                                                1
# 64GB SD CARD                                                              1
# EMMC NAND 4GB                                                             1
# SD CARD EMMC                                                              1
# M.2 NVME                                                                  1
# SATA SSD REMOVABLE RAID SUPPORT                                           1
# 1X SATA HDD DRIVE BAY 1X CFAST CARD SLOT                                  1
# 512MB SLC NAND 4GB EMMC                                                   1
# 32GB                                                                      1
# 64MB FLASH EXPANDABLE TO 128MB                                            1
# 16MB SPI                                                                  1
# SATA 2.5 INCH HDD/SSD MSATA                                               1
# 4MB SPI                                                                   1
# COMPACT FLASH SOCKET TYPE III                                             1
# NO                                                                        1
# 4GB EMMC FLASH 16MB NOR                                                   1
# EMMC/SATA SSD                                                             1
# MINIBLADE SOCKET FOR FLASH STORAGE                                        1
# EMMC 64GB SLC / 128GB MLC                                                 1
# 64GB MLC INDUSTRIAL-GRADE MSATA SSD                                       1
# CF CARD SOCKET                                                            1
# 1 X MSATA CONNECTOR 1 X 3.5 OR 2 X 2.5 HDD SOCKET                         1
# 4GB                                                                       1
# ON-BOARD SSD                                                              1
# MINI-PCIE DUAL PURPOSE SLOT FOR MSATA SSD SUPPORT                         1
# 512MB NAND 4GB EMMC                                                       1
# M.2 SOCKET 3 KEY-M FOR PCIE NVME OR SATA STORAGE SUPPORT                  1
# NVME SSD MAX CAPACITY 512GB                                               1
# COMPACT FLASH                                                             1
# 8K BYTES OF MASK ROM                                                      1
# NVME X4 2280                                                              1
# 1 X BGA NVME SSD                                                          1
# EXTERNAL STORAGE NVME PCIE                                                1
# 16GB UMLC SQFLASH MSATA                                                   1
# 1 M.2 M KEY FOR SSD                                                       1
# 1 X MSATA 1 X SATA HDD DRIVE BAY                                          1
# 128GB SSD                                                                 1
# NVME SUPPORT VROC OPTIONAL                                                1
# COMPACTFLASH SOCKET TYPE I                                                1
# 64GB SPI                                                                  1
# CFAST SLOT                                                                1
# SATA HDD AND COMPACTFLASH CARD TYPE III                                   1
# 64MB QSPI                                                                 1
# HFLASH                                                                    1
# 2MB QSPI                                                                  1
# TWO SATA BAYS CFAST SLOT                                                  1
# COMPACTFLASH TYPE III SATA                                                1
# 6 X SATA 6GB/S                                                            1
# 1GB EMMC                                                                  1
# FROM 8GB EMMC                                                             1
# M.2 B-KEY M-KEY                                                           1
# 4GB SD CARD                                                               1
# 1 X M-KEY FOR STORAGE 1 X B-KEY FOR STORAGE                               1
# PCIE AND SATA INTERFACES FOR M.2 SSD DEVICES                              1
# 64MB SERIAL SPI                                                           1
# 2GB NAND 16MB SPI NOR                                                     1
# IDE-BASED DISK MODULE                                                     1
# NVME SSD AVAILABLE                                                        1
# EMMC 32GB BUILD OPTION                                                    1
# 1X HDD 1X CFAST 1X MSATA                                                  1
# SSD BAY CFAST SOCKET                                                      1
# INTERNAL HDD BAY CFAST                                                    1
# COMPACTFLASH SOCKET TYPE I/II                                             1
# EMMC4.51                                                                  1
# NOR QSPIA EMMC                                                            1
# MINIBLADE SOCKET EUSB INTERFACE                                           1
# M.2 SOCKET 3 INTERFACE FOR SATA/PCIE MODE SSD SUPPORT                     1
# 2242/2260/2280/22110 STORAGE DEVICES                                      1
# SATA                                                                      1
# M.2 2280 PCIE NVME GEN4 X4 CLASS 40 SSD 4TB                               1
# ONE CF SLOT                                                               1
# 1MB SERIAL FLASH                                                          1
# DUAL EXTERNAL HDD/SSD TRAY                                                1
# 1 X NVME M.2 AND 6 X SATA                                                 1
# 1X 64GB MLC INDUSTRIAL-GRADE SSD                                          1
# ONE MSATA DRIVE BAY                                                       1
# EITHER MSATA OR FULL SIZE MINIPCIE                                        1
# 8GB DDR4                                                                  1
# 8GB NAND                                                                  1
# SATA CFAST MICRO SD                                                       1
# 2 X M.2 2280 SLOTS                                                        1
# TWO M.2 SLOTS HYPER M.2 X16 GEN 4 CARD WITH FOUR ADDITIONAL M.2 SLOTS     1
# ONE SATA 3GB/S PORT ONE MINI PCIE MSATA SOCKET                            1
# DISK MODULE SOCKET FOR REMOVABLE FLASH STORAGE                            1
# 1 X NVME M.2                                                              1
# DISKONCHIP FLASH SOCKET                                                   1
# SATA 3.0 FOR STORAGE                                                      1
# EMMC 4.5                                                                  1
# EMBEDDED FLASH                                                            1
# EXPANDABLE SSD-BASED STORAGE NVME AND SATA                                1
# EMMC 5.0 16GB/32GB                                                        1
# MICROSD CARD CONNECTOR                                                    1
# MICROSD SLOT 64GB                                                         1
# SOLDERED EMMC 5.1                                                         1
# EMMC 5.1                                                                  1
# 64GB EMMC MICROSD SATA                                                    1
# M.2 SSD MSATA                                                             1
# 64GB UFS                                                                  1
# FLASH MLC 64GB SLC 32GB                                                   1
# EMMC NAND 64GB                                                            1
# MULTIPLE M.2 SLOTS                                                        1
# M.2 NVME SSD 2.5 SATA SSD                                                 1
# NVRAM 512MB MSATA SOCKET                                                  1
# MSATA AND EUSB OPTIONS                                                    1
# ONE SATA 3GBPS PORT ONE MINI PCIE MSATA SOCKET ONE MICROSD SOCKET         1
# 32GB MASS STORAGE                                                         1
# 8GB CFAST SSD                                                             1
# 2GB/4GB/8GB SSD                                                           1
# 64GB EMMC FLASH MEMORY                                                    1
# M.2 NVME MSATA                                                            1
# SATA FLASH DRIVE SOLDERED ONBOARD                                         1
# EMMC M.2 SSD CONNECTOR                                                    1
# 1 X 64GB EMMC                                                             1
# MSATA AND MICROSD                                                         1
# EMMC 5.1 FLASH STORAGE 128GB                                              1
# 1 X M.2 2242/2280 B-KEY                                                   1
# 64GB NVME SSD                                                             1
# 8 X SATA3 1 X M.2                                                         1
# DISKONCHIP FLASH DEVICE                                                   1
# SATA MSATA                                                                1
# 256MBS FLASH                                                              1
# SATA M.2 SOCKET NAND                                                      1
# 1GB SLC NAND                                                              1
# 128GB 2.5 SATA INDUSTRIAL SOLID STATE DRIVE                               1
# 8GB NANDRIVE                                                              1
# EMMC FLASH 16GB EXPANDABLE                                                1
# MSATA SATAIII                                                             1
# ON BOARD EMMC                                                             1
# 1 X M.2 M KEY 1 X SATA ISATA 6GB/S                                        1
# 64GB EMMC DRIVE SOLDERED ONBOARD                                          1
# 4GB EMMC 32GB FLASH VIA MICRO SD CARD                                     1
# FLASH OPTIONAL MLC 64GB SLC 32GB                                          1
# EMMC FLASH 64GB EXPANDABLE                                                1
# COMPACTFLASH SOCKET TYPE I/II SUPPORTED                                   1
# 8GB EMMC FLASH 32MB QSPI                                                  1
# ONE MSATA SLOT TWO DRIVE BAY FOR SATA 2.5 SSD/HDD                         1
# 8GB/16GB EMMC                                                             1
# NVME SSDS                                                                 1
# INTEL C621 10 X SATA 6GB/S SOFTWARE RAID                                  1
# CF SOCKET TYPE II                                                         1
# NVME X1 SSD                                                               1
# ONE INTERNAL MSATA SOCKET ONE SATA HDD BAY                                1
# ON-BOARD STORAGE                                                          1
# 8GBS EMMC FLASH                                                           1
# 8GB / 16GB / 32GB                                                         1
# 64GB MLC SSD                                                              1
# 9 X SATA3 PORTS 1 X M.2 2280                                              1
# 4MBS SERIAL FLASH                                                         1
# M.2 M KEY FOR NVME SSD                                                    1
# 128GB EMMC 5.0                                                            1
# 1 X 2.5 SATA MLC 64 128 256 512GB 1TB SSD                                 1
# DUAL HOT-SWAPPABLE HDD/SSD SLOTS WITH RAID SUPPORT                        1
# SATA SSD BAY MSATA                                                        1
# 500GB HDD                                                                 1
# 1 X 4GB ON-BOARD SSD                                                      1
# 1 X MSATA SOCKET 1 X 2.5 SSD                                              1
# 4GB EMMC 256KBIT EEPROM                                                   1
# 64GB EMMC FLASH                                                           1
# MICRO SD CARD M.2 NVME SSD                                                1
# NVME PCIE GEN3 X4                                                         1
# FLASH 8GB                                                                 1
# EMMC OPTIONAL                                                             1
# 8 X SATAIII                                                               1
# 32GB EMMC 5.0                                                             1
# 2.5 HDD/SSD BAY CFAST MSATA                                               1
# 2 X M.2 NVME PCIE GEN3 X4 INTERFACE                                       1
# 8GB 16GB OR 32GB EMMC                                                     1
# TYPE I/II COMPACTFLASH SOCKET                                             1
# MSATA MICRO SD CARD SLOT                                                  1
# MICRO SD                                                                  1
# HDD SUPPORT HOT-SWAP                                                      1
# TWO REMOVABLE SATA HDD BAYS MSATA SOCKET                                  1
# SDMMC CARD SOCKET SDHC 32GB                                               1
# NVME SSD AS BOOT DISKS                                                    1
# MSATA FULL-SIZE SUPPORT                                                   1
# ONE MSATA DRIVE ONE SATA HDD BAY                                          1
# EUSB FLASH STORAGE                                                        1
# 2X SATA GEN3 MICROSD M.2 TYPE B SOCKET                                    1
# 2X HDD 1X CFAST 1X MSATA                                                  1
# 64GB 2.5 SATA INDUSTRIAL SOLID STATE DRIVE                                1
# COMPACTFLASH SOCKET EUSB INTERFACE                                        1
# SD FUNCTIONS AS STORAGE DEVICE ONLY                                       1
# 1X M.2 TYPE M 2280 FOR SSD                                                1
# ON-BOARD 4GB SSD                                                          1
# INTERNAL HDD BAY MAX 9.5MM HEIGHT                                         1
# SATA AND M.2                                                              1
# 32GB EMMC ROM                                                             1
# EMMC ONBOARD                                                              1
# PLATFORM SOLID STATE MASS MEMORY                                          1
# THREE INTERNAL SATA PORTS                                                 1
# M.2 2242/2280 KEY B                                                       1
# 64GB EMMC 1X SATA 1X MICROSD SLOT                                         1
# MSATA CFAST SATA HDD/SSD                                                  1
# 128MBIT SPI                                                               1
# 3 X SATA                                                                  1
# INTERNAL HDD BAY MAX 9.5 MM HEIGHT CFAST                                  1
# M.2 SSD PCIE X4 BASED                                                     1
# HDD CFAST MSATA                                                           1
# EMMC OPTION 64GB MLC                                                      1
# TWO 2.5 SATA DRIVES                                                       1
# 64GB EMMC OPTIONAL                                                        1
# 8GB EMMC 32MB QSPI                                                        1
# 512GB NVME SSD                                                            1
# 32GB SD CARD                                                              1
# 2 X M.2 SLOTS AND 4 X SATA 6GB/S PORTS                                    1
# MICRO SD PORT                                                             1
# ONE SATA HDD BAY MSATA SOCKET                                             1
# 4 X SATA3.0 2 X M.2 KEY M                                                 1
# TWO SATA REMOVABLE HDD BAYS                                               1
# 16GB EMMC FLASH                                                           1
# COMPACTFLASH CFAST SATA MSATA                                             1
# M.2 SSD                                                                   1
# EMMC FLASH 8GB EXPANDABLE 128GB                                           1
# SATA HDD/SSD BAYS MSATA                                                   1
# M.2 M KEY SSD NVME SUPPORTED                                              1
# EMMC SD/MICROSD                                                           1
# 64GB TLC SSD                                                              1
# 0GB RAM                                                                   1
# UFS 2.0 FLASH 64GB                                                        1
# COMPACTFLASH SATA                                                         1
# 10 X SATA 3                                                               1
# 8GB/16GB/32GB 64GB EMMC OPTIONS                                           1
# 4GB NAND 16MB SPI                                                         1
# 4GB/8GB EMMC                                                              1
# M.2 SATA                                                                  1
# M.2                                                                       1
# MSATA NVME                                                                1
# MICROSD SLOT FOR ON-BOARD STORAGE                                         1
# 1X SSD 1X MSATA SOCKET                                                    1
# SPI NOR 64MB                                                              1
# NVME X4 SSD                                                               1
# 64GB MLC INDUSTRIAL GRADE SSD                                             1
# EMMC M.2 MICROSD                                                          1
# 32G SSD                                                                   1
# MICROSD SOCKET                                                            1
# 128MB NAND                                                                1
# 1GB NAND 4GB EMMC                                                         1
# 1GB NAND                                                                  1
# 1 X SATA 6GB/S PORT                                                       1
# HDD/SSD AND MSATA                                                         1
# 16GB/32GB EMMC                                                            1
# M.2 NVME SSD SUPPORT                                                      1
# REMOVABLE FLASH STORAGE                                                   1
# 2X SATA HDD 1X MSATA                                                      1
# 2242/2260/2280/22110 STORAGE DEVICES VIA M.2 SLOTS                        1
# 4GB SOLID STATE STORAGE                                                   1
# TYPE II CF SOCKET                                                         1
# HYPER M.2 X16 GEN 4 CARD WITH MULTIPLE M.2 SLOTS                          1
# 1X SATA HDD 1X COMPACT FLASH CARD                                         1
# 1X MINI PCIE FULL CARD SLOT PCIE GEN2/USB OR M-SATA                       1
# HDD/SSD BAY SUPPORT MSATA SLOT                                            1
# EMMC 16GB SLC 64GB MLC                                                    1
# SATA AND MSATA                                                            1
# M.2 KEY B SLOT FOR STORAGE CARDS                                          1
# 64GB M.2 SSD                                                              1
# ONE SATA HDD BAY FULL SIZE MSATA SOCKET                                   1
# 8GBS EMMC                                                                 1
# 4GB EMMC 512MB NAND                                                       1
# 128MB/1GB NAND STORAGE                                                    1
# SATA 2.5 INCH HDD/SSD SUPPORT                                             1
# SATA HDD AND COMPACTFLASH                                                 1
# 512MB SLC NAND                                                            1
# 2 X SATA 6GB/S WITH 5V SATA POWER CONNECTOR                               1
# COMPACT FLASH CARD TYPE II SATA HDD                                       1
# MICROSD CAGE                                                              1
# 8GB SD CARD                                                               1
# NVME PCIE                                                                 1
# M.2 M KEY STORAGE                                                         1
# EMMC QUAD SPI NOR CONFIGURABLE                                            1
# 8GB EMMC FLASH STORAGE                                                    1
# NVME SSD OPTIONAL                                                         1
# TWO SATA REMOVABLE HDD BAYS CFAST CARD                                    1
# 1GB BY SKU                                                                1
# NVME AND SATA SSD                                                         1
# ONE MSATA TWO DRIVE BAYS SATA HDD                                         1
# 32MB SOLID-STATE DISK                                                     1
# CFAST TYPE I/II                                                           1
# 16GB EMMC EXPANDABLE VIA MICROSD                                          1
# MLC 32GB SLC 16GB                                                         1
# NVME X4 SSD OPTIONAL                                                      1
# M.2 M KEY                                                                 1
# EMMC DRIVE SATA GEN3 M.2 SSD                                              1
# 4MB SPI DISK                                                              1
# 64MB SPI NOR 1GB NAND                                                     1
# 8/16/32MB DOC FLASH MEMORY                                                1
# EMMC 64GB/128GB                                                           1
# EMMC5.0                                                                   1
# NVME SSD ONBOARD                                                          1
# EMMC 64GB MICRO SD SLOT                                                   1
# MSATA AND/OR SATA HDD BAY                                                 1
# EMMC DRIVE 1X SATA CONNECTOR MINI MSATA INTERFACE                         1
# 1 X SATA HDD/SSD BAY 1 X HALF-SIZE MSATA                                  1
# 1 X SATA 3.0 1 X M.2 2242/2280 B-KEY                                      1
# EMMC 64GB NAND                                                            1
# 4MB FLASH                                                                 1
# EMMC 0GB / 4GB / 8GB                                                      1
# SLC 16GB MLC 32GB                                                         1
# M.2 NVME SLOTS                                                            1
# SATA HDD/SSD SUPPORT                                                      1
# 128GB MLC SSD                                                             1
# NVME                                                                      1
# MSATA MODULES MICROSD SOCKET                                              1
# 4GB EMMC 512MB SLC NAND                                                   1
# TWO M.2 SLOTS ONE SUPPORTING PCIE 4.0                                     1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.11 Input Voltage

# %% [markdown]
# This cleaning process will:
# - Handles special cases like 'ATX', 'AC', 'VDC', etc.
# - Standardizes all ATX-related entries to simply 'ATX'.
# - Categorizes entries like "WIDE VOLTAGE INPUT RANGE" as 'VARIABLE'.
# - Converts all numeric values to floats for consistency.
# - Handles ranges that don't include 'V' at the end.

# %%
def clean_input_voltage(value):
    if not isinstance(value, str):
        return value

    value = value.upper().strip()
    value = re.sub(r"\s+", " ", value)  # Remove extra spaces

    # Handle special cases
    if value in ["ATX", "AC", "VDC", "DC POWER", "DC POWER INPUT", "USB POWERED"]:
        return value
    if "ATX" in value or "AT POWER" in value:
        return "ATX"
    if "WIDE VOLTAGE INPUT RANGE" in value or "NOMINAL VOLTAGE" in value:
        return "VARIABLE"

    # Standardize range format
    range_match = re.search(r"(\d+(?:\.\d+)?)\s*-\s*(\d+(?:\.\d+)?)\s*V", value)
    if range_match:
        return f"{float(range_match.group(1))}V-{float(range_match.group(2))}V"

    # Handle single values
    single_match = re.search(r"(\d+(?:\.\d+)?)\s*V(?:OLT)?S?", value)
    if single_match:
        return f"{float(single_match.group(1))}V"

    # Handle ranges without 'V'
    range_match_no_v = re.search(r"(\d+(?:\.\d+)?)\s*-\s*(\d+(?:\.\d+)?)", value)
    if range_match_no_v:
        return f"{float(range_match_no_v.group(1))}V-{float(range_match_no_v.group(2))}V"

    return value


original_unique = df["input_voltage"].nunique()
df["input_voltage"] = df["input_voltage"].apply(clean_input_voltage)
cleaned_unique = df["input_voltage"].nunique()

print("\n=== Input Voltage Cleaning Results ===")
print(f"Original unique values: {original_unique}")
print(f"Cleaned unique values:  {cleaned_unique}")
print(f"Reduction:              {original_unique - cleaned_unique}")
print(f"Reduction percentage:   {((original_unique - cleaned_unique) / original_unique) * 100:.2f}%")

print("\n=== Top 20 Input Voltage Configurations ===")
print(df["input_voltage"].value_counts().head(20).to_string())

# Count unique voltage configurations
unique_voltage_configs = df["input_voltage"].nunique()
print(f"\nTotal unique voltage configurations: {unique_voltage_configs}")

# Calculate statistics
voltage_values = df["input_voltage"].dropna()
single_voltages = voltage_values[voltage_values.str.contains("^[\d.]+V$", regex=True)].str.rstrip("V").astype(float)

print("\n=== Single Voltage Statistics ===")
print(f"Most common:  {single_voltages.mode().values[0]}V")
print(f"Median:       {single_voltages.median():.2f}V")
print(f"Mean:         {single_voltages.mean():.2f}V")
print(f"Min:          {single_voltages.min():.2f}V")
print(f"Max:          {single_voltages.max():.2f}V")

# Count products with voltage ranges
voltage_ranges = voltage_values[voltage_values.str.contains("-")]
print("\n=== Voltage Range Statistics ===")
print(f"Products with ranges: {len(voltage_ranges)}")
print(f"Percentage:           {len(voltage_ranges) / len(voltage_values) * 100:.2f}%")

print("\n=== Full Input Voltage Distribution ===")
print(df["input_voltage"].value_counts().to_string())
# Out:
# === Input Voltage Cleaning Results ===
# Original unique values: 137
# Cleaned unique values:  42
# Reduction:              95
# Reduction percentage:   69.34%
#
# === Top 20 Input Voltage Configurations ===
# input_voltage
# 12.0V            513
# 5.0V             239
# 3.3V              33
# 9.0V-36.0V        28
# 24.0V             23
# ATX               21
# 100.0V-240.0V     17
# 12.0V-24.0V       14
# 8.0V-60.0V        12
# 19.0V              6
# 8.0V-30.0V         5
# 3.0V               3
# VARIABLE           2
# AC                 2
# 8.5V               2
# 12.0V-28.0V        2
# 36.0V              2
# 12.0V-60.0V        1
# 8.0V               1
# 30.0V              1
#
# Total unique voltage configurations: 42
#
# === Single Voltage Statistics ===
# Most common:  12.0V
# Median:       12.00V
# Mean:         10.09V
# Min:          1.20V
# Max:          48.00V
#
# === Voltage Range Statistics ===
# Products with ranges: 88
# Percentage:           9.27%
#
# === Full Input Voltage Distribution ===
# input_voltage
# 12.0V                    513
# 5.0V                     239
# 3.3V                      33
# 9.0V-36.0V                28
# 24.0V                     23
# ATX                       21
# 100.0V-240.0V             17
# 12.0V-24.0V               14
# 8.0V-60.0V                12
# 19.0V                      6
# 8.0V-30.0V                 5
# 3.0V                       3
# VARIABLE                   2
# AC                         2
# 8.5V                       2
# 12.0V-28.0V                2
# 36.0V                      2
# 12.0V-60.0V                1
# 8.0V                       1
# 30.0V                      1
# DC POWER INPUT             1
# 7.0V-36.0V                 1
# 9.0V-15.0V                 1
# 4.2V-5.5V                  1
# DC POWER                   1
# 7.0V-12.0V                 1
# 3.0V-3.6V                  1
# 9.0V                       1
# 2.8V                       1
# 12.0V-48.0V                1
# 48.0V                      1
# 2.0V                       1
# 9.0V-34.0V                 1
# 4.75V-20.0V                1
# VDC                        1
# 10% TO 90% OF NOMINAL      1
# 21.0V                      1
# 3.6V                       1
# 1.2V                       1
# 34.0V                      1
# 1.7V-5.5V                  1
# USB POWERED                1

# %% [markdown]
# ### 2.12 IO Count

# %% [markdown]
# This cleaning process will:
# - USB standardization:
#     - USB 2.0 and USB 2 are now treated as the same.
#     - USB 3.0, 3.1, and 3.2 are grouped as "USB 3.x" since the differences are often minimal and inconsistently reported.
#     - Unspecified USB remains as just "USB".
# - SATA and PCIe versioning:
#     - We now capture version information for SATA and PCIe when available.
#     - This allows us to differentiate between, for example, SATA II and SATA III.
# - Other interfaces:
#     - We've kept other interfaces (like ETHERNET, SERIAL, DISPLAY) without version information, as it's less commonly specified and less critical for differentiation.
# - Handling ambiguity:
#     - When a product just specifies "USB" without a version, we keep it as "USB". This ambiguity is preserved in the data, allowing for further analysis if needed.

# %%
def standardize_io_type(io_type):
    io_type = io_type.upper().strip()

    # Standardize USB types
    usb_match = re.search(r"\bUSB\s*([\d.]+)?(?:\s*(?:GEN)?\s*([\d.]+))?", io_type)
    if usb_match:
        version = usb_match.group(1) or usb_match.group(2)
        if version:
            # Standardize version numbers
            if version in ["1", "1.0"]:
                return "USB 1.0"
            if version in ["2", "2.0"]:
                return "USB 2.0"
            elif version in ["3", "3.0"]:
                return "USB 3.0"
            elif version in ["4", "4.0"]:
                return "USB 4.0"
            else:
                return f"USB {version}"
        return "USB"

    # Standardize SATA
    sata_match = re.search(r"\bSATA\s*(I{1,3}|[\d.]+)?", io_type)
    if sata_match:
        version = sata_match.group(1)
        if version:
            if version == "III":
                return "SATA 3.0"
            elif version == "II":
                return "SATA 2.0"
            elif version == "I":
                return "SATA 1.0"
            elif version in ["3", "3.0"]:
                return "SATA 3.0"
            elif version in ["4", "4.0"]:
                return "SATA 4.0"
            elif version in ["5", "5.0"]:
                return "SATA 5.0"
            elif version in ["6", "6.0"]:
                return "SATA 6.0"
            else:
                return f"SATA {version}"
        return "SATA"

    # Standardize PCIe
    pcie_match = re.search(r"\bPCIE\s*([\d.]+)?", io_type)
    if pcie_match:
        version = pcie_match.group(1)
        if version:
            return f"PCIE {version}"
        return "PCIE"

    # Standardize other common I/O types
    elif re.search(r"\b(ETHERNET|LAN|RJ45)\b", io_type):
        return "ETHERNET"
    elif re.search(r"\b(RS-?232|RS-?485|RS-?422|UART|COM|SERIAL)\b", io_type):
        return "SERIAL"
    elif re.search(r"\b(HDMI|VGA|DVI|DISPLAYPORT|DP)\b", io_type):
        return "DISPLAY"
    elif re.search(r"\b(GPIO|DIGITAL I/O)\b", io_type):
        return "GPIO"
    elif re.search(r"\b(I2C|SPI|CAN|SDIO)\b", io_type):
        return "OTHER_BUS"
    elif re.search(r"\b(AUDIO|MIC|LINE-IN|LINE-OUT)\b", io_type):
        return "AUDIO"
    else:
        return "OTHER"


def clean_io_count(value):
    if isinstance(value, str):
        try:
            value_list = ast.literal_eval(value)
            if isinstance(value_list, list):
                if value_list == ["Not Available"]:
                    return []

                # Extract I/O types using regex
                io_types = re.findall(r"\b[\w\s.-]+\b", " ".join(value_list))

                # Standardize and filter I/O types
                return list(set(standardize_io_type(io) for io in io_types if io))
        except:
            # If ast.literal_eval fails, try to extract I/O types directly from the string
            io_types = re.findall(r"\b[\w\s.-]+\b", value)
            return list(set(standardize_io_type(io) for io in io_types if io))
    return value if isinstance(value, list) else []


# Apply the cleaning function
df["io_count"] = df["io_count"].apply(clean_io_count)

# Count unique IO configurations, treating each list as a single entity
unique_io_configs = df["io_count"].apply(lambda x: tuple(sorted(x))).nunique()
print(f"Number of unique IO configurations: {unique_io_configs}")

# Count occurrences of specific IO types
io_type_counts = df["io_count"].explode().value_counts()
print("\nTop 20 most common IO types:")
print(io_type_counts.head(20))

# Count number of IO types per product
io_count_per_product = df["io_count"].apply(len)
print(f"\nAverage number of IO types per product: {io_count_per_product.mean():.2f}")
print(f"Median number of IO types per product: {io_count_per_product.median()}")
print(f"Max number of IO types per product: {io_count_per_product.max()}")
# Out:
# Number of unique IO configurations: 280
#
# Top 20 most common IO types:
# io_count
# USB          414
# OTHER        321
# SERIAL       233
# ETHERNET     206
# USB 3.0      186
# USB 2.0      185
# DISPLAY      143
# PCIE         138
# SATA         104
# GPIO          81
# USB 3.2       65
# OTHER_BUS     60
# AUDIO         50
# USB 3.1       43
# SATA 3.0      38
# USB 1.0       31
# SATA 6.0      13
# SATA 2.0      11
# USB 4.0        7
# PCIE 4         5
# Name: count, dtype: int64
#
# Average number of IO types per product: 2.39
# Median number of IO types per product: 2.0
# Max number of IO types per product: 8

# %%
df["io_count"].value_counts()
# Out:
# io_count
# [USB]                                                                    114
# [USB 3.0]                                                                 77
# [USB 2.0]                                                                 72
# []                                                                        68
# [USB 1.0]                                                                 28
# [USB 3.2]                                                                 27
# [OTHER]                                                                   24
# [USB 3.1]                                                                 21
# [OTHER, USB]                                                              17
# [SERIAL, USB]                                                             12
# [SATA, ETHERNET, USB, PCIE]                                               12
# [SERIAL, USB, OTHER]                                                      11
# [GPIO]                                                                    11
# [OTHER, USB 3.0]                                                           9
# [DISPLAY, ETHERNET, USB, SERIAL]                                           9
# [SERIAL, ETHERNET, USB, OTHER_BUS]                                         7
# [SERIAL, ETHERNET, USB]                                                    7
# [OTHER, ETHERNET, USB]                                                     7
# [OTHER, ETHERNET, OTHER_BUS, SERIAL, USB]                                  6
# [OTHER, USB 2.0]                                                           6
# [SERIAL, ETHERNET, USB, SATA]                                              5
# [DISPLAY, ETHERNET, AUDIO, SERIAL, USB]                                    5
# [SERIAL, USB, SATA]                                                        5
# [DISPLAY, ETHERNET, OTHER, SERIAL, USB]                                    5
# [ETHERNET, USB 3.0]                                                        5
# [SERIAL, USB 2.0, OTHER]                                                   4
# [OTHER, USB 2.0, PCIE, SATA 3.0, USB 3.0]                                  4
# [OTHER, USB, SERIAL]                                                       4
# [PCIE, USB 3.2]                                                            4
# [GPIO, USB 2.0]                                                            4
# [DISPLAY, USB, SERIAL]                                                     4
# [OTHER, PCIE 4, USB 3.2]                                                   4
# [USB 2.0, PCIE]                                                            4
# [OTHER, ETHERNET, USB 2.0]                                                 3
# [USB 3.2, ETHERNET, SATA 3.0, PCIE]                                        3
# [PCIE, USB, SATA]                                                          3
# [OTHER, ETHERNET, USB, SATA]                                               3
# [SERIAL, ETHERNET, USB, OTHER]                                             3
# [USB 3.1, SATA 3.0]                                                        3
# [USB 4.0]                                                                  3
# [ETHERNET, USB, SATA, PCIE]                                                3
# [OTHER, USB, SERIAL, OTHER_BUS]                                            3
# [OTHER, USB, SATA]                                                         3
# [OTHER, DISPLAY, USB, SERIAL]                                              3
# [SERIAL, ETHERNET, USB, DISPLAY]                                           3
# [OTHER, PCIE, OTHER_BUS, SERIAL, USB]                                      3
# [OTHER, USB, GPIO]                                                         3
# [ETHERNET, USB]                                                            3
# [SERIAL, ETHERNET, USB 2.0, USB 3.0]                                       3
# [ETHERNET, USB 3.2]                                                        3
# [ETHERNET, OTHER, DISPLAY, USB]                                            3
# [OTHER, USB, SATA, PCIE]                                                   3
# [USB 1.0, OTHER]                                                           2
# [ETHERNET, USB 2.0, USB 3.0, PCIE]                                         2
# [OTHER, ETHERNET, USB 3.2]                                                 2
# [USB 2.0, PCIE, SATA 3.0, USB 3.0, SERIAL]                                 2
# [OTHER, USB, PCIE]                                                         2
# [SERIAL, ETHERNET, USB, GPIO]                                              2
# [USB 6]                                                                    2
# [OTHER, USB, SERIAL, SATA]                                                 2
# [OTHER, GPIO, SATA, PCIE, USB]                                             2
# [ETHERNET, USB, SATA]                                                      2
# [OTHER, SERIAL, USB 3.0]                                                   2
# [SATA, OTHER, USB 3.1, PCIE]                                               2
# [DISPLAY, ETHERNET, USB, OTHER]                                            2
# [SERIAL, OTHER, USB 3.2]                                                   2
# [SATA 3.0, SERIAL, USB 2.0, OTHER]                                         2
# [ETHERNET, OTHER, DISPLAY, USB 3.0]                                        2
# [USB 3.0, PCIE]                                                            2
# [SERIAL, DISPLAY, USB, SATA]                                               2
# [OTHER, GPIO, USB 2.0, SATA, USB 3.0, SERIAL]                              2
# [SERIAL, ETHERNET, OTHER]                                                  2
# [ETHERNET, SERIAL, DISPLAY, USB]                                           2
# [SERIAL, USB 2.0, AUDIO, OTHER]                                            2
# [GPIO, USB 3.1]                                                            2
# [USB, PCIE]                                                                2
# [SATA, OTHER, USB, PCIE]                                                   2
# [SERIAL, USB 2.0, USB 3.0]                                                 2
# [DISPLAY, OTHER, USB 2.0, USB 3.0, SERIAL]                                 2
# [USB 2.0, AUDIO]                                                           2
# [DISPLAY, ETHERNET, USB 2.0, OTHER, USB 3.0]                               2
# [DISPLAY, USB 2.0]                                                         2
# [DISPLAY, USB]                                                             2
# [SERIAL, USB 2.0, USB 3.0, OTHER]                                          2
# [OTHER, ETHERNET, DISPLAY, SERIAL, USB]                                    2
# [DISPLAY, USB, OTHER]                                                      2
# [ETHERNET, USB 4.0]                                                        2
# [OTHER, ETHERNET, DISPLAY, AUDIO, USB]                                     2
# [DISPLAY, USB, OTHER, PCIE]                                                2
# [USB, SATA]                                                                2
# [SERIAL, ETHERNET, USB, PCIE]                                              2
# [OTHER, USB, SERIAL, PCIE]                                                 2
# [DISPLAY, OTHER, AUDIO, SERIAL, USB]                                       2
# [SERIAL, USB, OTHER_BUS]                                                   2
# [SERIAL, USB, OTHER, SATA]                                                 2
# [AUDIO, DISPLAY, ETHERNET, USB]                                            2
# [USB, OTHER_BUS]                                                           2
# [OTHER, USB 2.0, USB 3.0]                                                  2
# [OTHER, USB 3.1]                                                           2
# [GPIO, DISPLAY, USB, OTHER]                                                2
# [USB 3.2, OTHER, SATA 3.0, PCIE]                                           2
# [DISPLAY, USB, SERIAL, OTHER]                                              2
# [SERIAL, USB 2.0]                                                          2
# [OTHER, GPIO, SATA 2.0, SERIAL, USB]                                       2
# [OTHER, DISPLAY, AUDIO, SERIAL, USB]                                       2
# [OTHER, DISPLAY, USB 2.0]                                                  2
# [DISPLAY, ETHERNET, USB 3.0, OTHER]                                        2
# [SERIAL, AUDIO, USB]                                                       2
# [SERIAL, USB, OTHER, GPIO]                                                 2
# [SERIAL, USB 2.0, USB 3.0, GPIO]                                           2
# [OTHER, PCIE, SATA 2.0, SERIAL, USB]                                       1
# [DISPLAY, ETHERNET, SATA, PCIE, OTHER_BUS, USB]                            1
# [OTHER, AUDIO, USB 3.1]                                                    1
# [DISPLAY, OTHER, AUDIO, OTHER_BUS, SERIAL, USB]                            1
# [OTHER, GPIO, USB 2.0, PCIE, SATA 3.0, USB 3.0, OTHER_BUS]                 1
# [GPIO, ETHERNET, SATA, PCIE, USB]                                          1
# [DISPLAY, USB, SATA 3.0, OTHER]                                            1
# [ETHERNET, AUDIO, SATA, PCIE, SERIAL, USB]                                 1
# [DISPLAY, ETHERNET, OTHER, SATA, USB]                                      1
# [DISPLAY, ETHERNET, SATA, SERIAL, USB]                                     1
# [GPIO, USB 2.0, SERIAL, USB 3.0]                                           1
# [DISPLAY, ETHERNET, OTHER, GPIO, USB]                                      1
# [AUDIO, USB 3.1]                                                           1
# [OTHER, AUDIO, USB 3.0]                                                    1
# [SERIAL, USB, PCIE]                                                        1
# [GPIO, USB, PCIE, SATA]                                                    1
# [OTHER, ETHERNET, USB 4.0]                                                 1
# [SERIAL, USB, PCIE, SATA]                                                  1
# [SATA 3.0, USB 3.0, PCIE]                                                  1
# [USB 2.0, PCIE, USB 3.0, SATA]                                             1
# [SERIAL, AUDIO, USB 3.1]                                                   1
# [OTHER, PCIE, SATA, SERIAL, USB]                                           1
# [OTHER, SATA 6.0]                                                          1
# [OTHER, OTHER_BUS]                                                         1
# [ETHERNET, USB 2.0, SATA 3.0, USB 3.0, SERIAL]                             1
# [GPIO, ETHERNET, DISPLAY, OTHER, PCIE, USB]                                1
# [DISPLAY, ETHERNET, OTHER, PCIE 4, USB 3.0, SATA 2]                        1
# [DISPLAY, ETHERNET, OTHER, GPIO, SATA, USB]                                1
# [USB 1.0, PCIE]                                                            1
# [DISPLAY, ETHERNET, OTHER, SATA, SERIAL, USB]                              1
# [AUDIO, USB 3.0]                                                           1
# [OTHER, DISPLAY, USB 3.0]                                                  1
# [ETHERNET, AUDIO, PCIE, SATA, USB]                                         1
# [DISPLAY, ETHERNET, USB, GPIO]                                             1
# [SATA 6.0, USB 2.0, USB 3.0, OTHER]                                        1
# [OTHER, DISPLAY, SATA 2.0, SERIAL, USB]                                    1
# [OTHER, ETHERNET, AUDIO, SATA, PCIE, USB]                                  1
# [AUDIO, USB]                                                               1
# [OTHER, USB 2.0, USB, USB 3.2]                                             1
# [DISPLAY, ETHERNET, SATA, PCIE, USB]                                       1
# [DISPLAY, ETHERNET, USB 2.0, SERIAL, USB]                                  1
# [OTHER, DISPLAY, USB]                                                      1
# [ETHERNET, USB, SATA 3.0, PCIE]                                            1
# [DISPLAY, OTHER, GPIO, SERIAL, USB]                                        1
# [OTHER, GPIO, PCIE, SATA 2.0, USB]                                         1
# [DISPLAY, OTHER, USB 2.0, PCIE, SERIAL, USB]                               1
# [OTHER, ETHERNET, USB 2.0, DISPLAY]                                        1
# [OTHER, USB 2.0, AUDIO, PCIE, USB 3.0, SATA 3.0, OTHER_BUS]                1
# [OTHER, USB 2.0, PCIE, USB 3.0, SATA 3.0]                                  1
# [GPIO, OTHER, OTHER_BUS, SERIAL, USB]                                      1
# [DISPLAY, ETHERNET, USB 3.0]                                               1
# [USB, SATA, PCIE]                                                          1
# [DISPLAY, ETHERNET, USB, SATA]                                             1
# [OTHER, ETHERNET, DISPLAY, PCIE, SATA 3.0, SERIAL, USB]                    1
# [ETHERNET, USB 3.1]                                                        1
# [OTHER, ETHERNET, GPIO, SERIAL, USB]                                       1
# [OTHER, GPIO, USB 3.2]                                                     1
# [SATA, GPIO, USB, PCIE]                                                    1
# [DISPLAY, USB 2.0, SATA, PCIE, USB 3.0]                                    1
# [SATA, USB 3.2]                                                            1
# [GPIO, OTHER_BUS, OTHER]                                                   1
# [OTHER, ETHERNET, USB, SERIAL]                                             1
# [USB 3.0, SATA]                                                            1
# [USB 2.0, USB, USB 3.0]                                                    1
# [DISPLAY, OTHER, USB 2.0, AUDIO, USB 3.0]                                  1
# [GPIO, ETHERNET, DISPLAY, OTHER, AUDIO, USB]                               1
# [USB 2.0, USB 3.0]                                                         1
# [OTHER, ETHERNET, AUDIO]                                                   1
# [USB 2.0, SATA 3.0]                                                        1
# [OTHER, SERIAL]                                                            1
# [OTHER, ETHERNET, USB, OTHER_BUS]                                          1
# [DISPLAY, OTHER, PCIE, SATA, USB]                                          1
# [OTHER, ETHERNET, USB 2.0, PCIE, USB 3.2, SATA 6.0]                        1
# [GPIO, SATA, PCIE, OTHER_BUS, SERIAL, USB]                                 1
# [DISPLAY, SERIAL, USB 3.0]                                                 1
# [OTHER, DISPLAY, USB, SATA]                                                1
# [DISPLAY, SATA, USB 3.0, PCIE]                                             1
# [OTHER, USB, OTHER_BUS, GPIO]                                              1
# [GPIO, OTHER, USB 2.0, ETHERNET, PCIE, USB 3.0, SATA 3.0, OTHER_BUS]       1
# [GPIO, OTHER]                                                              1
# [ETHERNET, USB 2.0, SATA, OTHER_BUS, USB 3.0]                              1
# [DISPLAY, USB, PCIE, SATA]                                                 1
# [OTHER, SATA 6.0, USB 3.2]                                                 1
# [DISPLAY, USB 2.0, SATA, USB 3.0, SERIAL]                                  1
# [OTHER, DISPLAY, PCIE, SATA, SERIAL, USB]                                  1
# [USB 2.0, PCIE, USB 3.2, SATA 3.0, SERIAL]                                 1
# [OTHER, USB 2.0, SATA 2.0, OTHER_BUS]                                      1
# [OTHER, USB 3.0, USB 2.0, SATA 6.0]                                        1
# [DISPLAY, ETHERNET, USB 3.1]                                               1
# [DISPLAY, ETHERNET, USB 2.0, OTHER, PCIE, USB 3.0, SATA 3.0]               1
# [PCIE, ETHERNET, USB, SATA]                                                1
# [DISPLAY, OTHER, OTHER_BUS, SERIAL, USB]                                   1
# [OTHER, USB 2.0, USB 3.0, SATA]                                            1
# [PCIE, USB, SERIAL, SATA]                                                  1
# [SATA 1.0, SERIAL, USB]                                                    1
# [OTHER, GPIO, OTHER_BUS, SERIAL, USB]                                      1
# [OTHER, USB 3.0, PCIE]                                                     1
# [OTHER, GPIO, SATA, PCIE, SERIAL, USB]                                     1
# [OTHER, ETHERNET, USB 3.0]                                                 1
# [DISPLAY, OTHER, USB 2.0, USB 3.2, PCIE, SERIAL]                           1
# [ETHERNET, SATA, OTHER_BUS, SERIAL, USB]                                   1
# [GPIO, DISPLAY, OTHER, AUDIO, USB]                                         1
# [AUDIO, ETHERNET, USB]                                                     1
# [USB 3.2, SATA 3.0, PCIE]                                                  1
# [OTHER, OTHER_BUS, SERIAL, GPIO]                                           1
# [OTHER, ETHERNET, SATA, SERIAL, USB]                                       1
# [GPIO, SERIAL, OTHER_BUS, OTHER]                                           1
# [AUDIO, USB 3.2]                                                           1
# [OTHER, PCIE, SATA 2.0, SATA 3.0, OTHER_BUS, USB]                          1
# [OTHER, USB 3.0, PCIE 3.0, PCIE 2.0, SERIAL]                               1
# [DISPLAY, ETHERNET, USB, OTHER_BUS]                                        1
# [OTHER, ETHERNET, AUDIO, USB 3.0]                                          1
# [GPIO, DISPLAY, ETHERNET, OTHER, USB 3.0]                                  1
# [SERIAL, USB 3.0, OTHER]                                                   1
# [OTHER, ETHERNET, DISPLAY, USB 2.0, AUDIO, SERIAL]                         1
# [ETHERNET, PCIE, SATA, SERIAL, USB]                                        1
# [GPIO, ETHERNET, OTHER, AUDIO, USB]                                        1
# [DISPLAY, ETHERNET, USB 2.0, OTHER, GPIO, USB 3.0, OTHER_BUS, SERIAL]      1
# [SATA 6.0, ETHERNET, USB 3.0]                                              1
# [OTHER, SATA, PCIE, OTHER_BUS, USB]                                        1
# [AUDIO, SERIAL, ETHERNET, USB]                                             1
# [DISPLAY, ETHERNET, USB]                                                   1
# [OTHER, ETHERNET, GPIO, PCIE, USB]                                         1
# [USB 3.2, SATA]                                                            1
# [DISPLAY, ETHERNET, OTHER, PCIE, OTHER_BUS, SERIAL, USB]                   1
# [GPIO, USB 2.0, USB 3.0]                                                   1
# [OTHER, USB 2.0, SERIAL, USB 3.0]                                          1
# [OTHER, USB 2.0, SATA 2.0, OTHER_BUS, PCIE 2.0]                            1
# [USB 3.0, SATA 6.0]                                                        1
# [DISPLAY, ETHERNET, SERIAL, USB 3.0]                                       1
# [ETHERNET, SATA, PCIE, OTHER_BUS, USB]                                     1
# [GPIO, DISPLAY, USB 2.0, USB 3.0]                                          1
# [USB 2.0, USB 3.1]                                                         1
# [DISPLAY, USB 3.1, SATA 3.0, PCIE]                                         1
# [DISPLAY, ETHERNET, GPIO, OTHER_BUS, SERIAL, USB]                          1
# [SATA 1, OTHER, DISPLAY, USB 2.0]                                          1
# [PCIE, USB, OTHER, SATA]                                                   1
# [OTHER, USB 2.0, PCIE, SATA 2.0, OTHER_BUS]                                1
# [OTHER, USB 3.2]                                                           1
# [OTHER, PCIE, USB 3.2, SATA 6.0, SERIAL]                                   1
# [SERIAL, OTHER]                                                            1
# [SATA 6.0, USB 3.2]                                                        1
# [OTHER, ETHERNET, PCIE, SERIAL, USB]                                       1
# [DISPLAY, ETHERNET, OTHER, GPIO, AUDIO, SATA, SERIAL, USB]                 1
# [OTHER, USB 2.0, PCIE, SATA 3.0, USB 3.0, OTHER_BUS, SERIAL]               1
# [SERIAL, USB, GPIO, SATA]                                                  1
# [DISPLAY, ETHERNET, USB, PCIE]                                             1
# [OTHER, ETHERNET, USB 2.0, DISPLAY, USB 3.0, SERIAL]                       1
# [DISPLAY, ETHERNET, OTHER, USB 3.0, SERIAL]                                1
# [DISPLAY, ETHERNET, OTHER, AUDIO, USB 3.1]                                 1
# [SERIAL, USB, OTHER, PCIE]                                                 1
# [SATA 3.0, ETHERNET, USB 3.0, PCIE]                                        1
# [DISPLAY]                                                                  1
# [OTHER, DISPLAY, USB 3.2]                                                  1
# [SATA 6.0, USB 3.0, PCIE]                                                  1
# [OTHER, ETHERNET, USB 2.0, SATA, USB 3.0, SERIAL]                          1
# [SATA 1, OTHER, USB 3.1]                                                   1
# [SERIAL, USB 3.0]                                                          1
# [PCIE, USB 2.0, SATA, USB 3.2]                                             1
# [OTHER, ETHERNET, USB 2.0, DISPLAY, USB 3.0, SERIAL, USB]                  1
# [GPIO, ETHERNET, OTHER_BUS, SERIAL, USB]                                   1
# [SERIAL, USB 3.0, AUDIO, OTHER]                                            1
# [OTHER, ETHERNET, GPIO, OTHER_BUS, SERIAL, USB]                            1
# [USB 2.0, USB]                                                             1
# [OTHER, USB 2.0, PCIE, SATA 6.0, USB 3.0]                                  1
# [USB 2.0, USB 3.0, PCIE]                                                   1
# [DISPLAY, ETHERNET, OTHER, PCIE, USB]                                      1
# [OTHER, ETHERNET, DISPLAY, AUDIO, USB 3.0, SERIAL]                         1
# [DISPLAY, OTHER, PCIE, SATA, SERIAL, USB]                                  1
# [GPIO, OTHER, USB 2.0, SATA 3.0, USB 3.0]                                  1
# [OTHER, ETHERNET, GPIO, PCIE, SERIAL]                                      1
# [OTHER, ETHERNET, GPIO, DISPLAY, USB]                                      1
# [DISPLAY, OTHER, AUDIO, PCIE, SATA 2.0, SERIAL, USB]                       1
# [ETHERNET]                                                                 1
# [OTHER, USB 2.0, OTHER_BUS, SATA 3.0, SERIAL, USB 3.1]                     1
# [OTHER, SERIAL, OTHER_BUS, GPIO]                                           1
# [DISPLAY, ETHERNET, OTHER, OTHER_BUS, USB]                                 1
# [OTHER, USB 2.0, PCIE, SATA 6.0, USB 3.1]                                  1
# [DISPLAY, ETHERNET, USB 2.0, USB 3.0, SERIAL]                              1
# [OTHER, USB 2.0, GPIO]                                                     1
# [DISPLAY, PCIE, SATA, OTHER_BUS, USB]                                      1
# [OTHER, SERIAL, USB 3.2]                                                   1
# [DISPLAY, OTHER, GPIO, OTHER_BUS, USB 3.0, SERIAL]                         1
# [GPIO, OTHER, PCIE, SATA, USB]                                             1
# [DISPLAY, ETHERNET, USB 2.0, AUDIO, USB 3.0, SERIAL]                       1
# [OTHER, USB 4.0]                                                           1
# [ETHERNET, USB 2.0]                                                        1
# [OTHER, PCIE, SATA, OTHER_BUS, SERIAL, USB]                                1
# [OTHER, ETHERNET, SATA, PCIE, USB 3.0]                                     1
# [DISPLAY, OTHER, USB 3.2, SATA 6.0, SERIAL]                                1
# [DISPLAY, OTHER, USB 3.2, PCIE, SERIAL]                                    1
# [DISPLAY, OTHER, OTHER_BUS, USB 3.0, SERIAL]                               1
# [SATA 3.0, USB 2.0, USB 3.0, PCIE]                                         1
# [GPIO, DISPLAY, ETHERNET, SATA, PCIE, USB 3.0]                             1
# [SERIAL, USB, SATA 3.0, PCIE]                                              1
# [OTHER, ETHERNET, USB, PCIE]                                               1
# [OTHER, ETHERNET, AUDIO, PCIE, USB]                                        1
# [GPIO, DISPLAY, USB 2.0, OTHER, AUDIO, USB 3.0]                            1
# [GPIO, ETHERNET, USB 2.0, AUDIO, SATA 3.0, USB 3.0, SERIAL]                1
# [OTHER, GPIO]                                                              1
# [DISPLAY, AUDIO, USB 3.0]                                                  1
# [DISPLAY, USB 3.1, SERIAL, OTHER]                                          1
# [USB 2.0, USB 3.1, PCIE]                                                   1
# [USB 2.0, SATA 2.0]                                                        1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.13 Wireless

# %% [markdown]
# This cleaning process will:
# - Standardizes Wi-Fi versions (Wi-Fi 6, Wi-Fi 5, and generic Wi-Fi).
# - Standardizes Bluetooth versions (Bluetooth 5+, Bluetooth 4, and generic Bluetooth).
# - Standardizes cellular technologies (5G, 4G/LTE, 3G, and generic cellular).
# - Identifies other common wireless technologies (GPS, NFC, Zigbee, LoRa).
# - Groups less common or unspecified wireless technologies as "OTHER".

# %%
def standardize_wireless(item):
    item = item.upper().strip()

    # Standardize Wi-Fi
    if re.search(r"\b(WI-?FI|WLAN|802\.11)\b", item):
        if re.search(r"\b(6E?|AX)\b", item):
            return "WI-FI 6"
        elif re.search(r"\b(6|AX)\b", item):
            return "WI-FI 6"
        elif re.search(r"\b(AC|5)\b", item):
            return "WI-FI 5"
        else:
            return "WI-FI"

    # Standardize Bluetooth
    elif re.search(r"\bBLUETOOTH\b", item):
        if re.search(r"\b(5\.\d|LE)\b", item):
            return "BLUETOOTH 5+"
        elif re.search(r"\b4\.\d\b", item):
            return "BLUETOOTH 4"
        else:
            return "BLUETOOTH"

    # Standardize Cellular
    elif re.search(r"\b(5G|LTE|4G|3G|CELLULAR|WWAN)\b", item):
        if "5G" in item:
            return "5G"
        elif "LTE" in item or "4G" in item:
            return "4G/LTE"
        elif "3G" in item:
            return "3G"
        else:
            return "CELLULAR"

    # Other common wireless technologies
    elif "GPS" in item:
        return "GPS"
    elif "NFC" in item:
        return "NFC"
    elif "ZIGBEE" in item:
        return "ZIGBEE"
    elif "LORA" in item:
        return "LORA"

    # For items that don't match any specific category
    else:
        return "OTHER"


def clean_wireless(value):
    if isinstance(value, str):
        try:
            value_list = ast.literal_eval(value)
            if isinstance(value_list, list):
                return list(set(standardize_wireless(item) for item in value_list if item.strip()))
        except:
            return list(set(standardize_wireless(item) for item in value.split(",") if item.strip()))
    return value if isinstance(value, list) else []


# Apply the cleaning function
df["wireless"] = df["wireless"].apply(clean_wireless)

# Display the updated value counts
print(df["wireless"].value_counts().head(20))

# Count unique wireless configurations
unique_wireless_configs = df["wireless"].apply(lambda x: tuple(sorted(x))).nunique()
print(f"\nNumber of unique wireless configurations: {unique_wireless_configs}")

# Count number of wireless types per product
wireless_count_per_product = df["wireless"].apply(len)
print(f"\nAverage number of wireless types per product: {wireless_count_per_product.mean():.2f}")
print(f"Median number of wireless types per product: {wireless_count_per_product.median()}")
print(f"Max number of wireless types per product: {wireless_count_per_product.max()}")
# Out:
# wireless
# []                                320
# [WI-FI]                           189
# [WI-FI, BLUETOOTH]                111
# [OTHER]                            84
# [WI-FI 5]                          27
# [WI-FI 6]                          26
# [WI-FI, CELLULAR, BLUETOOTH]       22
# [WI-FI 5, BLUETOOTH]               15
# [5G]                               14
# [4G/LTE, WI-FI, BLUETOOTH]         14
# [WI-FI, OTHER, BLUETOOTH]          12
# [BLUETOOTH 5+, WI-FI]               9
# [WI-FI 5, BLUETOOTH 4]              8
# [WI-FI 5, BLUETOOTH 5+]             7
# [WI-FI, BLUETOOTH 4]                7
# [WI-FI, 3G]                         6
# [WI-FI, OTHER]                      6
# [WI-FI 5, OTHER, BLUETOOTH 5+]      6
# [4G/LTE]                            6
# [4G/LTE, WI-FI]                     5
# Name: count, dtype: int64
#
# Number of unique wireless configurations: 79
#
# Average number of wireless types per product: 1.12
# Median number of wireless types per product: 1.0
# Max number of wireless types per product: 5

# %%
df["wireless"].value_counts()
# Out:
# wireless
# []                                        320
# [WI-FI]                                   189
# [WI-FI, BLUETOOTH]                        111
# [OTHER]                                    84
# [WI-FI 5]                                  27
# [WI-FI 6]                                  26
# [WI-FI, CELLULAR, BLUETOOTH]               22
# [WI-FI 5, BLUETOOTH]                       15
# [5G]                                       14
# [4G/LTE, WI-FI, BLUETOOTH]                 14
# [WI-FI, OTHER, BLUETOOTH]                  12
# [BLUETOOTH 5+, WI-FI]                       9
# [WI-FI 5, BLUETOOTH 4]                      8
# [WI-FI 5, BLUETOOTH 5+]                     7
# [WI-FI, BLUETOOTH 4]                        7
# [WI-FI, 3G]                                 6
# [WI-FI, OTHER]                              6
# [WI-FI 5, OTHER, BLUETOOTH 5+]              6
# [4G/LTE]                                    6
# [4G/LTE, WI-FI]                             5
# [WI-FI, GPS, BLUETOOTH]                     5
# [WI-FI 6, BLUETOOTH 5+]                     4
# [BLUETOOTH 5+, OTHER]                       4
# [WI-FI 5, OTHER]                            4
# [WI-FI, CELLULAR]                           3
# [OTHER, LORA, BLUETOOTH]                    2
# [OTHER, LORA]                               2
# [CELLULAR]                                  2
# [4G/LTE, WI-FI, LORA, OTHER]                2
# [WI-FI 6, 5G, ZIGBEE, BLUETOOTH, LORA]      2
# [WI-FI 6, 5G]                               2
# [WI-FI, GPS]                                2
# [OTHER, NFC, BLUETOOTH]                     2
# [WI-FI 5, OTHER, BLUETOOTH 4]               2
# [WI-FI, 3G, BLUETOOTH]                      1
# [OTHER, BLUETOOTH 4]                        1
# [4G/LTE, WI-FI, ZIGBEE, NFC]                1
# [OTHER, GPS, BLUETOOTH 4]                   1
# [WI-FI, GPS, NFC, BLUETOOTH 4]              1
# [BLUETOOTH 5+, WI-FI, BLUETOOTH 4]          1
# [OTHER, BLUETOOTH]                          1
# [4G/LTE, OTHER, BLUETOOTH]                  1
# [3G]                                        1
# [BLUETOOTH 5+, WI-FI, OTHER]                1
# [WI-FI 5, BLUETOOTH 4, 3G]                  1
# [CELLULAR, GPS, WI-FI]                      1
# [4G/LTE, WI-FI, ZIGBEE]                     1
# [CELLULAR, GPS, BLUETOOTH]                  1
# [BLUETOOTH 5+]                              1
# [WI-FI, CELLULAR, OTHER, BLUETOOTH]         1
# [WI-FI, OTHER, 3G]                          1
# [WI-FI, BLUETOOTH 4, OTHER]                 1
# [4G/LTE, 5G, OTHER]                         1
# [4G/LTE, WI-FI, GPS, BLUETOOTH]             1
# [WI-FI 6, 4G/LTE, 5G, BLUETOOTH 5+]         1
# [BLUETOOTH]                                 1
# [WI-FI 5, WI-FI, OTHER]                     1
# [BLUETOOTH 5+, WI-FI, BLUETOOTH]            1
# [OTHER, GPS, ZIGBEE]                        1
# [BLUETOOTH 5+, WI-FI, ZIGBEE, OTHER]        1
# [WI-FI 5, 4G/LTE, BLUETOOTH]                1
# [WI-FI, GPS, OTHER, BLUETOOTH]              1
# [4G/LTE, OTHER, WI-FI, BLUETOOTH, 3G]       1
# [WI-FI 5, GPS, BLUETOOTH]                   1
# [NFC, BLUETOOTH]                            1
# [WI-FI, GPS, 5G]                            1
# [4G/LTE, WI-FI, ZIGBEE, LORA]               1
# [OTHER, WI-FI]                              1
# [WI-FI, LORA, 5G, BLUETOOTH]                1
# [WI-FI, ZIGBEE, OTHER]                      1
# [WI-FI 6, 5G, BLUETOOTH 5+]                 1
# [WI-FI 6, WI-FI 5]                          1
# [WI-FI 6, BLUETOOTH]                        1
# [4G/LTE, OTHER, WI-FI, ZIGBEE, LORA]        1
# [BLUETOOTH 5+, NFC, ZIGBEE, OTHER]          1
# [5G, WI-FI, BLUETOOTH]                      1
# [BLUETOOTH 5+, WI-FI, 4G/LTE, NFC]          1
# [WI-FI, ZIGBEE, OTHER, BLUETOOTH]           1
# [CELLULAR, WI-FI]                           1
# [WI-FI 5, OTHER, GPS, BLUETOOTH]            1
# [WI-FI 6, WI-FI, BLUETOOTH 4]               1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.14 Operating System BSP

# %% [markdown]
# This cleaning process will:
# - Standardizes Windows versions (Windows IoT, Windows Embedded, Windows 10, Windows 11, Windows Server, and generic Windows).
# - Standardizes Linux distributions (Ubuntu, Yocto Linux, Debian, Fedora, CentOS, Red Hat Enterprise Linux, and generic Linux).
# - Identifies other common operating systems (Android, VxWorks, QNX, Raspberry Pi OS).
# - Groups less common or unspecified operating systems as "OTHER".

# %%
def standardize_os(item):
    item = item.upper().strip()

    # Standardize Windows
    if "WINDOWS" in item:
        if "IOT" in item:
            return "WINDOWS IOT"
        elif "EMBEDDED" in item:
            return "WINDOWS EMBEDDED"
        elif "10" in item:
            return "WINDOWS 10"
        elif "11" in item:
            return "WINDOWS 11"
        elif "SERVER" in item:
            return "WINDOWS SERVER"
        else:
            return "WINDOWS"

    # Standardize Linux
    elif "LINUX" in item:
        if "UBUNTU" in item:
            return "UBUNTU"
        elif "YOCTO" in item:
            return "YOCTO LINUX"
        elif "DEBIAN" in item:
            return "DEBIAN"
        elif "FEDORA" in item:
            return "FEDORA"
        elif "CENTOS" in item:
            return "CENTOS"
        elif "REDHAT" in item or "RED HAT" in item:
            return "RED HAT ENTERPRISE LINUX"
        else:
            return "LINUX"

    # Other common operating systems
    elif "ANDROID" in item:
        return "ANDROID"
    elif "VXWORKS" in item:
        return "VXWORKS"
    elif "QNX" in item:
        return "QNX"
    elif "RASPBIAN" in item or "RASPBERRY PI OS" in item:
        return "RASPBERRY PI OS"

    # For items that don't match any specific category
    else:
        return "OTHER"


def clean_operating_system_bsp(value):
    if isinstance(value, str):
        try:
            value_list = ast.literal_eval(value)
            if isinstance(value_list, list):
                return list(set(standardize_os(item) for item in value_list if item.strip()))
        except:
            return list(set(standardize_os(item) for item in value.split(",") if item.strip()))
    return value if isinstance(value, list) else []


# Apply the cleaning function
df["operating_system_bsp"] = df["operating_system_bsp"].apply(clean_operating_system_bsp)

# Display the updated value counts
print(df["operating_system_bsp"].value_counts().head(20))

# Count unique OS configurations
unique_os_configs = df["operating_system_bsp"].apply(lambda x: tuple(sorted(x))).nunique()
print(f"\nNumber of unique OS configurations: {unique_os_configs}")

# Count number of OS types per product
os_count_per_product = df["operating_system_bsp"].apply(len)
print(f"\nAverage number of OS types per product: {os_count_per_product.mean():.2f}")
print(f"Median number of OS types per product: {os_count_per_product.median()}")
print(f"Max number of OS types per product: {os_count_per_product.max()}")
# Out:
# operating_system_bsp
# []                                                  109
# [OTHER]                                              92
# [LINUX]                                              67
# [LINUX, WINDOWS]                                     61
# [ANDROID, LINUX]                                     42
# [WINDOWS]                                            28
# [OTHER, WINDOWS 10]                                  25
# [WINDOWS 10]                                         23
# [OTHER, ANDROID, LINUX]                              23
# [RASPBERRY PI OS]                                    22
# [WINDOWS EMBEDDED]                                   21
# [OTHER, LINUX]                                       19
# [LINUX, WINDOWS 10]                                  18
# [LINUX, WINDOWS IOT]                                 18
# [LINUX, WINDOWS EMBEDDED]                            18
# [VXWORKS, LINUX, WINDOWS]                            18
# [WINDOWS IOT]                                        17
# [LINUX, WINDOWS, VXWORKS, QNX, WINDOWS EMBEDDED]     14
# [OTHER, LINUX, WINDOWS]                              14
# [OTHER, WINDOWS IOT]                                 13
# Name: count, dtype: int64
#
# Number of unique OS configurations: 147
#
# Average number of OS types per product: 1.91
# Median number of OS types per product: 2.0
# Max number of OS types per product: 6

# %%
df["operating_system_bsp"].value_counts()
# Out:
# operating_system_bsp
# []                                                                    109
# [OTHER]                                                                92
# [LINUX]                                                                67
# [LINUX, WINDOWS]                                                       61
# [ANDROID, LINUX]                                                       42
# [WINDOWS]                                                              28
# [OTHER, WINDOWS 10]                                                    25
# [WINDOWS 10]                                                           23
# [OTHER, ANDROID, LINUX]                                                23
# [RASPBERRY PI OS]                                                      22
# [WINDOWS EMBEDDED]                                                     21
# [OTHER, LINUX]                                                         19
# [LINUX, WINDOWS 10]                                                    18
# [LINUX, WINDOWS IOT]                                                   18
# [LINUX, WINDOWS EMBEDDED]                                              18
# [VXWORKS, LINUX, WINDOWS]                                              18
# [WINDOWS IOT]                                                          17
# [LINUX, WINDOWS, VXWORKS, QNX, WINDOWS EMBEDDED]                       14
# [OTHER, LINUX, WINDOWS]                                                14
# [OTHER, WINDOWS IOT]                                                   13
# [OTHER, ANDROID]                                                       13
# [YOCTO LINUX]                                                          12
# [UBUNTU, WINDOWS 10]                                                   11
# [VXWORKS, LINUX, WINDOWS, WINDOWS EMBEDDED]                             9
# [OTHER, LINUX, WINDOWS IOT]                                             8
# [LINUX, WINDOWS IOT, WINDOWS 10]                                        7
# [OTHER, WINDOWS EMBEDDED]                                               7
# [OTHER, WINDOWS]                                                        7
# [QNX, LINUX, WINDOWS, VXWORKS]                                          6
# [OTHER, UBUNTU]                                                         6
# [UBUNTU]                                                                6
# [VXWORKS, UBUNTU, WINDOWS EMBEDDED]                                     6
# [OTHER, ANDROID, LINUX, WINDOWS]                                        5
# [DEBIAN]                                                                5
# [OTHER, ANDROID, WINDOWS IOT, LINUX, WINDOWS]                           5
# [WINDOWS, WINDOWS 10]                                                   5
# [OTHER, LINUX, WINDOWS 10]                                              4
# [LINUX, WINDOWS, WINDOWS 10]                                            4
# [WINDOWS, WINDOWS EMBEDDED]                                             4
# [LINUX, WINDOWS, WINDOWS EMBEDDED]                                      4
# [WINDOWS, UBUNTU]                                                       4
# [ANDROID, LINUX, WINDOWS EMBEDDED]                                      4
# [VXWORKS, LINUX, WINDOWS EMBEDDED]                                      4
# [LINUX, WINDOWS, WINDOWS IOT]                                           4
# [UBUNTU, WINDOWS, WINDOWS 10]                                           4
# [ANDROID, LINUX, QNX]                                                   3
# [OTHER, RASPBERRY PI OS]                                                3
# [OTHER, WINDOWS 10, WINDOWS IOT, LINUX, WINDOWS 11]                     3
# [WINDOWS SERVER, WINDOWS 10]                                            3
# [UBUNTU, WINDOWS EMBEDDED]                                              3
# [YOCTO LINUX, ANDROID, OTHER]                                           3
# [OTHER, LINUX, WINDOWS, WINDOWS IOT]                                    3
# [WINDOWS 11, LINUX, WINDOWS 10]                                         3
# [YOCTO LINUX, WINDOWS, WINDOWS IOT]                                     3
# [YOCTO LINUX, ANDROID]                                                  3
# [OTHER, QNX]                                                            3
# [OTHER, WINDOWS 10, WINDOWS IOT, LINUX, WINDOWS, WINDOWS EMBEDDED]      3
# [WINDOWS SERVER, LINUX]                                                 3
# [YOCTO LINUX, WINDOWS IOT]                                              3
# [VXWORKS, LINUX, WINDOWS 10]                                            3
# [VXWORKS, OTHER, LINUX, QNX]                                            3
# [YOCTO LINUX, OTHER, WINDOWS IOT]                                       3
# [VXWORKS, LINUX, QNX, WINDOWS 10]                                       2
# [UBUNTU, WINDOWS, VXWORKS, QNX, WINDOWS EMBEDDED]                       2
# [OTHER, ANDROID, LINUX, WINDOWS 10]                                     2
# [OTHER, WINDOWS, WINDOWS 10]                                            2
# [OTHER, WINDOWS IOT, RASPBERRY PI OS]                                   2
# [OTHER, ANDROID, LINUX, WINDOWS EMBEDDED]                               2
# [VXWORKS, ANDROID, LINUX, WINDOWS]                                      2
# [OTHER, LINUX, WINDOWS, VXWORKS, QNX, WINDOWS EMBEDDED]                 2
# [VXWORKS, ANDROID, LINUX, WINDOWS EMBEDDED]                             2
# [OTHER, WINDOWS SERVER]                                                 2
# [ANDROID]                                                               2
# [ANDROID, LINUX, WINDOWS, VXWORKS, QNX, WINDOWS EMBEDDED]               2
# [VXWORKS, YOCTO LINUX, OTHER, WINDOWS IOT]                              2
# [OTHER, LINUX, WINDOWS SERVER, WINDOWS 10]                              2
# [ANDROID, WINDOWS IOT, UBUNTU, WINDOWS EMBEDDED]                        2
# [WINDOWS IOT, UBUNTU, WINDOWS EMBEDDED]                                 2
# [OTHER, LINUX, WINDOWS EMBEDDED]                                        2
# [VXWORKS, OTHER, LINUX, WINDOWS]                                        2
# [WINDOWS EMBEDDED, WINDOWS IOT]                                         2
# [OTHER, WINDOWS IOT, UBUNTU, WINDOWS 10]                                2
# [OTHER, WINDOWS IOT, LINUX, WINDOWS, WINDOWS EMBEDDED]                  2
# [ANDROID, LINUX, WINDOWS]                                               2
# [WINDOWS SERVER, LINUX, WINDOWS]                                        2
# [WINDOWS 11, UBUNTU]                                                    1
# [VXWORKS, YOCTO LINUX, WINDOWS 10]                                      1
# [LINUX, RASPBERRY PI OS]                                                1
# [VXWORKS, YOCTO LINUX, WINDOWS SERVER, WINDOWS IOT]                     1
# [VXWORKS, ANDROID, QNX]                                                 1
# [YOCTO LINUX, UBUNTU]                                                   1
# [VXWORKS, OTHER, WINDOWS]                                               1
# [ANDROID, WINDOWS EMBEDDED]                                             1
# [ANDROID, WINDOWS 10, LINUX, WINDOWS, VXWORKS]                          1
# [VXWORKS, YOCTO LINUX, ANDROID, WINDOWS IOT]                            1
# [OTHER, ANDROID, WINDOWS 10, YOCTO LINUX, WINDOWS IOT]                  1
# [VXWORKS, YOCTO LINUX, ANDROID]                                         1
# [OTHER, LINUX, WINDOWS SERVER]                                          1
# [WINDOWS IOT, WINDOWS EMBEDDED]                                         1
# [OTHER, WINDOWS, WINDOWS EMBEDDED]                                      1
# [OTHER, UBUNTU, WINDOWS 10]                                             1
# [VXWORKS, OTHER, WINDOWS 10]                                            1
# [WINDOWS 10, WINDOWS IOT]                                               1
# [VXWORKS, LINUX, WINDOWS, WINDOWS 10]                                   1
# [ANDROID, LINUX, QNX, WINDOWS EMBEDDED]                                 1
# [YOCTO LINUX, ANDROID, OTHER, WINDOWS IOT]                              1
# [VXWORKS, UBUNTU, QNX, WINDOWS EMBEDDED]                                1
# [FEDORA, OTHER, WINDOWS, WINDOWS EMBEDDED]                              1
# [WINDOWS EMBEDDED, WINDOWS 10]                                          1
# [ANDROID, LINUX, WINDOWS, WINDOWS IOT]                                  1
# [YOCTO LINUX, OTHER]                                                    1
# [VXWORKS, OTHER]                                                        1
# [RED HAT ENTERPRISE LINUX, WINDOWS SERVER, WINDOWS 10]                  1
# [ANDROID, LINUX, VXWORKS, QNX, WINDOWS EMBEDDED]                        1
# [VXWORKS, OTHER, ANDROID, LINUX]                                        1
# [OTHER, UBUNTU, WINDOWS IOT]                                            1
# [ANDROID, UBUNTU, YOCTO LINUX, WINDOWS IOT, WINDOWS]                    1
# [YOCTO LINUX, LINUX, OTHER]                                             1
# [WINDOWS IOT, WINDOWS, WINDOWS EMBEDDED]                                1
# [RED HAT ENTERPRISE LINUX, LINUX, WINDOWS SERVER]                       1
# [OTHER, UBUNTU, WINDOWS 10, WINDOWS IOT, WINDOWS 11]                    1
# [WINDOWS EMBEDDED, LINUX, WINDOWS, WINDOWS 10]                          1
# [QNX]                                                                   1
# [FEDORA, WINDOWS EMBEDDED]                                              1
# [VXWORKS, QNX, LINUX, WINDOWS]                                          1
# [WINDOWS EMBEDDED, LINUX, WINDOWS, WINDOWS IOT]                         1
# [OTHER, WINDOWS SERVER, WINDOWS IOT, LINUX, VXWORKS]                    1
# [VXWORKS, OTHER, WINDOWS IOT]                                           1
# [YOCTO LINUX, ANDROID, UBUNTU]                                          1
# [VXWORKS, OTHER, LINUX]                                                 1
# [VXWORKS, LINUX, WINDOWS IOT]                                           1
# [OTHER, WINDOWS, UBUNTU]                                                1
# [OTHER, UBUNTU, WINDOWS, WINDOWS EMBEDDED]                              1
# [OTHER, WINDOWS SERVER, UBUNTU, WINDOWS 10]                             1
# [WINDOWS SERVER, LINUX, WINDOWS IOT]                                    1
# [YOCTO LINUX, ANDROID, DEBIAN]                                          1
# [OTHER, ANDROID, WINDOWS 10]                                            1
# [OTHER, ANDROID, WINDOWS IOT, WINDOWS, WINDOWS EMBEDDED]                1
# [OTHER, LINUX, WINDOWS, VXWORKS, QNX]                                   1
# [LINUX, WINDOWS IOT, WINDOWS, WINDOWS EMBEDDED]                         1
# [FEDORA, WINDOWS 10]                                                    1
# [OTHER, FEDORA, WINDOWS, WINDOWS EMBEDDED]                              1
# [OTHER, WINDOWS SERVER, WINDOWS 10]                                     1
# [VXWORKS, OTHER, WINDOWS, WINDOWS 10]                                   1
# [WINDOWS 10, WINDOWS SERVER, LINUX, WINDOWS, VXWORKS]                   1
# [VXWORKS, ANDROID, LINUX, WINDOWS 10]                                   1
# [OTHER, ANDROID, WINDOWS 10, WINDOWS IOT, LINUX]                        1
# [LINUX, WINDOWS SERVER, WINDOWS 10]                                     1
# [WINDOWS IOT, UBUNTU, WINDOWS 10]                                       1
# [OTHER, LINUX, WINDOWS, WINDOWS EMBEDDED]                               1
# [VXWORKS, RED HAT ENTERPRISE LINUX, OTHER, WINDOWS 10]                  1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.15 Operating Temperature Max

# %% [markdown]
# This cleaning process will:

# %%
def clean_temperature(value):
    if isinstance(value, str):
        value = value.upper()
        value = re.sub(r"\s+", "", value)  # Remove all spaces
        # Standardize temperature format
        value = re.sub(r"(\d+(?:\.\d+)?)°?C", r"\1°C", value)
        value = re.sub(r"(\d+(?:\.\d+)?)°?F", r"\1°F", value)
        # Handle 'DEGREESCELSIUS' format
        value = re.sub(r"(\d+(?:\.\d+)?)DEGREESCELSIUS", r"\1°C", value)
        # Handle Fahrenheit to Celsius conversion
        f_to_c_match = re.search(r"(\d+(?:\.\d+)?)°F\((\d+(?:\.\d+)?)°C\)", value)
        if f_to_c_match:
            return f"{f_to_c_match.group(2)}°C"
        # Handle Celsius to Fahrenheit (remove Fahrenheit)
        c_to_f_match = re.search(r"(\d+(?:\.\d+)?)°C\(\d+(?:\.\d+)?°F\)", value)
        if c_to_f_match:
            return f"{c_to_f_match.group(1)}°C"
        # Handle ranges
        range_match = re.search(r"(-?\d+(?:\.\d+)?)°?C\s*(?:TO|-)\s*(-?\d+(?:\.\d+)?)°?C", value)
        if range_match:
            return f"{range_match.group(1)}°C-{range_match.group(2)}°C"
        # Handle single Celsius values
        celsius_match = re.search(r"(-?\d+(?:\.\d+)?)°?C", value)
        if celsius_match:
            return f"{celsius_match.group(1)}°C"
    return value


original_unique = df["operating_temperature_max"].nunique()
df["operating_temperature_max"] = df["operating_temperature_max"].apply(clean_temperature)
cleaned_unique = df["operating_temperature_max"].nunique()

# Compare the number of unique values before and after cleaning
print(f"\nOriginal unique operating temperature max: {original_unique}")
print(f"Cleaned unique operating temperature max: {cleaned_unique}")
print(f"Reduction: {original_unique - cleaned_unique} ({((original_unique - cleaned_unique) / original_unique) * 100:.2f}%)")

df["operating_temperature_max"].value_counts()
# Out:
# Original unique operating temperature max: 48
# Cleaned unique operating temperature max: 21
# Reduction: 27 (56.25%)
# operating_temperature_max
# 60°C     504
# 85°C     340
# 70°C      54
# 50°C      18
# 40°C      15
# 75°C       6
# 125°C      4
# 55°C       4
# 105°C      3
# 35°C       3
# 100°C      2
# 85℃        2
# 83°C       1
# +80℃       1
# 65°C       1
# 90°C       1
# 45°C       1
# 80°C       1
# 85OC       1
# 95°C       1
# 70℃        1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.16 Operating Temperature Min

# %%
# Apply the cleaning function
original_unique = df["operating_temperature_min"].nunique()
df["operating_temperature_min"] = df["operating_temperature_min"].apply(clean_temperature)
cleaned_unique = df["operating_temperature_min"].nunique()

# Compare the number of unique values before and after cleaning
print(f"\nOriginal unique operating temperature min: {original_unique}")
print(f"Cleaned unique operating temperature min: {cleaned_unique}")
print(
    f"Reduction: {original_unique - cleaned_unique} ({((original_unique - cleaned_unique) / original_unique) * 100:.2f}%)"
)

df["operating_temperature_min"].value_counts()
# Out:
# Original unique operating temperature min: 27
# Cleaned unique operating temperature min: 10
# Reduction: 17 (62.96%)
# operating_temperature_min
# -40°C    384
# 0°C      373
# -20°C    161
# -25°C     17
# -30°C     10
# -10°C      8
# -40℃       3
# 5°C        2
# -40OC      1
# -20℃       1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.17 Certifications

# %% [markdown]
# This cleaning process will:
# - Standardizes common certifications (CE, FCC, ROHS, UL, CCC, BSMI, CB, MIL-STD-810, EN 50155, IEC 60068, REACH, WEEE, ISO, VCCI, KC, TELEC, IC, RCM).
# - Distinguishes between FCC Class A and FCC Class B.
# - Groups less common or unspecified certifications as "OTHER".

# %%
def standardize_certification(cert):
    cert = cert.upper().strip()

    # Common certifications
    if re.search(r"\bCE\b", cert):
        return "CE"
    elif re.search(r"\bFCC\b", cert):
        if "CLASS A" in cert:
            return "FCC CLASS A"
        elif "CLASS B" in cert:
            return "FCC CLASS B"
        else:
            return "FCC"
    elif re.search(r"\bROHS\b", cert):
        return "ROHS"
    elif re.search(r"\bUL\b", cert):
        return "UL"
    elif re.search(r"\bCCC\b", cert):
        return "CCC"
    elif re.search(r"\bBSMI\b", cert):
        return "BSMI"
    elif re.search(r"\bCB\b", cert):
        return "CB"
    elif re.search(r"\bMIL-STD-810[GH]?\b", cert):
        return "MIL-STD-810"
    elif re.search(r"\bEN\s*50155\b", cert):
        return "EN 50155"
    elif re.search(r"\bIEC\s*60068\b", cert):
        return "IEC 60068"
    elif re.search(r"\bREACH\b", cert):
        return "REACH"
    elif re.search(r"\bWEEE\b", cert):
        return "WEEE"
    elif re.search(r"\bISO\s*\d+", cert):
        return "ISO"
    elif re.search(r"\bVCCI\b", cert):
        return "VCCI"
    elif re.search(r"\bKC\b", cert):
        return "KC"
    elif re.search(r"\bTELEC\b", cert):
        return "TELEC"
    elif re.search(r"\bIC\b", cert):
        return "IC"
    elif re.search(r"\bRCM\b", cert):
        return "RCM"

    # For items that don't match any specific category
    return "OTHER"


def clean_certifications(value):
    if isinstance(value, str):
        try:
            value_list = ast.literal_eval(value)
            if isinstance(value_list, list):
                return list(set(standardize_certification(item) for item in value_list if item.strip()))
        except:
            return list(set(standardize_certification(item) for item in re.split(r"[,;]", value) if item.strip()))
    return value if isinstance(value, list) else []


# Apply the cleaning function
df["certifications"] = df["certifications"].apply(clean_certifications)

# Display the updated value counts
print(df["certifications"].value_counts().head(20))

# Count unique certification configurations
unique_cert_configs = df["certifications"].apply(lambda x: tuple(sorted(x))).nunique()
print(f"\nNumber of unique certification configurations: {unique_cert_configs}")

# Count number of certifications per product
cert_count_per_product = df["certifications"].apply(len)
print(f"\nAverage number of certifications per product: {cert_count_per_product.mean():.2f}")
print(f"Median number of certifications per product: {cert_count_per_product.median()}")
print(f"Max number of certifications per product: {cert_count_per_product.max()}")
# Out:
# certifications
# []                                                221
# [CE, FCC]                                          67
# [ROHS]                                             42
# [ROHS COMPLIANT]                                   31
# [CE, FCC CLASS B]                                  29
# [CE/FCC]                                           22
# [CE, FCC, ROHS]                                    15
# [CE, FCC CLASS B, ROHS COMPLIANT]                  13
# [CE, FCC CLASS A]                                  13
# [ROHS, CE, FCC CLASS B]                            13
# [FCC CLASS B]                                      11
# [CE/FCC CLASS B]                                   10
# [CE, FCC, UL, CCC, BSMI]                           10
# [ROHS COMPLIANT 2002/95/EC]                        10
# [IEC 60068-2-27, IEC 60068-2-64, MIL-STD-810F]      9
# [FCC CLASS A]                                       9
# [CE]                                                9
# [MIL-STD-810G]                                      8
# [FCC, CE]                                           8
# [FCC PART 15]                                       8
# Name: count, dtype: int64
#
# Number of unique certification configurations: 298
#
# Average number of certifications per product: 1.94
# Median number of certifications per product: 1.0
# Max number of certifications per product: 27

# %%
df["certifications"].value_counts()
# Out:
# certifications
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                       221
# [CE, FCC]                                                                                                                                                                                                                                                                                                                                                                                                                                                 67
# [ROHS]                                                                                                                                                                                                                                                                                                                                                                                                                                                    42
# [ROHS COMPLIANT]                                                                                                                                                                                                                                                                                                                                                                                                                                          31
# [CE, FCC CLASS B]                                                                                                                                                                                                                                                                                                                                                                                                                                         29
# [CE/FCC]                                                                                                                                                                                                                                                                                                                                                                                                                                                  22
# [CE, FCC, ROHS]                                                                                                                                                                                                                                                                                                                                                                                                                                           15
# [CE, FCC CLASS B, ROHS COMPLIANT]                                                                                                                                                                                                                                                                                                                                                                                                                         13
# [CE, FCC CLASS A]                                                                                                                                                                                                                                                                                                                                                                                                                                         13
# [ROHS, CE, FCC CLASS B]                                                                                                                                                                                                                                                                                                                                                                                                                                   13
# [FCC CLASS B]                                                                                                                                                                                                                                                                                                                                                                                                                                             11
# [CE/FCC CLASS B]                                                                                                                                                                                                                                                                                                                                                                                                                                          10
# [CE, FCC, UL, CCC, BSMI]                                                                                                                                                                                                                                                                                                                                                                                                                                  10
# [ROHS COMPLIANT 2002/95/EC]                                                                                                                                                                                                                                                                                                                                                                                                                               10
# [IEC 60068-2-27, IEC 60068-2-64, MIL-STD-810F]                                                                                                                                                                                                                                                                                                                                                                                                             9
# [FCC CLASS A]                                                                                                                                                                                                                                                                                                                                                                                                                                              9
# [CE]                                                                                                                                                                                                                                                                                                                                                                                                                                                       9
# [MIL-STD-810G]                                                                                                                                                                                                                                                                                                                                                                                                                                             8
# [FCC, CE]                                                                                                                                                                                                                                                                                                                                                                                                                                                  8
# [FCC PART 15]                                                                                                                                                                                                                                                                                                                                                                                                                                              8
# [MODULAR COMPLIANCE CERTIFICATION]                                                                                                                                                                                                                                                                                                                                                                                                                         8
# [CE/FCC CLASS A]                                                                                                                                                                                                                                                                                                                                                                                                                                           7
# [ROHS, REACH]                                                                                                                                                                                                                                                                                                                                                                                                                                              6
# [CE CLASS B, FCC CLASS B]                                                                                                                                                                                                                                                                                                                                                                                                                                  6
# [CE, FCC CLASS A, CCC, BSMI, UL]                                                                                                                                                                                                                                                                                                                                                                                                                           6
# [MIL-STD-810G COMPLIANCE]                                                                                                                                                                                                                                                                                                                                                                                                                                  5
# [FCC]                                                                                                                                                                                                                                                                                                                                                                                                                                                      5
# [IPC-A-610G CLASS 3]                                                                                                                                                                                                                                                                                                                                                                                                                                       5
# [CE, FCC, EAC, ROHS, UL, CUL]                                                                                                                                                                                                                                                                                                                                                                                                                              5
# [EN50155, EN45545, E-MARK]                                                                                                                                                                                                                                                                                                                                                                                                                                 5
# [FCC, CHINA ROHS]                                                                                                                                                                                                                                                                                                                                                                                                                                          4
# [IEC, MIL-STD-810F]                                                                                                                                                                                                                                                                                                                                                                                                                                        4
# [CLASS I, DIVISION 2 (CID2) & ATEX SOLUTIONS]                                                                                                                                                                                                                                                                                                                                                                                                              4
# [ROHS, MIL-STD-810G]                                                                                                                                                                                                                                                                                                                                                                                                                                       4
# [DIN EN ISO 9001]                                                                                                                                                                                                                                                                                                                                                                                                                                          4
# [ROHS COMPLIANCE]                                                                                                                                                                                                                                                                                                                                                                                                                                          4
# [ROHS COMPLIANT, MIL-STD-810G]                                                                                                                                                                                                                                                                                                                                                                                                                             4
# [CE, LVD, FCC CLASS B]                                                                                                                                                                                                                                                                                                                                                                                                                                     3
# [ROHS, REACH, PICMG COM EXPRESS R2.1]                                                                                                                                                                                                                                                                                                                                                                                                                      3
# [ROHS, MIL-STD-810H]                                                                                                                                                                                                                                                                                                                                                                                                                                       3
# [CE, FCC CLASS A, CCC, BSMI, CB, UL]                                                                                                                                                                                                                                                                                                                                                                                                                       3
# [CE, FCC, UL, CB, CCC, BSMI]                                                                                                                                                                                                                                                                                                                                                                                                                               3
# [CE, FCC CLASS B, ROHS]                                                                                                                                                                                                                                                                                                                                                                                                                                    3
# [EMC CE, FCC]                                                                                                                                                                                                                                                                                                                                                                                                                                              3
# [AEC-Q100]                                                                                                                                                                                                                                                                                                                                                                                                                                                 3
# [IEC-60068-2, IPC-A-610]                                                                                                                                                                                                                                                                                                                                                                                                                                   3
# [MODULAR COMPLIANCE CERTIFICATION FOR WIRELESS LAN AND BLUETOOTH]                                                                                                                                                                                                                                                                                                                                                                                          2
# [CE, FCC CLASS B, CCC, BSMI, UL, CB]                                                                                                                                                                                                                                                                                                                                                                                                                       2
# [UL, CCC, BSMI, CE, FCC]                                                                                                                                                                                                                                                                                                                                                                                                                                   2
# [ARINC 600]                                                                                                                                                                                                                                                                                                                                                                                                                                                2
# [CB/UL/BSMI/CCC]                                                                                                                                                                                                                                                                                                                                                                                                                                           2
# [ISO 9001:2015]                                                                                                                                                                                                                                                                                                                                                                                                                                            2
# [EUP/ERP]                                                                                                                                                                                                                                                                                                                                                                                                                                                  2
# [CE, FCC, EN 55032, EN 55035]                                                                                                                                                                                                                                                                                                                                                                                                                              2
# [ARM SYSTEMREADY ES]                                                                                                                                                                                                                                                                                                                                                                                                                                       2
# [80 PLUS PLATINUM]                                                                                                                                                                                                                                                                                                                                                                                                                                         2
# [FCC CLASS A, CE, ROHS]                                                                                                                                                                                                                                                                                                                                                                                                                                    2
# [IEEE 802.3AF COMPLIANT]                                                                                                                                                                                                                                                                                                                                                                                                                                   2
# [UL]                                                                                                                                                                                                                                                                                                                                                                                                                                                       2
# [ROHS, CE, FCC CLASS A]                                                                                                                                                                                                                                                                                                                                                                                                                                    2
# [SPARKPLUG COMPATIBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                     2
# [CERTIFICATION READY WIRELESS KIT WITH INTEL XMM7560 4G LTE CAT16]                                                                                                                                                                                                                                                                                                                                                                                         2
# [CE, FCC, CCC]                                                                                                                                                                                                                                                                                                                                                                                                                                             2
# [REACH, ROHS COMPLIANT]                                                                                                                                                                                                                                                                                                                                                                                                                                    2
# [IEC 60068-2-1]                                                                                                                                                                                                                                                                                                                                                                                                                                            2
# [CERTIFIED ANTENNA KIT AVAILABLE]                                                                                                                                                                                                                                                                                                                                                                                                                          2
# [MIL-I-46058C, IPC-CC-830, ROHS DIRECTIVE 2002/95/EC, UL FILE NUMBER E105698]                                                                                                                                                                                                                                                                                                                                                                              2
# [CE, FCC CLASS A, CB]                                                                                                                                                                                                                                                                                                                                                                                                                                      2
# [MIL-I-46058C, IPC-CC-830, ROHS DIRECTIVE 2002/95/EC]                                                                                                                                                                                                                                                                                                                                                                                                      2
# [FCC CFR PART 15 SUBPART B, CE, EN 55032, EN 55035, IEC 61000-3-2, IEC 61000-3-3]                                                                                                                                                                                                                                                                                                                                                                          2
# [EUP/ERP COMPLIANT]                                                                                                                                                                                                                                                                                                                                                                                                                                        2
# [CE, FCC CLASS A, CCC, BSMI, UL, ROHS]                                                                                                                                                                                                                                                                                                                                                                                                                     2
# [EN50155:2021 FOR EDGE AI PLATFORMS]                                                                                                                                                                                                                                                                                                                                                                                                                       2
# [ROHS, CE]                                                                                                                                                                                                                                                                                                                                                                                                                                                 2
# [COMMON CRITERIA CERTIFICATION]                                                                                                                                                                                                                                                                                                                                                                                                                            2
# [CE, FCC CLASS B, CCC, BSMI, UL]                                                                                                                                                                                                                                                                                                                                                                                                                           2
# [EAC, UL LISTED, CUL LISTED, ROHS]                                                                                                                                                                                                                                                                                                                                                                                                                         2
# [REACH, ROHS]                                                                                                                                                                                                                                                                                                                                                                                                                                              2
# [FCC, IC, CE, UKCA, RCM, MIC, KC, BLUETOOTH SIG]                                                                                                                                                                                                                                                                                                                                                                                                           2
# [FCC PART 15 CLASS B, EN 55032 CLASS B, ICES-003 CLASS B, VCCI CLASS II]                                                                                                                                                                                                                                                                                                                                                                                   2
# [MIL-STD-810G, ROHS]                                                                                                                                                                                                                                                                                                                                                                                                                                       2
# [EN50155]                                                                                                                                                                                                                                                                                                                                                                                                                                                  2
# [EMC, CE, FCC CLASS B]                                                                                                                                                                                                                                                                                                                                                                                                                                     2
# [CE, FCC, BSMI]                                                                                                                                                                                                                                                                                                                                                                                                                                            2
# [CLASS I, DIVISION 2 SOLUTION]                                                                                                                                                                                                                                                                                                                                                                                                                             2
# [ISO 26262]                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# [IEEE 802.11B/G/N/AC]                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# [TPM, EUPE, VPRO]                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# [UL, CE, FCC, PTCRB, ATEX, IECEX, ROHS, WEEE]                                                                                                                                                                                                                                                                                                                                                                                                              1
# [MIL-STD-810H, ROHS, EU CONFLICT MINERALS COMPLIANT]                                                                                                                                                                                                                                                                                                                                                                                                       1
# [CE, FCC, CB, ITE, UL, EN60601-1, EN60601-1-2]                                                                                                                                                                                                                                                                                                                                                                                                             1
# [CE, UKCA]                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# [CERTIFYING WI-FI, 3G, AND BLUETOOTH MODULES]                                                                                                                                                                                                                                                                                                                                                                                                              1
# [CE/FCC CLASS A, CCC, BSMI, UL, CB, EN50121-3-2, EN50121-4, MIL-STD 810G]                                                                                                                                                                                                                                                                                                                                                                                  1
# [C1D2, ATEX, IECEX, MICROSOFT AZURE IOT EDGE, AMAZON AWS IOT GREENGRASS]                                                                                                                                                                                                                                                                                                                                                                                   1
# [CE, FCC PART 15 CLASS B]                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# [CHINA ROHS]                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [EN 50155, EN 50121-3-2, EN 45545-2]                                                                                                                                                                                                                                                                                                                                                                                                                       1
# [CE, FCC CLASS A, ROHS, ISO CERTIFIED]                                                                                                                                                                                                                                                                                                                                                                                                                     1
# [ISO 7637-2]                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [CE, FCC CLASS A, ROHS, REACH]                                                                                                                                                                                                                                                                                                                                                                                                                             1
# [CE, RED, FCC, IC, SRRC, TELEC, ROHS COMPLIANT]                                                                                                                                                                                                                                                                                                                                                                                                            1
# [IEC 60068-2-64, IEC-60068-2-27, MIL-STD-202 F]                                                                                                                                                                                                                                                                                                                                                                                                            1
# [IPC-A-610G CLASS 3, EMC CE/FCC CLASS A, CCC, BSMI, CB, UL]                                                                                                                                                                                                                                                                                                                                                                                                1
# [ROHS, IEC SAFETY INTEGRITY]                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [EMC CE/FCC CLASS B, CCC/BSMI, SAFETY UL/CB/CCC/BSMI]                                                                                                                                                                                                                                                                                                                                                                                                      1
# [ROHS, WEEE]                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# ...
# [UL, CCC, BSMI, CB, CE, FCC]                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [PRE-CERTIFIED WI-FI/BT MODULE]                                                                                                                                                                                                                                                                                                                                                                                                                            1
# [MICROSOFT AZURE CERTIFIED]                                                                                                                                                                                                                                                                                                                                                                                                                                1
# [CE, FCC, EAC, ROHS, UL]                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# [MIL-I-46058C QUALIFIED, IPC-CC-830 AND ROHS DIRECTIVE 2002/95/EC COMPLIANT]                                                                                                                                                                                                                                                                                                                                                                               1
# [CE/FCC CLASS B, PTCRB, GCF]                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [FCC CLASS A, UL 94V0]                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# [JEDEC ESD, LATCH-UP, MSL]                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# [EMC CERTIFICATION: CE, FCC, CCC, SAFETY CERTIFICATION: UL, CB, CCC, BSMI, KC, RF CERTIFICATION: CE-RF, FCC-RF, IC-RF]                                                                                                                                                                                                                                                                                                                                     1
# [CE, EN 55032, EN 55024, FCC PART 15 CLASS A]                                                                                                                                                                                                                                                                                                                                                                                                              1
# [FCC PART 15 CLASS B]                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# [ROHS COMPLIANT, REACH COMPLIANT]                                                                                                                                                                                                                                                                                                                                                                                                                          1
# [ISO 7637-2, MIL-STD-810G, CE, FCC, UL/CUL]                                                                                                                                                                                                                                                                                                                                                                                                                1
# [EMC CE, FCC CLASS B]                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# [FCC, IC, ETSI/CE, UKCA, CE, RCM, KC, CCC, UL LISTED]                                                                                                                                                                                                                                                                                                                                                                                                      1
# [CE/FCC CLASS B, CCC, BSMI]                                                                                                                                                                                                                                                                                                                                                                                                                                1
# [ROHS II, UL, CE, WEEE]                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# [HUMISEAL® 1A33 COATING, MIL-I-46058C QUALIFIED, IPC-CC-830 AND ROHS DIRECTIVE 2002/95/EC COMPLIANT, UL FILE NUMBER E105698]                                                                                                                                                                                                                                                                                                                               1
# [CE, FCC CLASS B, CCC, BSMI, C-TICK, UL]                                                                                                                                                                                                                                                                                                                                                                                                                   1
# [PSA CERTIFIED, ARM SYSTEMREADY]                                                                                                                                                                                                                                                                                                                                                                                                                           1
# [ISO 9001, ISO 13485, ISO 14001, ISO 27001]                                                                                                                                                                                                                                                                                                                                                                                                                1
# [MIL-STD-810G, ROHS COMPLIANT]                                                                                                                                                                                                                                                                                                                                                                                                                             1
# [UL, CAN ICES-3(B)/NMB-3(B), CE, ROHS, VCCI]                                                                                                                                                                                                                                                                                                                                                                                                               1
# [SMARC SMART MOBILITY ARCHITECTURE SPECIFICATION]                                                                                                                                                                                                                                                                                                                                                                                                          1
# [CE, FCC CLASS A, CCC, BSMI, UL, CB]                                                                                                                                                                                                                                                                                                                                                                                                                       1
# [CE/ FCC CLASS-B]                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# [ROHS, CE, FCC CLASS A, CCC, BSMI, CB, UL]                                                                                                                                                                                                                                                                                                                                                                                                                 1
# [CCC, BSMI, CE, FCC, ROHS COMPLIANT]                                                                                                                                                                                                                                                                                                                                                                                                                       1
# [CE, RED, FCC, IC, SRRC, TELEC, ROHS]                                                                                                                                                                                                                                                                                                                                                                                                                      1
# [EMC CE/FCC CLASS B]                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# [EN 60950-1, IEC 60950-1, AS/NZS 60950-1, GB4943, 47 CFR PART 15 CLASS A, ICES 003 CLASS A, AS/NZS CISPR 32 CLASS A, CISPR 22/CISPR 32 CLASS A, EN55022/EN55032 CLASS A, VCCI CLASS A, CNS-13438 CLASS A, KN32 CLASS A, IEC/EN 61000-3-2, IEC/EN 61000-3-3, IEC/EN-61000-4-2, IEC/EN-61000-4-3, IEC/EN-61000-4-4, IEC/EN-61000-4-5, IEC/EN-61000-4-6, IEC/EN-61000-4-11, KN35, EN300 386, EN55022, EN55032, EN55024, EN55035, EN50082-1/EN-61000-6-1]      1
# [FCC, INDUSTRY CANADA RSS, ETSI EN 302 208 V2.1.1, RED EU, MIC JAPAN]                                                                                                                                                                                                                                                                                                                                                                                      1
# [FCC, CE, IC, VCCI, RCM]                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# [CE, FCC, UL, CCC, BSMI, ROHS]                                                                                                                                                                                                                                                                                                                                                                                                                             1
# [USB-IF, EX APPROVALS, INTRINSICALLY SAFE]                                                                                                                                                                                                                                                                                                                                                                                                                 1
# Name: count, dtype: int64

# %% [markdown]
# ## Cleaned Data

# %%
# Display top 10 unique values for each column, sorted by frequency
for column in columns:
    if df[column].dtype == 'object':
        # Handle columns with list values
        if df[column].apply(lambda x: isinstance(x, list)).any():
            # Convert lists to tuples for hashing
            value_counts = df[column].apply(lambda x: tuple(x) if isinstance(x, list) else x).value_counts().head(50)
        else:
            value_counts = df[column].value_counts().head(50)
    else:
        value_counts = df[column].value_counts().head(50)

    unique_count = len(value_counts)

    print(f"\n{'-' * 100}")
    print(f"{column.upper()} (Total unique values: {unique_count})")
    print(f"{'-' * 100}")

    if not value_counts.empty:
        max_value_length = max(len(str(value)) for value in value_counts.index)
        max_count_length = max(len(str(count)) for count in value_counts.values)

        for value, count in value_counts.items():
            percentage = (count / len(df)) * 100
            print(f"{str(value):<{max_value_length}} | {count:>{max_count_length}} | {percentage:.2f}%")
    else:
        print("No data available for this column")

    print(f"{'-' * 100}")

    # Print values as concatenated string
    concatenated_values = ", ".join(str(value) for value in value_counts.index)
    print(f"Values: {concatenated_values}...")
    print()
# Out:
# ----------------------------------------------------------------------------------------------------
# NAME (Total unique values: 50)
# ----------------------------------------------------------------------------------------------------
# AIMB                                             | 47 | 4.80%
# SOM                                              | 20 | 2.04%
# ASMB                                             | 12 | 1.23%
# PCM                                              | 12 | 1.23%
# ARK                                              | 11 | 1.12%
# MIO                                              | 10 | 1.02%
# RSB                                              |  9 | 0.92%
# RASPBERRY-PI MODEL B                             |  7 | 0.72%
# VENICE GW                                        |  7 | 0.72%
# AIMB-275                                         |  7 | 0.72%
# EDHMIC                                           |  6 | 0.61%
# COM-EXPRESS COMPACT                              |  6 | 0.61%
# COM-EXPRESS BASIC                                |  6 | 0.61%
# TREK                                             |  6 | 0.61%
# MIC                                              |  6 | 0.61%
# EMETXEI                                          |  5 | 0.51%
# PCA                                              |  5 | 0.51%
# UNOG                                             |  5 | 0.51%
# AIMB-580                                         |  5 | 0.51%
# CONGATC                                          |  5 | 0.51%
# COM MODULES                                      |  5 | 0.51%
# PCEGA                                            |  5 | 0.51%
# ARKL                                             |  4 | 0.41%
# CONGATS                                          |  4 | 0.41%
# EMETXEIM                                         |  4 | 0.41%
# VENICE GW SINGLE BOARD                           |  4 | 0.41%
# PCEGAE                                           |  4 | 0.41%
# COM-EXPRESS MINI                                 |  4 | 0.41%
# SOM COM-EXPRESS COMPACT                          |  4 | 0.41%
# AGS GPU SERVER                                   |  3 | 0.31%
# SOM INTEL ATOMCELERON PROCESSOR COM-EXPRESS MINI |  3 | 0.31%
# CONGASA                                          |  3 | 0.31%
# MIO EXTENSION SBC                                |  3 | 0.31%
# COMPUTE                                          |  3 | 0.31%
# ARKDS                                            |  3 | 0.31%
# RASPBERRY-PI COMPUTE                             |  3 | 0.31%
# CONGATCA                                         |  3 | 0.31%
# RASPBERRY-PI                                     |  3 | 0.31%
# ROCK PI N                                        |  3 | 0.31%
# UBIQUITOUS TOUCH                                 |  3 | 0.31%
# IBASE IBAF                                       |  3 | 0.31%
# AIMB-225                                         |  3 | 0.31%
# MIOJUAE                                          |  3 | 0.31%
# ODYSSEY XJ                                       |  3 | 0.31%
# ROCK PI S                                        |  3 | 0.31%
# ROM Q7                                           |  3 | 0.31%
# AIMB KIOSK                                       |  2 | 0.20%
# EMNANOAM                                         |  2 | 0.20%
# CONGAMA                                          |  2 | 0.20%
# KINODH                                           |  2 | 0.20%
# ----------------------------------------------------------------------------------------------------
# Values: AIMB, SOM, ASMB, PCM, ARK, MIO, RSB, RASPBERRY-PI MODEL B, VENICE GW, AIMB-275, EDHMIC, COM-EXPRESS COMPACT, COM-EXPRESS BASIC, TREK, MIC, EMETXEI, PCA, UNOG, AIMB-580, CONGATC, COM MODULES, PCEGA, ARKL, CONGATS, EMETXEIM, VENICE GW SINGLE BOARD, PCEGAE, COM-EXPRESS MINI, SOM COM-EXPRESS COMPACT, AGS GPU SERVER, SOM INTEL ATOMCELERON PROCESSOR COM-EXPRESS MINI, CONGASA, MIO EXTENSION SBC, COMPUTE, ARKDS, RASPBERRY-PI COMPUTE, CONGATCA, RASPBERRY-PI, ROCK PI N, UBIQUITOUS TOUCH, IBASE IBAF, AIMB-225, MIOJUAE, ODYSSEY XJ, ROCK PI S, ROM Q7, AIMB KIOSK, EMNANOAM, CONGAMA, KINODH...
#
#
# ----------------------------------------------------------------------------------------------------
# MANUFACTURER (Total unique values: 50)
# ----------------------------------------------------------------------------------------------------
# ADVANTECH                   | 406 | 41.47%
# IEI                         |  60 | 6.13%
# CONGATEC                    |  50 | 5.11%
# KONTRON                     |  37 | 3.78%
# VERSALOGIC                  |  35 | 3.58%
# ADLINK TECHNOLOGY           |  29 | 2.96%
# IBASE                       |  27 | 2.76%
# ARBOR TECHNOLOGY            |  25 | 2.55%
# IWAVE SYSTEMS               |  22 | 2.25%
# RASPBERRY PI                |  21 | 2.15%
# SOLIDRUN                    |  19 | 1.94%
# KARO ELECTRONICS            |  17 | 1.74%
# MYIR ELECTRONICS            |  15 | 1.53%
# AXIOMTEK                    |  14 | 1.43%
# GATEWORKS                   |  12 | 1.23%
# EUROTECH                    |  11 | 1.12%
# PHOENIX CONTACT             |  11 | 1.12%
# EDA TECHNOLOGY CO LTD       |   9 | 0.92%
# SECO                        |   9 | 0.92%
# NEXCOBOT                    |   9 | 0.92%
# DIGI INTERNATIONAL          |   8 | 0.82%
# GIGAIPC                     |   6 | 0.61%
# FORLINX EMBEDDED TECHNOLOGY |   6 | 0.61%
# SEEEDSTUDIO                 |   6 | 0.61%
# RADXA                       |   6 | 0.61%
# ASUS                        |   6 | 0.61%
# NVIDIA                      |   6 | 0.61%
# AAEON                       |   5 | 0.51%
# OLIMEX                      |   4 | 0.41%
# ESPRESSIF                   |   4 | 0.41%
# NXP                         |   4 | 0.41%
# GOOGLE                      |   3 | 0.31%
# KUNBUS                      |   3 | 0.31%
# MIXTILE                     |   3 | 0.31%
# D SYSTEMS                   |   3 | 0.31%
# GUMSTIX                     |   3 | 0.31%
# BOUNDARY DEVICES            |   3 | 0.31%
# ACURA EMBEDDED SYSTEMS      |   3 | 0.31%
# INTEL                       |   3 | 0.31%
# STARTECHCOM                 |   2 | 0.20%
# BEACON EMBEDDEDWORKS        |   2 | 0.20%
# MOXA                        |   2 | 0.20%
# TOYBRICK                    |   2 | 0.20%
# EDA TECHNOLOGY              |   2 | 0.20%
# NEXCOM                      |   2 | 0.20%
# INTRINSYC TECHNOLOGIES      |   2 | 0.20%
# NORDIC SEMICONDUCTOR        |   1 | 0.10%
# AIM                         |   1 | 0.10%
# MICROSOFT                   |   1 | 0.10%
# SCIOSENSE                   |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
# Values: ADVANTECH, IEI, CONGATEC, KONTRON, VERSALOGIC, ADLINK TECHNOLOGY, IBASE, ARBOR TECHNOLOGY, IWAVE SYSTEMS, RASPBERRY PI, SOLIDRUN, KARO ELECTRONICS, MYIR ELECTRONICS, AXIOMTEK, GATEWORKS, EUROTECH, PHOENIX CONTACT, EDA TECHNOLOGY CO LTD, SECO, NEXCOBOT, DIGI INTERNATIONAL, GIGAIPC, FORLINX EMBEDDED TECHNOLOGY, SEEEDSTUDIO, RADXA, ASUS, NVIDIA, AAEON, OLIMEX, ESPRESSIF, NXP, GOOGLE, KUNBUS, MIXTILE, D SYSTEMS, GUMSTIX, BOUNDARY DEVICES, ACURA EMBEDDED SYSTEMS, INTEL, STARTECHCOM, BEACON EMBEDDEDWORKS, MOXA, TOYBRICK, EDA TECHNOLOGY, NEXCOM, INTRINSYC TECHNOLOGIES, NORDIC SEMICONDUCTOR, AIM, MICROSOFT, SCIOSENSE...
#
#
# ----------------------------------------------------------------------------------------------------
# FORM_FACTOR (Total unique values: 50)
# ----------------------------------------------------------------------------------------------------
# COM EXPRESS                      | 147 | 15.02%
# SBC                              | 133 | 13.59%
# MINI-ITX                         |  76 | 7.76%
# ATX                              |  51 | 5.21%
# SMARC                            |  40 | 4.09%
# BOX PC                           |  38 | 3.88%
# QSEVEN                           |  37 | 3.78%
# MICRO-ATX                        |  35 | 3.58%
# PICO-ITX                         |  35 | 3.58%
# SOM                              |  31 | 3.17%
# RASPBERRY PI                     |  25 | 2.55%
# SODIMM                           |  17 | 1.74%
# DIN RAIL                         |  13 | 1.33%
# EBX                              |  12 | 1.23%
# PCPLUS                           |  12 | 1.23%
# EPIC                             |  11 | 1.12%
# EMBEDDED                         |  11 | 1.12%
# HALF-SIZE                        |  11 | 1.12%
# QFN                              |  10 | 1.02%
# ETX                              |   9 | 0.92%
# PICMG                            |   9 | 0.92%
# COM                              |   8 | 0.82%
# RACKMOUNT                        |   8 | 0.82%
# ALL-IN-ONE                       |   8 | 0.82%
# THIN MINI-ITX                    |   7 | 0.72%
# COMPACT                          |   6 | 0.61%
# MIO                              |   6 | 0.61%
# PROPRIETARY                      |   6 | 0.61%
# COMPACT PCI                      |   5 | 0.51%
# REGULAR SIZE                     |   4 | 0.41%
# PC104                            |   4 | 0.41%
# PC                               |   4 | 0.41%
# PALMSIZE                         |   4 | 0.41%
# SLOT SBC                         |   4 | 0.41%
# PANEL PC                         |   4 | 0.41%
# PCI                              |   3 | 0.31%
# DEVELOPMENT BOARD                |   3 | 0.31%
# SMALL SIZE                       |   3 | 0.31%
# MINI PCIE                        |   3 | 0.31%
# COMPACT IN-VEHICLE COMPUTING BOX |   3 | 0.31%
# MICROSOM                         |   3 | 0.31%
# DIGI SMTPLUS                     |   2 | 0.20%
# SMALL ENCLOSURE                  |   2 | 0.20%
# COMHPC                           |   2 | 0.20%
# COMPACT VISION SYSTEM            |   2 | 0.20%
# MODULAR IPC                      |   2 | 0.20%
# MXM                              |   2 | 0.20%
# COMHPC SIZE A                    |   2 | 0.20%
# PCI-ISA                          |   2 | 0.20%
# EPIC SBC                         |   2 | 0.20%
# ----------------------------------------------------------------------------------------------------
# Values: COM EXPRESS, SBC, MINI-ITX, ATX, SMARC, BOX PC, QSEVEN, MICRO-ATX, PICO-ITX, SOM, RASPBERRY PI, SODIMM, DIN RAIL, EBX, PCPLUS, EPIC, EMBEDDED, HALF-SIZE, QFN, ETX, PICMG, COM, RACKMOUNT, ALL-IN-ONE, THIN MINI-ITX, COMPACT, MIO, PROPRIETARY, COMPACT PCI, REGULAR SIZE, PC104, PC, PALMSIZE, SLOT SBC, PANEL PC, PCI, DEVELOPMENT BOARD, SMALL SIZE, MINI PCIE, COMPACT IN-VEHICLE COMPUTING BOX, MICROSOM, DIGI SMTPLUS, SMALL ENCLOSURE, COMHPC, COMPACT VISION SYSTEM, MODULAR IPC, MXM, COMHPC SIZE A, PCI-ISA, EPIC SBC...
#
#
# ----------------------------------------------------------------------------------------------------
# EVALUATION_OR_COMMERCIALIZATION (Total unique values: 2)
# ----------------------------------------------------------------------------------------------------
# False | 826 | 84.37%
# True  | 151 | 15.42%
# ----------------------------------------------------------------------------------------------------
# Values: False, True...
#
#
# ----------------------------------------------------------------------------------------------------
# PROCESSOR_ARCHITECTURE (Total unique values: 19)
# ----------------------------------------------------------------------------------------------------
# X86                                                      | 626 | 63.94%
# ARM                                                      | 291 | 29.72%
# X86-64                                                   |  11 | 1.12%
# INTEL ATOM                                               |   9 | 0.92%
# INTEL CORE                                               |   7 | 0.72%
# INTEL HYBRID                                             |   4 | 0.41%
# AMD ZEN                                                  |   3 | 0.31%
# INTEL                                                    |   3 | 0.31%
# RISC-V                                                   |   2 | 0.20%
# XTENSA                                                   |   2 | 0.20%
# ARM CORTEX-A7                                            |   1 | 0.10%
# PICMZ                                                    |   1 | 0.10%
# 8-BIT                                                    |   1 | 0.10%
# ARM CORTEX-A53                                           |   1 | 0.10%
# AMD                                                      |   1 | 0.10%
# ARMV8                                                    |   1 | 0.10%
# INTEL XEON E AND 8TH/9TH GENERATION CORE I3/I5/I7 SERIES |   1 | 0.10%
# ARM CORTEX-A                                             |   1 | 0.10%
# 16-BIT                                                   |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
# Values: X86, ARM, X86-64, INTEL ATOM, INTEL CORE, INTEL HYBRID, AMD ZEN, INTEL, RISC-V, XTENSA, ARM CORTEX-A7, PICMZ, 8-BIT, ARM CORTEX-A53, AMD, ARMV8, INTEL XEON E AND 8TH/9TH GENERATION CORE I3/I5/I7 SERIES, ARM CORTEX-A, 16-BIT...
#
#
# ----------------------------------------------------------------------------------------------------
# PROCESSOR_CORE_COUNT (Total unique values: 30)
# ----------------------------------------------------------------------------------------------------
# 4    | 460 | 46.99%
# 2    | 202 | 20.63%
# 1    |  60 | 6.13%
# 6    |  41 | 4.19%
# 8    |  37 | 3.78%
# 24   |  15 | 1.53%
# 16   |  15 | 1.53%
# 1-14 |  12 | 1.23%
# 14   |  10 | 1.02%
# 1-16 |  10 | 1.02%
# 1-24 |   9 | 0.92%
# 6-10 |   6 | 0.61%
# 12   |   6 | 0.61%
# 1-4  |   5 | 0.51%
# 10   |   5 | 0.51%
# 9    |   2 | 0.20%
# 1-8  |   2 | 0.20%
# 128  |   2 | 0.20%
# 1-6  |   2 | 0.20%
# 1-28 |   2 | 0.20%
# 80   |   1 | 0.10%
# 3    |   1 | 0.10%
# 64   |   1 | 0.10%
# 5    |   1 | 0.10%
# 32   |   1 | 0.10%
# 2-16 |   1 | 0.10%
# 1-60 |   1 | 0.10%
# 20   |   1 | 0.10%
# 1-10 |   1 | 0.10%
# 1-32 |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
# Values: 4, 2, 1, 6, 8, 24, 16, 1-14, 14, 1-16, 1-24, 6-10, 12, 1-4, 10, 9, 1-8, 128, 1-6, 1-28, 80, 3, 64, 5, 32, 2-16, 1-60, 20, 1-10, 1-32...
#
#
# ----------------------------------------------------------------------------------------------------
# PROCESSOR_MANUFACTURER (Total unique values: 27)
# ----------------------------------------------------------------------------------------------------
# INTEL                 | 627 | 64.04%
# NXP                   | 120 | 12.26%
# AMD                   |  61 | 6.23%
# BROADCOM              |  34 | 3.47%
# ROCKCHIP              |  23 | 2.35%
# TEXAS INSTRUMENTS     |  15 | 1.53%
# FREESCALE             |  13 | 1.33%
# ARM                   |  12 | 1.23%
# ALLWINNER             |  10 | 1.02%
# NVIDIA                |   8 | 0.82%
# DMP                   |   7 | 0.72%
# STMICROELECTRONICS    |   6 | 0.61%
# RENESAS               |   6 | 0.61%
# QUALCOMM              |   5 | 0.51%
# XILINX                |   5 | 0.51%
# RABBIT                |   4 | 0.41%
# ESPRESSIF             |   4 | 0.41%
# MARVELL               |   4 | 0.41%
# MEDIATEK              |   3 | 0.31%
# RASPBERRY PI          |   3 | 0.31%
# VIA                   |   1 | 0.10%
# MICROCHIP             |   1 | 0.10%
# ATMEL                 |   1 | 0.10%
# ADVANTECH             |   1 | 0.10%
# WESTERN DESIGN CENTER |   1 | 0.10%
# KNERON                |   1 | 0.10%
# STERICSSON            |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
# Values: INTEL, NXP, AMD, BROADCOM, ROCKCHIP, TEXAS INSTRUMENTS, FREESCALE, ARM, ALLWINNER, NVIDIA, DMP, STMICROELECTRONICS, RENESAS, QUALCOMM, XILINX, RABBIT, ESPRESSIF, MARVELL, MEDIATEK, RASPBERRY PI, VIA, MICROCHIP, ATMEL, ADVANTECH, WESTERN DESIGN CENTER, KNERON, STERICSSON...
#
#
# ----------------------------------------------------------------------------------------------------
# PROCESSOR_TDP (Total unique values: 50)
# ----------------------------------------------------------------------------------------------------
# 6W                    | 102 | 10.42%
# 15W                   |  94 | 9.60%
# 35W                   |  49 | 5.01%
# 45W                   |  45 | 4.60%
# 65W                   |  38 | 3.88%
# 10W                   |  33 | 3.37%
# 95W                   |  26 | 2.66%
# 125W                  |  22 | 2.25%
# 28W                   |  20 | 2.04%
# 12W                   |  16 | 1.63%
# 0W-45W                |  12 | 1.23%
# 25W                   |  10 | 1.02%
# 6W-12W                |   9 | 0.92%
# 35W-65W               |   8 | 0.82%
# 5W                    |   6 | 0.61%
# 205W                  |   5 | 0.51%
# 15W-45W               |   5 | 0.51%
# 12W-25W               |   5 | 0.51%
# 6.7W                  |   4 | 0.41%
# 9W                    |   4 | 0.41%
# 15W-25W               |   4 | 0.41%
# 6W-45W                |   4 | 0.41%
# 31W                   |   3 | 0.31%
# 80W                   |   3 | 0.31%
# 8W                    |   3 | 0.31%
# 70W                   |   3 | 0.31%
# 25W-45W               |   3 | 0.31%
# 17W                   |   3 | 0.31%
# 5W-10W                |   3 | 0.31%
# ultra low power       |   3 | 0.31%
# 6W-10W                |   3 | 0.31%
# 19W                   |   3 | 0.31%
# 12W-54W               |   2 | 0.20%
# 2W                    |   2 | 0.20%
# 77W                   |   2 | 0.20%
# 12W-28W               |   2 | 0.20%
# 0W-125W               |   2 | 0.20%
# 10W-54W               |   2 | 0.20%
# low power consumption |   2 | 0.20%
# 1W                    |   2 | 0.20%
# 0W-13W                |   1 | 0.10%
# 13W                   |   1 | 0.10%
# 19.5W                 |   1 | 0.10%
# 7.5W                  |   1 | 0.10%
# 105W                  |   1 | 0.10%
# 0W-54W                |   1 | 0.10%
# watts                 |   1 | 0.10%
# 0W-60W                |   1 | 0.10%
# low power design      |   1 | 0.10%
# 160W                  |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
# Values: 6W, 15W, 35W, 45W, 65W, 10W, 95W, 125W, 28W, 12W, 0W-45W, 25W, 6W-12W, 35W-65W, 5W, 205W, 15W-45W, 12W-25W, 6.7W, 9W, 15W-25W, 6W-45W, 31W, 80W, 8W, 70W, 25W-45W, 17W, 5W-10W, ultra low power, 6W-10W, 19W, 12W-54W, 2W, 77W, 12W-28W, 0W-125W, 10W-54W, low power consumption, 1W, 0W-13W, 13W, 19.5W, 7.5W, 105W, 0W-54W, watts, 0W-60W, low power design, 160W...
#
#
# ----------------------------------------------------------------------------------------------------
# MEMORY (Total unique values: 50)
# ----------------------------------------------------------------------------------------------------
# 8GB                             | 150 | 15.32%
# 4GB                             | 123 | 12.56%
# 0-32GB                          |  85 | 8.68%
# 0-8GB                           |  78 | 7.97%
# 1GB                             |  66 | 6.74%
# 0-64GB                          |  66 | 6.74%
# 2GB                             |  61 | 6.23%
# 32GB                            |  43 | 4.39%
# 512MB                           |  39 | 3.98%
# 64GB                            |  38 | 3.88%
# 0-16GB                          |  34 | 3.47%
# 0-4GB                           |  30 | 3.06%
# 16GB                            |  21 | 2.15%
# 0-128GB                         |  18 | 1.84%
# 0-2GB                           |  18 | 1.84%
# 128GB                           |  10 | 1.02%
# 256MB                           |   9 | 0.92%
# 0-1GB                           |   6 | 0.61%
# 0-512GB                         |   4 | 0.41%
# 0-512MB                         |   4 | 0.41%
# 3GB                             |   3 | 0.31%
# DDR4, DDR5                      |   3 | 0.31%
# 512K SRAM                       |   3 | 0.31%
# 0-6TB                           |   2 | 0.20%
# 1MB                             |   2 | 0.20%
# 264KB SRAM                      |   2 | 0.20%
# 128MB                           |   2 | 0.20%
# DDR3L SODIMM                    |   2 | 0.20%
# DDR4 SODIMM                     |   2 | 0.20%
# 0-768GB                         |   2 | 0.20%
# 64MB                            |   2 | 0.20%
# DDR4 ECC/NON-ECC 2133 MHZ UDIMM |   2 | 0.20%
# 512GB                           |   2 | 0.20%
# MB RAM                          |   2 | 0.20%
# 0-96GB                          |   2 | 0.20%
# DDR SODIMM                      |   1 | 0.10%
# ONBOARD DDR3L                   |   1 | 0.10%
# 136 KB SRAM                     |   1 | 0.10%
# 16MB                            |   1 | 0.10%
# 256 KB FLASH, 64 KB SRAM        |   1 | 0.10%
# 16 KB EEPROM, 64 KB FLASH       |   1 | 0.10%
# DDR4 RDIMM/LRDIMM               |   1 | 0.10%
# DDR4 SODIMM SOCKETS             |   1 | 0.10%
# DDR3 SODIMM, 1066 MHZ           |   1 | 0.10%
# LPDDR                           |   1 | 0.10%
# 576 BYTES OF STATIC RAM         |   1 | 0.10%
# SODIMM                          |   1 | 0.10%
# KB SRAM                         |   1 | 0.10%
# 400 KB                          |   1 | 0.10%
# 520 KB SRAM                     |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
# Values: 8GB, 4GB, 0-32GB, 0-8GB, 1GB, 0-64GB, 2GB, 32GB, 512MB, 64GB, 0-16GB, 0-4GB, 16GB, 0-128GB, 0-2GB, 128GB, 256MB, 0-1GB, 0-512GB, 0-512MB, 3GB, DDR4, DDR5, 512K SRAM, 0-6TB, 1MB, 264KB SRAM, 128MB, DDR3L SODIMM, DDR4 SODIMM, 0-768GB, 64MB, DDR4 ECC/NON-ECC 2133 MHZ UDIMM, 512GB, MB RAM, 0-96GB, DDR SODIMM, ONBOARD DDR3L, 136 KB SRAM, 16MB, 256 KB FLASH, 64 KB SRAM, 16 KB EEPROM, 64 KB FLASH, DDR4 RDIMM/LRDIMM, DDR4 SODIMM SOCKETS, DDR3 SODIMM, 1066 MHZ, LPDDR, 576 BYTES OF STATIC RAM, SODIMM, KB SRAM, 400 KB, 520 KB SRAM...
#
#
# ----------------------------------------------------------------------------------------------------
# ONBOARD_STORAGE (Total unique values: 50)
# ----------------------------------------------------------------------------------------------------
# 64GB EMMC                                        | 82 | 8.38%
# 16GB EMMC                                        | 54 | 5.52%
# MSATA                                            | 49 | 5.01%
# 8GB EMMC                                         | 26 | 2.66%
# EMMC                                             | 20 | 2.04%
# 32GB EMMC                                        | 19 | 1.94%
# NVME SSD                                         | 19 | 1.94%
# EMMC 64GB                                        | 15 | 1.53%
# 8GB EMMC NAND                                    | 11 | 1.12%
# COMPACTFLASH TYPE III                            | 10 | 1.02%
# NON-VOLATILE USER DATA STORAGE                   |  9 | 0.92%
# 1TB NVME SSD                                     |  8 | 0.82%
# COMPACTFLASH SOCKET                              |  7 | 0.72%
# 32GB/S M.2                                       |  7 | 0.72%
# 128GB EMMC FLASH                                 |  6 | 0.61%
# MSATA SUPPORT                                    |  6 | 0.61%
# 4GB EMMC NAND                                    |  6 | 0.61%
# 4GB EMMC FLASH                                   |  6 | 0.61%
# EMMC 8GB                                         |  5 | 0.51%
# 4GB NAND                                         |  5 | 0.51%
# 64GB SSD                                         |  5 | 0.51%
# 64GB EMMC 128GB M.2 SSD                          |  5 | 0.51%
# 4GB EMMC                                         |  5 | 0.51%
# MICRO SD CARD SLOT                               |  5 | 0.51%
# EMMC SSD                                         |  4 | 0.41%
# CF SOCKET                                        |  4 | 0.41%
# FLASH                                            |  4 | 0.41%
# 8GB/16GB/32GB EMMC                               |  4 | 0.41%
# EMMC 5.0 HIGH-SPEED DRIVE 32GB SOLDERED ON BOARD |  4 | 0.41%
# EIGHT SATA 3 AND ONE M.2 CONNECTORS              |  4 | 0.41%
# MSATA SUPPORTED                                  |  4 | 0.41%
# 1 X MSATA                                        |  4 | 0.41%
# MICROSD CARD SLOT                                |  4 | 0.41%
# 256MB NAND                                       |  3 | 0.31%
# CFAST MSATA                                      |  3 | 0.31%
# NVME 256GB                                       |  3 | 0.31%
# 1GB                                              |  3 | 0.31%
# 16GBS EMMC                                       |  3 | 0.31%
# SOLDERED EMMC 5.0 32GB                           |  3 | 0.31%
# 64GBS EMMC                                       |  3 | 0.31%
# 8GB/16GB/32GB 64GB OR 128GB EMMC FLASH           |  3 | 0.31%
# MLC 8GB SLC 4GB                                  |  3 | 0.31%
# MSATA SATA                                       |  3 | 0.31%
# 16GB EMMC NAND                                   |  3 | 0.31%
# CFAST TYPE III                                   |  3 | 0.31%
# MSATA AND SATA HDD                               |  3 | 0.31%
# EMMC 32GB                                        |  3 | 0.31%
# 32GBS EMMC                                       |  3 | 0.31%
# EMMC 5.1 ON BOARD MASS STORAGE                   |  3 | 0.31%
# MICROSD SLOT                                     |  3 | 0.31%
# ----------------------------------------------------------------------------------------------------
# Values: 64GB EMMC, 16GB EMMC, MSATA, 8GB EMMC, EMMC, 32GB EMMC, NVME SSD, EMMC 64GB, 8GB EMMC NAND, COMPACTFLASH TYPE III, NON-VOLATILE USER DATA STORAGE, 1TB NVME SSD, COMPACTFLASH SOCKET, 32GB/S M.2, 128GB EMMC FLASH, MSATA SUPPORT, 4GB EMMC NAND, 4GB EMMC FLASH, EMMC 8GB, 4GB NAND, 64GB SSD, 64GB EMMC 128GB M.2 SSD, 4GB EMMC, MICRO SD CARD SLOT, EMMC SSD, CF SOCKET, FLASH, 8GB/16GB/32GB EMMC, EMMC 5.0 HIGH-SPEED DRIVE 32GB SOLDERED ON BOARD, EIGHT SATA 3 AND ONE M.2 CONNECTORS, MSATA SUPPORTED, 1 X MSATA, MICROSD CARD SLOT, 256MB NAND, CFAST MSATA, NVME 256GB, 1GB, 16GBS EMMC, SOLDERED EMMC 5.0 32GB, 64GBS EMMC, 8GB/16GB/32GB 64GB OR 128GB EMMC FLASH, MLC 8GB SLC 4GB, MSATA SATA, 16GB EMMC NAND, CFAST TYPE III, MSATA AND SATA HDD, EMMC 32GB, 32GBS EMMC, EMMC 5.1 ON BOARD MASS STORAGE, MICROSD SLOT...
#
#
# ----------------------------------------------------------------------------------------------------
# INPUT_VOLTAGE (Total unique values: 50)
# ----------------------------------------------------------------------------------------------------
# 12V                              | 517 | 52.81%
# 5V                               | 239 | 24.41%
# 3.3V                             |  33 | 3.37%
# 9V-36V                           |  28 | 2.86%
# 24V                              |  23 | 2.35%
# 100V-240V                        |  17 | 1.74%
# 12V-24V                          |  14 | 1.43%
# 8V-60V                           |  12 | 1.23%
# 19V                              |   6 | 0.61%
# ATX                              |   6 | 0.61%
# 8V-30V                           |   5 | 0.51%
# ATX POWER SUPPLY                 |   4 | 0.41%
# 12V-28V                          |   2 | 0.20%
# 3.0V                             |   2 | 0.20%
# ATX/AT POWER SUPPLY              |   2 | 0.20%
# AC                               |   2 | 0.20%
# 8.5V                             |   2 | 0.20%
# 36V                              |   2 | 0.20%
# 1.2V                             |   1 | 0.10%
# 5.0V                             |   1 | 0.10%
# 2.8V                             |   1 | 0.10%
# WIDE VOLTAGE INPUT RANGE         |   1 | 0.10%
# 9V                               |   1 | 0.10%
# 3.0V-3.6V                        |   1 | 0.10%
# 7V-12V                           |   1 | 0.10%
# DC POWER                         |   1 | 0.10%
# STANDARD 20-PIN ATX POWER SUPPLY |   1 | 0.10%
# 4.2V-5.5V                        |   1 | 0.10%
# 9V-15V                           |   1 | 0.10%
# ATX/AT                           |   1 | 0.10%
# 7V-36V                           |   1 | 0.10%
# DC POWER INPUT                   |   1 | 0.10%
# 30V                              |   1 | 0.10%
# 8V                               |   1 | 0.10%
# 48V                              |   1 | 0.10%
# 12V-60V                          |   1 | 0.10%
# 12V-48V                          |   1 | 0.10%
# 9V-34V                           |   1 | 0.10%
# 4.75V-20V                        |   1 | 0.10%
# 24 + 8-PIN ATX POWER INPUT       |   1 | 0.10%
# 10% TO 90% OF NOMINAL VOLTAGE    |   1 | 0.10%
# VDC                              |   1 | 0.10%
# 10% TO 90% OF NOMINAL            |   1 | 0.10%
# 21V                              |   1 | 0.10%
# AT/ATX POWER SUPPLY              |   1 | 0.10%
# 3.6V                             |   1 | 0.10%
# 3V                               |   1 | 0.10%
# 34V                              |   1 | 0.10%
# 1.7V-5.5V                        |   1 | 0.10%
# 2.0V                             |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
# Values: 12V, 5V, 3.3V, 9V-36V, 24V, 100V-240V, 12V-24V, 8V-60V, 19V, ATX, 8V-30V, ATX POWER SUPPLY, 12V-28V, 3.0V, ATX/AT POWER SUPPLY, AC, 8.5V, 36V, 1.2V, 5.0V, 2.8V, WIDE VOLTAGE INPUT RANGE, 9V, 3.0V-3.6V, 7V-12V, DC POWER, STANDARD 20-PIN ATX POWER SUPPLY, 4.2V-5.5V, 9V-15V, ATX/AT, 7V-36V, DC POWER INPUT, 30V, 8V, 48V, 12V-60V, 12V-48V, 9V-34V, 4.75V-20V, 24 + 8-PIN ATX POWER INPUT, 10% TO 90% OF NOMINAL VOLTAGE, VDC, 10% TO 90% OF NOMINAL, 21V, AT/ATX POWER SUPPLY, 3.6V, 3V, 34V, 1.7V-5.5V, 2.0V...
#
#
# ----------------------------------------------------------------------------------------------------
# IO_COUNT (Total unique values: 50)
# ----------------------------------------------------------------------------------------------------
# ('USB',)                                            | 114 | 11.64%
# ('USB 3.0',)                                        |  77 | 7.87%
# ('USB 2.0',)                                        |  72 | 7.35%
# ()                                                  |  68 | 6.95%
# ('USB 1.0',)                                        |  28 | 2.86%
# ('USB 3.2',)                                        |  27 | 2.76%
# ('OTHER',)                                          |  24 | 2.45%
# ('USB 3.1',)                                        |  21 | 2.15%
# ('OTHER', 'USB')                                    |  17 | 1.74%
# ('SERIAL', 'USB')                                   |  12 | 1.23%
# ('SATA', 'ETHERNET', 'USB', 'PCIE')                 |  12 | 1.23%
# ('SERIAL', 'USB', 'OTHER')                          |  11 | 1.12%
# ('GPIO',)                                           |  11 | 1.12%
# ('OTHER', 'USB 3.0')                                |   9 | 0.92%
# ('DISPLAY', 'ETHERNET', 'USB', 'SERIAL')            |   9 | 0.92%
# ('SERIAL', 'ETHERNET', 'USB', 'OTHER_BUS')          |   7 | 0.72%
# ('SERIAL', 'ETHERNET', 'USB')                       |   7 | 0.72%
# ('OTHER', 'ETHERNET', 'USB')                        |   7 | 0.72%
# ('OTHER', 'ETHERNET', 'OTHER_BUS', 'SERIAL', 'USB') |   6 | 0.61%
# ('OTHER', 'USB 2.0')                                |   6 | 0.61%
# ('SERIAL', 'ETHERNET', 'USB', 'SATA')               |   5 | 0.51%
# ('DISPLAY', 'ETHERNET', 'AUDIO', 'SERIAL', 'USB')   |   5 | 0.51%
# ('SERIAL', 'USB', 'SATA')                           |   5 | 0.51%
# ('DISPLAY', 'ETHERNET', 'OTHER', 'SERIAL', 'USB')   |   5 | 0.51%
# ('ETHERNET', 'USB 3.0')                             |   5 | 0.51%
# ('SERIAL', 'USB 2.0', 'OTHER')                      |   4 | 0.41%
# ('OTHER', 'USB 2.0', 'PCIE', 'SATA 3.0', 'USB 3.0') |   4 | 0.41%
# ('OTHER', 'USB', 'SERIAL')                          |   4 | 0.41%
# ('PCIE', 'USB 3.2')                                 |   4 | 0.41%
# ('GPIO', 'USB 2.0')                                 |   4 | 0.41%
# ('DISPLAY', 'USB', 'SERIAL')                        |   4 | 0.41%
# ('OTHER', 'PCIE 4', 'USB 3.2')                      |   4 | 0.41%
# ('USB 2.0', 'PCIE')                                 |   4 | 0.41%
# ('OTHER', 'ETHERNET', 'USB 2.0')                    |   3 | 0.31%
# ('USB 3.2', 'ETHERNET', 'SATA 3.0', 'PCIE')         |   3 | 0.31%
# ('PCIE', 'USB', 'SATA')                             |   3 | 0.31%
# ('OTHER', 'ETHERNET', 'USB', 'SATA')                |   3 | 0.31%
# ('SERIAL', 'ETHERNET', 'USB', 'OTHER')              |   3 | 0.31%
# ('USB 3.1', 'SATA 3.0')                             |   3 | 0.31%
# ('USB 4.0',)                                        |   3 | 0.31%
# ('ETHERNET', 'USB', 'SATA', 'PCIE')                 |   3 | 0.31%
# ('OTHER', 'USB', 'SERIAL', 'OTHER_BUS')             |   3 | 0.31%
# ('OTHER', 'USB', 'SATA')                            |   3 | 0.31%
# ('OTHER', 'DISPLAY', 'USB', 'SERIAL')               |   3 | 0.31%
# ('SERIAL', 'ETHERNET', 'USB', 'DISPLAY')            |   3 | 0.31%
# ('OTHER', 'PCIE', 'OTHER_BUS', 'SERIAL', 'USB')     |   3 | 0.31%
# ('OTHER', 'USB', 'GPIO')                            |   3 | 0.31%
# ('ETHERNET', 'USB')                                 |   3 | 0.31%
# ('SERIAL', 'ETHERNET', 'USB 2.0', 'USB 3.0')        |   3 | 0.31%
# ('ETHERNET', 'USB 3.2')                             |   3 | 0.31%
# ----------------------------------------------------------------------------------------------------
# Values: ('USB',), ('USB 3.0',), ('USB 2.0',), (), ('USB 1.0',), ('USB 3.2',), ('OTHER',), ('USB 3.1',), ('OTHER', 'USB'), ('SERIAL', 'USB'), ('SATA', 'ETHERNET', 'USB', 'PCIE'), ('SERIAL', 'USB', 'OTHER'), ('GPIO',), ('OTHER', 'USB 3.0'), ('DISPLAY', 'ETHERNET', 'USB', 'SERIAL'), ('SERIAL', 'ETHERNET', 'USB', 'OTHER_BUS'), ('SERIAL', 'ETHERNET', 'USB'), ('OTHER', 'ETHERNET', 'USB'), ('OTHER', 'ETHERNET', 'OTHER_BUS', 'SERIAL', 'USB'), ('OTHER', 'USB 2.0'), ('SERIAL', 'ETHERNET', 'USB', 'SATA'), ('DISPLAY', 'ETHERNET', 'AUDIO', 'SERIAL', 'USB'), ('SERIAL', 'USB', 'SATA'), ('DISPLAY', 'ETHERNET', 'OTHER', 'SERIAL', 'USB'), ('ETHERNET', 'USB 3.0'), ('SERIAL', 'USB 2.0', 'OTHER'), ('OTHER', 'USB 2.0', 'PCIE', 'SATA 3.0', 'USB 3.0'), ('OTHER', 'USB', 'SERIAL'), ('PCIE', 'USB 3.2'), ('GPIO', 'USB 2.0'), ('DISPLAY', 'USB', 'SERIAL'), ('OTHER', 'PCIE 4', 'USB 3.2'), ('USB 2.0', 'PCIE'), ('OTHER', 'ETHERNET', 'USB 2.0'), ('USB 3.2', 'ETHERNET', 'SATA 3.0', 'PCIE'), ('PCIE', 'USB', 'SATA'), ('OTHER', 'ETHERNET', 'USB', 'SATA'), ('SERIAL', 'ETHERNET', 'USB', 'OTHER'), ('USB 3.1', 'SATA 3.0'), ('USB 4.0',), ('ETHERNET', 'USB', 'SATA', 'PCIE'), ('OTHER', 'USB', 'SERIAL', 'OTHER_BUS'), ('OTHER', 'USB', 'SATA'), ('OTHER', 'DISPLAY', 'USB', 'SERIAL'), ('SERIAL', 'ETHERNET', 'USB', 'DISPLAY'), ('OTHER', 'PCIE', 'OTHER_BUS', 'SERIAL', 'USB'), ('OTHER', 'USB', 'GPIO'), ('ETHERNET', 'USB'), ('SERIAL', 'ETHERNET', 'USB 2.0', 'USB 3.0'), ('ETHERNET', 'USB 3.2')...
#
#
# ----------------------------------------------------------------------------------------------------
# WIRELESS (Total unique values: 50)
# ----------------------------------------------------------------------------------------------------
# ()                                               | 320 | 32.69%
# ('WI-FI',)                                       | 189 | 19.31%
# ('WI-FI', 'BLUETOOTH')                           | 111 | 11.34%
# ('OTHER',)                                       |  84 | 8.58%
# ('WI-FI 5',)                                     |  27 | 2.76%
# ('WI-FI 6',)                                     |  26 | 2.66%
# ('WI-FI', 'CELLULAR', 'BLUETOOTH')               |  22 | 2.25%
# ('WI-FI 5', 'BLUETOOTH')                         |  15 | 1.53%
# ('5G',)                                          |  14 | 1.43%
# ('4G/LTE', 'WI-FI', 'BLUETOOTH')                 |  14 | 1.43%
# ('WI-FI', 'OTHER', 'BLUETOOTH')                  |  12 | 1.23%
# ('BLUETOOTH 5+', 'WI-FI')                        |   9 | 0.92%
# ('WI-FI 5', 'BLUETOOTH 4')                       |   8 | 0.82%
# ('WI-FI 5', 'BLUETOOTH 5+')                      |   7 | 0.72%
# ('WI-FI', 'BLUETOOTH 4')                         |   7 | 0.72%
# ('WI-FI', '3G')                                  |   6 | 0.61%
# ('WI-FI', 'OTHER')                               |   6 | 0.61%
# ('WI-FI 5', 'OTHER', 'BLUETOOTH 5+')             |   6 | 0.61%
# ('4G/LTE',)                                      |   6 | 0.61%
# ('4G/LTE', 'WI-FI')                              |   5 | 0.51%
# ('WI-FI', 'GPS', 'BLUETOOTH')                    |   5 | 0.51%
# ('WI-FI 6', 'BLUETOOTH 5+')                      |   4 | 0.41%
# ('BLUETOOTH 5+', 'OTHER')                        |   4 | 0.41%
# ('WI-FI 5', 'OTHER')                             |   4 | 0.41%
# ('WI-FI', 'CELLULAR')                            |   3 | 0.31%
# ('OTHER', 'LORA', 'BLUETOOTH')                   |   2 | 0.20%
# ('OTHER', 'LORA')                                |   2 | 0.20%
# ('CELLULAR',)                                    |   2 | 0.20%
# ('4G/LTE', 'WI-FI', 'LORA', 'OTHER')             |   2 | 0.20%
# ('WI-FI 6', '5G', 'ZIGBEE', 'BLUETOOTH', 'LORA') |   2 | 0.20%
# ('WI-FI 6', '5G')                                |   2 | 0.20%
# ('WI-FI', 'GPS')                                 |   2 | 0.20%
# ('OTHER', 'NFC', 'BLUETOOTH')                    |   2 | 0.20%
# ('WI-FI 5', 'OTHER', 'BLUETOOTH 4')              |   2 | 0.20%
# ('WI-FI', '3G', 'BLUETOOTH')                     |   1 | 0.10%
# ('OTHER', 'BLUETOOTH 4')                         |   1 | 0.10%
# ('4G/LTE', 'WI-FI', 'ZIGBEE', 'NFC')             |   1 | 0.10%
# ('OTHER', 'GPS', 'BLUETOOTH 4')                  |   1 | 0.10%
# ('WI-FI', 'GPS', 'NFC', 'BLUETOOTH 4')           |   1 | 0.10%
# ('BLUETOOTH 5+', 'WI-FI', 'BLUETOOTH 4')         |   1 | 0.10%
# ('OTHER', 'BLUETOOTH')                           |   1 | 0.10%
# ('4G/LTE', 'OTHER', 'BLUETOOTH')                 |   1 | 0.10%
# ('3G',)                                          |   1 | 0.10%
# ('BLUETOOTH 5+', 'WI-FI', 'OTHER')               |   1 | 0.10%
# ('WI-FI 5', 'BLUETOOTH 4', '3G')                 |   1 | 0.10%
# ('CELLULAR', 'GPS', 'WI-FI')                     |   1 | 0.10%
# ('4G/LTE', 'WI-FI', 'ZIGBEE')                    |   1 | 0.10%
# ('CELLULAR', 'GPS', 'BLUETOOTH')                 |   1 | 0.10%
# ('BLUETOOTH 5+',)                                |   1 | 0.10%
# ('WI-FI', 'CELLULAR', 'OTHER', 'BLUETOOTH')      |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
# Values: (), ('WI-FI',), ('WI-FI', 'BLUETOOTH'), ('OTHER',), ('WI-FI 5',), ('WI-FI 6',), ('WI-FI', 'CELLULAR', 'BLUETOOTH'), ('WI-FI 5', 'BLUETOOTH'), ('5G',), ('4G/LTE', 'WI-FI', 'BLUETOOTH'), ('WI-FI', 'OTHER', 'BLUETOOTH'), ('BLUETOOTH 5+', 'WI-FI'), ('WI-FI 5', 'BLUETOOTH 4'), ('WI-FI 5', 'BLUETOOTH 5+'), ('WI-FI', 'BLUETOOTH 4'), ('WI-FI', '3G'), ('WI-FI', 'OTHER'), ('WI-FI 5', 'OTHER', 'BLUETOOTH 5+'), ('4G/LTE',), ('4G/LTE', 'WI-FI'), ('WI-FI', 'GPS', 'BLUETOOTH'), ('WI-FI 6', 'BLUETOOTH 5+'), ('BLUETOOTH 5+', 'OTHER'), ('WI-FI 5', 'OTHER'), ('WI-FI', 'CELLULAR'), ('OTHER', 'LORA', 'BLUETOOTH'), ('OTHER', 'LORA'), ('CELLULAR',), ('4G/LTE', 'WI-FI', 'LORA', 'OTHER'), ('WI-FI 6', '5G', 'ZIGBEE', 'BLUETOOTH', 'LORA'), ('WI-FI 6', '5G'), ('WI-FI', 'GPS'), ('OTHER', 'NFC', 'BLUETOOTH'), ('WI-FI 5', 'OTHER', 'BLUETOOTH 4'), ('WI-FI', '3G', 'BLUETOOTH'), ('OTHER', 'BLUETOOTH 4'), ('4G/LTE', 'WI-FI', 'ZIGBEE', 'NFC'), ('OTHER', 'GPS', 'BLUETOOTH 4'), ('WI-FI', 'GPS', 'NFC', 'BLUETOOTH 4'), ('BLUETOOTH 5+', 'WI-FI', 'BLUETOOTH 4'), ('OTHER', 'BLUETOOTH'), ('4G/LTE', 'OTHER', 'BLUETOOTH'), ('3G',), ('BLUETOOTH 5+', 'WI-FI', 'OTHER'), ('WI-FI 5', 'BLUETOOTH 4', '3G'), ('CELLULAR', 'GPS', 'WI-FI'), ('4G/LTE', 'WI-FI', 'ZIGBEE'), ('CELLULAR', 'GPS', 'BLUETOOTH'), ('BLUETOOTH 5+',), ('WI-FI', 'CELLULAR', 'OTHER', 'BLUETOOTH')...
#
#
# ----------------------------------------------------------------------------------------------------
# OPERATING_SYSTEM_BSP (Total unique values: 50)
# ----------------------------------------------------------------------------------------------------
# ()                                                            | 109 | 11.13%
# ('OTHER',)                                                    |  92 | 9.40%
# ('LINUX',)                                                    |  67 | 6.84%
# ('LINUX', 'WINDOWS')                                          |  61 | 6.23%
# ('ANDROID', 'LINUX')                                          |  42 | 4.29%
# ('WINDOWS',)                                                  |  28 | 2.86%
# ('OTHER', 'WINDOWS 10')                                       |  25 | 2.55%
# ('WINDOWS 10',)                                               |  23 | 2.35%
# ('OTHER', 'ANDROID', 'LINUX')                                 |  23 | 2.35%
# ('RASPBERRY PI OS',)                                          |  22 | 2.25%
# ('WINDOWS EMBEDDED',)                                         |  21 | 2.15%
# ('OTHER', 'LINUX')                                            |  19 | 1.94%
# ('LINUX', 'WINDOWS 10')                                       |  18 | 1.84%
# ('LINUX', 'WINDOWS IOT')                                      |  18 | 1.84%
# ('LINUX', 'WINDOWS EMBEDDED')                                 |  18 | 1.84%
# ('VXWORKS', 'LINUX', 'WINDOWS')                               |  18 | 1.84%
# ('WINDOWS IOT',)                                              |  17 | 1.74%
# ('LINUX', 'WINDOWS', 'VXWORKS', 'QNX', 'WINDOWS EMBEDDED')    |  14 | 1.43%
# ('OTHER', 'LINUX', 'WINDOWS')                                 |  14 | 1.43%
# ('OTHER', 'WINDOWS IOT')                                      |  13 | 1.33%
# ('OTHER', 'ANDROID')                                          |  13 | 1.33%
# ('YOCTO LINUX',)                                              |  12 | 1.23%
# ('UBUNTU', 'WINDOWS 10')                                      |  11 | 1.12%
# ('VXWORKS', 'LINUX', 'WINDOWS', 'WINDOWS EMBEDDED')           |   9 | 0.92%
# ('OTHER', 'LINUX', 'WINDOWS IOT')                             |   8 | 0.82%
# ('LINUX', 'WINDOWS IOT', 'WINDOWS 10')                        |   7 | 0.72%
# ('OTHER', 'WINDOWS EMBEDDED')                                 |   7 | 0.72%
# ('OTHER', 'WINDOWS')                                          |   7 | 0.72%
# ('QNX', 'LINUX', 'WINDOWS', 'VXWORKS')                        |   6 | 0.61%
# ('OTHER', 'UBUNTU')                                           |   6 | 0.61%
# ('UBUNTU',)                                                   |   6 | 0.61%
# ('VXWORKS', 'UBUNTU', 'WINDOWS EMBEDDED')                     |   6 | 0.61%
# ('OTHER', 'ANDROID', 'LINUX', 'WINDOWS')                      |   5 | 0.51%
# ('DEBIAN',)                                                   |   5 | 0.51%
# ('OTHER', 'ANDROID', 'WINDOWS IOT', 'LINUX', 'WINDOWS')       |   5 | 0.51%
# ('WINDOWS', 'WINDOWS 10')                                     |   5 | 0.51%
# ('OTHER', 'LINUX', 'WINDOWS 10')                              |   4 | 0.41%
# ('LINUX', 'WINDOWS', 'WINDOWS 10')                            |   4 | 0.41%
# ('WINDOWS', 'WINDOWS EMBEDDED')                               |   4 | 0.41%
# ('LINUX', 'WINDOWS', 'WINDOWS EMBEDDED')                      |   4 | 0.41%
# ('WINDOWS', 'UBUNTU')                                         |   4 | 0.41%
# ('ANDROID', 'LINUX', 'WINDOWS EMBEDDED')                      |   4 | 0.41%
# ('VXWORKS', 'LINUX', 'WINDOWS EMBEDDED')                      |   4 | 0.41%
# ('LINUX', 'WINDOWS', 'WINDOWS IOT')                           |   4 | 0.41%
# ('UBUNTU', 'WINDOWS', 'WINDOWS 10')                           |   4 | 0.41%
# ('ANDROID', 'LINUX', 'QNX')                                   |   3 | 0.31%
# ('OTHER', 'RASPBERRY PI OS')                                  |   3 | 0.31%
# ('OTHER', 'WINDOWS 10', 'WINDOWS IOT', 'LINUX', 'WINDOWS 11') |   3 | 0.31%
# ('WINDOWS SERVER', 'WINDOWS 10')                              |   3 | 0.31%
# ('UBUNTU', 'WINDOWS EMBEDDED')                                |   3 | 0.31%
# ----------------------------------------------------------------------------------------------------
# Values: (), ('OTHER',), ('LINUX',), ('LINUX', 'WINDOWS'), ('ANDROID', 'LINUX'), ('WINDOWS',), ('OTHER', 'WINDOWS 10'), ('WINDOWS 10',), ('OTHER', 'ANDROID', 'LINUX'), ('RASPBERRY PI OS',), ('WINDOWS EMBEDDED',), ('OTHER', 'LINUX'), ('LINUX', 'WINDOWS 10'), ('LINUX', 'WINDOWS IOT'), ('LINUX', 'WINDOWS EMBEDDED'), ('VXWORKS', 'LINUX', 'WINDOWS'), ('WINDOWS IOT',), ('LINUX', 'WINDOWS', 'VXWORKS', 'QNX', 'WINDOWS EMBEDDED'), ('OTHER', 'LINUX', 'WINDOWS'), ('OTHER', 'WINDOWS IOT'), ('OTHER', 'ANDROID'), ('YOCTO LINUX',), ('UBUNTU', 'WINDOWS 10'), ('VXWORKS', 'LINUX', 'WINDOWS', 'WINDOWS EMBEDDED'), ('OTHER', 'LINUX', 'WINDOWS IOT'), ('LINUX', 'WINDOWS IOT', 'WINDOWS 10'), ('OTHER', 'WINDOWS EMBEDDED'), ('OTHER', 'WINDOWS'), ('QNX', 'LINUX', 'WINDOWS', 'VXWORKS'), ('OTHER', 'UBUNTU'), ('UBUNTU',), ('VXWORKS', 'UBUNTU', 'WINDOWS EMBEDDED'), ('OTHER', 'ANDROID', 'LINUX', 'WINDOWS'), ('DEBIAN',), ('OTHER', 'ANDROID', 'WINDOWS IOT', 'LINUX', 'WINDOWS'), ('WINDOWS', 'WINDOWS 10'), ('OTHER', 'LINUX', 'WINDOWS 10'), ('LINUX', 'WINDOWS', 'WINDOWS 10'), ('WINDOWS', 'WINDOWS EMBEDDED'), ('LINUX', 'WINDOWS', 'WINDOWS EMBEDDED'), ('WINDOWS', 'UBUNTU'), ('ANDROID', 'LINUX', 'WINDOWS EMBEDDED'), ('VXWORKS', 'LINUX', 'WINDOWS EMBEDDED'), ('LINUX', 'WINDOWS', 'WINDOWS IOT'), ('UBUNTU', 'WINDOWS', 'WINDOWS 10'), ('ANDROID', 'LINUX', 'QNX'), ('OTHER', 'RASPBERRY PI OS'), ('OTHER', 'WINDOWS 10', 'WINDOWS IOT', 'LINUX', 'WINDOWS 11'), ('WINDOWS SERVER', 'WINDOWS 10'), ('UBUNTU', 'WINDOWS EMBEDDED')...
#
#
# ----------------------------------------------------------------------------------------------------
# OPERATING_TEMPERATURE_MAX (Total unique values: 21)
# ----------------------------------------------------------------------------------------------------
# 60°C  | 504 | 51.48%
# 85°C  | 340 | 34.73%
# 70°C  |  54 | 5.52%
# 50°C  |  18 | 1.84%
# 40°C  |  15 | 1.53%
# 75°C  |   6 | 0.61%
# 125°C |   4 | 0.41%
# 55°C  |   4 | 0.41%
# 105°C |   3 | 0.31%
# 35°C  |   3 | 0.31%
# 100°C |   2 | 0.20%
# 85℃   |   2 | 0.20%
# 83°C  |   1 | 0.10%
# +80℃  |   1 | 0.10%
# 65°C  |   1 | 0.10%
# 90°C  |   1 | 0.10%
# 45°C  |   1 | 0.10%
# 80°C  |   1 | 0.10%
# 85OC  |   1 | 0.10%
# 95°C  |   1 | 0.10%
# 70℃   |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
# Values: 60°C, 85°C, 70°C, 50°C, 40°C, 75°C, 125°C, 55°C, 105°C, 35°C, 100°C, 85℃, 83°C, +80℃, 65°C, 90°C, 45°C, 80°C, 85OC, 95°C, 70℃...
#
#
# ----------------------------------------------------------------------------------------------------
# OPERATING_TEMPERATURE_MIN (Total unique values: 10)
# ----------------------------------------------------------------------------------------------------
# -40°C | 384 | 39.22%
# 0°C   | 373 | 38.10%
# -20°C | 161 | 16.45%
# -25°C |  17 | 1.74%
# -30°C |  10 | 1.02%
# -10°C |   8 | 0.82%
# -40℃  |   3 | 0.31%
# 5°C   |   2 | 0.20%
# -40OC |   1 | 0.10%
# -20℃  |   1 | 0.10%
# ----------------------------------------------------------------------------------------------------
# Values: -40°C, 0°C, -20°C, -25°C, -30°C, -10°C, -40℃, 5°C, -40OC, -20℃...
#
#
# ----------------------------------------------------------------------------------------------------
# CERTIFICATIONS (Total unique values: 50)
# ----------------------------------------------------------------------------------------------------
# ()                                                                   | 221 | 22.57%
# ('CE', 'FCC')                                                        |  67 | 6.84%
# ('ROHS',)                                                            |  42 | 4.29%
# ('ROHS COMPLIANT',)                                                  |  31 | 3.17%
# ('CE', 'FCC CLASS B')                                                |  29 | 2.96%
# ('CE/FCC',)                                                          |  22 | 2.25%
# ('CE', 'FCC', 'ROHS')                                                |  15 | 1.53%
# ('CE', 'FCC CLASS B', 'ROHS COMPLIANT')                              |  13 | 1.33%
# ('CE', 'FCC CLASS A')                                                |  13 | 1.33%
# ('ROHS', 'CE', 'FCC CLASS B')                                        |  13 | 1.33%
# ('FCC CLASS B',)                                                     |  11 | 1.12%
# ('CE/FCC CLASS B',)                                                  |  10 | 1.02%
# ('CE', 'FCC', 'UL', 'CCC', 'BSMI')                                   |  10 | 1.02%
# ('ROHS COMPLIANT 2002/95/EC',)                                       |  10 | 1.02%
# ('IEC 60068-2-27', 'IEC 60068-2-64', 'MIL-STD-810F')                 |   9 | 0.92%
# ('FCC CLASS A',)                                                     |   9 | 0.92%
# ('CE',)                                                              |   9 | 0.92%
# ('MIL-STD-810G',)                                                    |   8 | 0.82%
# ('FCC', 'CE')                                                        |   8 | 0.82%
# ('FCC PART 15',)                                                     |   8 | 0.82%
# ('MODULAR COMPLIANCE CERTIFICATION',)                                |   8 | 0.82%
# ('CE/FCC CLASS A',)                                                  |   7 | 0.72%
# ('ROHS', 'REACH')                                                    |   6 | 0.61%
# ('CE CLASS B', 'FCC CLASS B')                                        |   6 | 0.61%
# ('CE', 'FCC CLASS A', 'CCC', 'BSMI', 'UL')                           |   6 | 0.61%
# ('MIL-STD-810G COMPLIANCE',)                                         |   5 | 0.51%
# ('FCC',)                                                             |   5 | 0.51%
# ('IPC-A-610G CLASS 3',)                                              |   5 | 0.51%
# ('CE', 'FCC', 'EAC', 'ROHS', 'UL', 'CUL')                            |   5 | 0.51%
# ('EN50155', 'EN45545', 'E-MARK')                                     |   5 | 0.51%
# ('FCC', 'CHINA ROHS')                                                |   4 | 0.41%
# ('IEC', 'MIL-STD-810F')                                              |   4 | 0.41%
# ('CLASS I', 'DIVISION 2 (CID2) & ATEX SOLUTIONS')                    |   4 | 0.41%
# ('ROHS', 'MIL-STD-810G')                                             |   4 | 0.41%
# ('DIN EN ISO 9001',)                                                 |   4 | 0.41%
# ('ROHS COMPLIANCE',)                                                 |   4 | 0.41%
# ('ROHS COMPLIANT', 'MIL-STD-810G')                                   |   4 | 0.41%
# ('CE', 'LVD', 'FCC CLASS B')                                         |   3 | 0.31%
# ('ROHS', 'REACH', 'PICMG COM EXPRESS R2.1')                          |   3 | 0.31%
# ('ROHS', 'MIL-STD-810H')                                             |   3 | 0.31%
# ('CE', 'FCC CLASS A', 'CCC', 'BSMI', 'CB', 'UL')                     |   3 | 0.31%
# ('CE', 'FCC', 'UL', 'CB', 'CCC', 'BSMI')                             |   3 | 0.31%
# ('CE', 'FCC CLASS B', 'ROHS')                                        |   3 | 0.31%
# ('EMC CE', 'FCC')                                                    |   3 | 0.31%
# ('AEC-Q100',)                                                        |   3 | 0.31%
# ('IEC-60068-2', 'IPC-A-610')                                         |   3 | 0.31%
# ('MODULAR COMPLIANCE CERTIFICATION FOR WIRELESS LAN AND BLUETOOTH',) |   2 | 0.20%
# ('CE', 'FCC CLASS B', 'CCC', 'BSMI', 'UL', 'CB')                     |   2 | 0.20%
# ('UL', 'CCC', 'BSMI', 'CE', 'FCC')                                   |   2 | 0.20%
# ('ARINC 600',)                                                       |   2 | 0.20%
# ----------------------------------------------------------------------------------------------------
# Values: (), ('CE', 'FCC'), ('ROHS',), ('ROHS COMPLIANT',), ('CE', 'FCC CLASS B'), ('CE/FCC',), ('CE', 'FCC', 'ROHS'), ('CE', 'FCC CLASS B', 'ROHS COMPLIANT'), ('CE', 'FCC CLASS A'), ('ROHS', 'CE', 'FCC CLASS B'), ('FCC CLASS B',), ('CE/FCC CLASS B',), ('CE', 'FCC', 'UL', 'CCC', 'BSMI'), ('ROHS COMPLIANT 2002/95/EC',), ('IEC 60068-2-27', 'IEC 60068-2-64', 'MIL-STD-810F'), ('FCC CLASS A',), ('CE',), ('MIL-STD-810G',), ('FCC', 'CE'), ('FCC PART 15',), ('MODULAR COMPLIANCE CERTIFICATION',), ('CE/FCC CLASS A',), ('ROHS', 'REACH'), ('CE CLASS B', 'FCC CLASS B'), ('CE', 'FCC CLASS A', 'CCC', 'BSMI', 'UL'), ('MIL-STD-810G COMPLIANCE',), ('FCC',), ('IPC-A-610G CLASS 3',), ('CE', 'FCC', 'EAC', 'ROHS', 'UL', 'CUL'), ('EN50155', 'EN45545', 'E-MARK'), ('FCC', 'CHINA ROHS'), ('IEC', 'MIL-STD-810F'), ('CLASS I', 'DIVISION 2 (CID2) & ATEX SOLUTIONS'), ('ROHS', 'MIL-STD-810G'), ('DIN EN ISO 9001',), ('ROHS COMPLIANCE',), ('ROHS COMPLIANT', 'MIL-STD-810G'), ('CE', 'LVD', 'FCC CLASS B'), ('ROHS', 'REACH', 'PICMG COM EXPRESS R2.1'), ('ROHS', 'MIL-STD-810H'), ('CE', 'FCC CLASS A', 'CCC', 'BSMI', 'CB', 'UL'), ('CE', 'FCC', 'UL', 'CB', 'CCC', 'BSMI'), ('CE', 'FCC CLASS B', 'ROHS'), ('EMC CE', 'FCC'), ('AEC-Q100',), ('IEC-60068-2', 'IPC-A-610'), ('MODULAR COMPLIANCE CERTIFICATION FOR WIRELESS LAN AND BLUETOOTH',), ('CE', 'FCC CLASS B', 'CCC', 'BSMI', 'UL', 'CB'), ('UL', 'CCC', 'BSMI', 'CE', 'FCC'), ('ARINC 600',)...

# %%
# save cleaned data
df.to_csv("../data/cleaned_data.csv", index=False)
